// %%
import scala.collection.immutable.HashMap
import scala.util.Random

// %% [markdown]
// # Atelier 2

// %% [markdown]
// ### Étape 1 - Représentation objet #####

// %%
case class Employee(
    val id: Int,
    val lastName: String,
    val firstName: String,
    val title: String,
    val reportsTo: Int
)
// Out:
// defined class Employee

// %%
case class MediaType(val id: Int, val name: String)
// Out:
// defined class MediaType

// %%
case class Genre(val id: Int, val name: String)
// Out:
// defined class Genre

// %%
case class Track(
    val id: Int,
    val name: String,
    val genreId: Int,
    val mediaTypeId: Int
)
// Out:
// defined class Track

// %%
case class InvoiceItem(
    val id: Int,
    val invoiceId: Int,
    val trackId: Int,
    val unitPrice: Double,
    val quantity: Int
)
// Out:
// defined class InvoiceItem

// %%
case class Invoice(val id: Int, val invoiceListItem: List[InvoiceItem])
// Out:
// defined class Invoice

// %% [markdown]
// ### Étape 2 - Génération du jeu de données

// %%
val genres: List[Genre] = List(
  new Genre(1, "Rock"),
  new Genre(2, "Jazz"),
  new Genre(3, "Metal"),
  new Genre(4, "Alternative & Punk"),
  new Genre(5, "Rock And Roll"),
  new Genre(6, "Blues"),
  new Genre(7, "Latin"),
  new Genre(8, "Reggae"),
  new Genre(9, "Pop"),
  new Genre(10, "Soundtrack"),
  new Genre(11, "Bossa Nova"),
  new Genre(12, "Easy Listening"),
  new Genre(13, "Heavy Metal"),
  new Genre(14, "R&B/Soul"),
  new Genre(15, "Electronica/Dance"),
  new Genre(16, "World"),
  new Genre(17, "Hip Hop/Rap"),
  new Genre(18, "Science Fiction"),
  new Genre(19, "TV Shows"),
  new Genre(20, "Sci Fi & Fantasy"),
  new Genre(21, "Drama"),
  new Genre(22, "Comedy"),
  new Genre(23, "Alternative"),
  new Genre(24, "Classical"),
  new Genre(25, "Opera")
)
// Out:
// genres = List(Genre(1,Rock), Genre(2,Jazz), Genre(3,Metal), Genre(4,Alternative & Punk), Genre(5,Rock And Roll), Genre(6,Blues), Genre(7,Latin), Genre(8,Reggae), Genre(9,Pop), Genre(10,Soundtrack), Genre(11,Bossa Nova), Genre(12,Easy Listening), Genre(13,Heavy Metal), Genre(14,R&B/Soul), Genre(15,Electronica/Dance), Genre(16,World), Genre(17,Hip Hop/Rap), Genre(18,Science Fiction), Genre(19,TV Shows), Genre(20,Sci Fi & Fantasy), Genre(21,Drama), Genre(22,Comedy), Genre(23,Alternative), Genre(24,Classical), Genre(25,Opera))
// List(Genre(1,Rock), Genre(2,Jazz), Genre(3,Metal), Genre(4,Alternative & Punk), Genre(5,Rock And Roll), Genre(6,Blues), Genre(7,Latin), Genre(8,Reggae), Genre(9,Pop), Genre(10,Soundtrack), Genre(11,Bossa Nova), Genre(12,Easy Listening), Genre(13,Heavy Metal), Genre(14,R&B/Soul), Genre(15,Electronica/Dance), Genre(16,World), Genre(17,Hip Hop/Rap), Genre(18,Science Fiction), Genre(19,TV Shows), Genre(20,Sci Fi & Fantasy), Genre(21,Drama), Genre(22,Comedy), Genre(23,Alternative), Genre(24,Classical), Genre(25,Opera))

// %%
val mediaTypes: List[MediaType] = List(
  new MediaType(1, "MPEG audio file"),
  new MediaType(2, "Protected AAC audio file"),
  new MediaType(3, "Protected MPEG-4 video file"),
  new MediaType(4, "Purchased AAC audio file"),
  new MediaType(5, "AAC audio file")
)
// Out:
// mediaTypes = List(MediaType(1,MPEG audio file), MediaType(2,Protected AAC audio file), MediaType(3,Protected MPEG-4 video file), MediaType(4,Purchased AAC audio file), MediaType(5,AAC audio file))
// List(MediaType(1,MPEG audio file), MediaType(2,Protected AAC audio file), MediaType(3,Protected MPEG-4 video file), MediaType(4,Purchased AAC audio file), MediaType(5,AAC audio file))

// %%
val employees: List[Employee] = List(
  new Employee(1, "Adams", "Andrew", "General Manager", 0),
  new Employee(2, "Edwards", "Nancy", "Sales Manager", 1),
  new Employee(3, "Peacock", "Jane", "Sales Support Agent", 2),
  new Employee(4, "Park", "Margaret", "Sales Support Agent", 2),
  new Employee(5, "Johnson", "Steve", "Sales Support Agent", 2),
  new Employee(6, "Mitchell", "Michael", "IT Manager", 1),
  new Employee(7, "King", "Robert", "IT Staff", 6),
  new Employee(8, "Callahan", "Laura", "IT Staff", 6)
)
// Out:
// employees = List(Employee(1,Adams,Andrew,General Manager,0), Employee(2,Edwards,Nancy,Sales Manager,1), Employee(3,Peacock,Jane,Sales Support Agent,2), Employee(4,Park,Margaret,Sales Support Agent,2), Employee(5,Johnson,Steve,Sales Support Agent,2), Employee(6,Mitchell,Michael,IT Manager,1), Employee(7,King,Robert,IT Staff,6), Employee(8,Callahan,Laura,IT Staff,6))
// List(Employee(1,Adams,Andrew,General Manager,0), Employee(2,Edwards,Nancy,Sales Manager,1), Employee(3,Peacock,Jane,Sales Support Agent,2), Employee(4,Park,Margaret,Sales Support Agent,2), Employee(5,Johnson,Steve,Sales Support Agent,2), Employee(6,Mitchell,Michael,IT Manager,1), Employee(7,King,Robert,IT Staff,6), Employee(8,Callahan,Laura,IT Staff,6))

// %%
val adjectives: HashMap[Int, String] = HashMap(
  1 -> "Cosmic",
  2 -> "Electric",
  3 -> "Velvet",
  4 -> "Mystic",
  5 -> "Atomic",
  6 -> "Phantom",
  7 -> "Silent",
  8 -> "Savage",
  9 -> "Eternal",
  10 -> "Digital",
  11 -> "Lost",
  12 -> "Sacred",
  13 -> "Wild",
  14 -> "Urban",
  15 -> "Golden",
  16 -> "Crystal",
  17 -> "Liquid",
  18 -> "Toxic",
  19 -> "Neon",
  20 -> "Crimson",
  21 -> "Stellar",
  22 -> "Raging",
  23 -> "Arctic",
  24 -> "Sonic",
  25 -> "Primal",
  26 -> "Midnight",
  27 -> "Screaming",
  28 -> "Infinite",
  29 -> "Royal",
  30 -> "Lunar"
)
// Out:
// adjectives = Map(5 -> Atomic, 10 -> Digital, 24 -> Sonic, 25 -> Primal, 14 -> Urban, 20 -> Crimson, 29 -> Royal, 1 -> Cosmic, 6 -> Phantom, 28 -> Infinite, 21 -> Stellar, 9 -> Eternal, 13 -> Wild, 2 -> Electric, 17 -> Liquid, 22 -> Raging, 27 -> Screaming, 12 -> Sacred, 7 -> Silent, 3 -> Velvet, 18 -> Toxic, 16 -> Crystal, 11 -> Lost, 26 -> Midnight, 23 -> Arctic, 8 -> Savage, 30 -> Lunar, 19 -> Neon, 4 -> Mystic, 15 -> Golden)
// Map(5 -> Atomic, 10 -> Digital, 24 -> Sonic, 25 -> Primal, 14 -> Urban, 20 -> Crimson, 29 -> Royal, 1 -> Cosmic, 6 -> Phantom, 28 -> Infinite, 21 -> Stellar, 9 -> Eternal, 13 -> Wild, 2 -> Electric, 17 -> Liquid, 22 -> Raging, 27 -> Screaming, 12 -> Sacred, 7 -> Silent, 3 -> Velvet, 18 -> Toxic, 16 -> Crystal, 11 -> Lost, 26 -> Midnight, 23 -> Arctic, 8 -> Savage, 30 -> Lunar, 19 -> Neon, 4 -> Mystic, 15 -> Golden)

// %%
val noms: HashMap[Int, String] = HashMap(
  1 -> "Echo",
  2 -> "Giants",
  3 -> "Wolves",
  4 -> "Horizon",
  5 -> "Empire",
  6 -> "Void",
  7 -> "Thunder",
  8 -> "Dragons",
  9 -> "Saints",
  10 -> "Kings",
  11 -> "Ghosts",
  12 -> "Ravens",
  13 -> "Pirates",
  14 -> "Heroes",
  15 -> "Rebels",
  16 -> "Demons",
  17 -> "Machines",
  18 -> "Angels",
  19 -> "Knights",
  20 -> "Lions",
  21 -> "Shadows",
  22 -> "Zombies",
  23 -> "Wizards",
  24 -> "Killers",
  25 -> "Titans",
  26 -> "Outlaws",
  27 -> "Rebels",
  28 -> "Prophets",
  29 -> "Bandits",
  30 -> "Warriors"
)
// Out:
// noms = Map(5 -> Empire, 10 -> Kings, 24 -> Killers, 25 -> Titans, 14 -> Heroes, 20 -> Lions, 29 -> Bandits, 1 -> Echo, 6 -> Void, 28 -> Prophets, 21 -> Shadows, 9 -> Saints, 13 -> Pirates, 2 -> Giants, 17 -> Machines, 22 -> Zombies, 27 -> Rebels, 12 -> Ravens, 7 -> Thunder, 3 -> Wolves, 18 -> Angels, 16 -> Demons, 11 -> Ghosts, 26 -> Outlaws, 23 -> Wizards, 8 -> Dragons, 30 -> Warriors, 19 -> Knights, 4 -> Horizon, 15 -> Rebels)
// Map(5 -> Empire, 10 -> Kings, 24 -> Killers, 25 -> Titans, 14 -> Heroes, 20 -> Lions, 29 -> Bandits, 1 -> Echo, 6 -> Void, 28 -> Prophets, 21 -> Shadows, 9 -> Saints, 13 -> Pirates, 2 -> Giants, 17 -> Machines, 22 -> Zombies, 27 -> Rebels, 12 -> Ravens, 7 -> Thunder, 3 -> Wolves, 18 -> Angels, 16 -> Demons, 11 -> Ghosts, 26 -> Outlaws, 23 -> Wizards, 8 -> Dragons, 30 -> Warriors, 19 -> Knights, 4 -> Horizon, 15 -> Rebels)

// %%
val complements: HashMap[Int, String] = HashMap(
  1 -> "of Doom",
  2 -> "in Chains",
  3 -> "from Mars",
  4 -> "of the North",
  5 -> "of Death",
  6 -> "in Disguise",
  7 -> "of the Night",
  8 -> "from Hell",
  9 -> "of Tomorrow",
  10 -> "in Flames",
  11 -> "of the Deep",
  12 -> "from Beyond",
  13 -> "of Destruction",
  14 -> "in Shadow",
  15 -> "from the Sky",
  16 -> "of the Abyss",
  17 -> "in Exile",
  18 -> "from the East",
  19 -> "of Eternity",
  20 -> "from the Desert",
  21 -> "of the Underground"
)
// Out:
// complements = Map(5 -> of Death, 10 -> in Flames, 14 -> in Shadow, 20 -> from the Desert, 1 -> of Doom, 6 -> in Disguise, 21 -> of the Underground, 9 -> of Tomorrow, 13 -> of Destruction, 2 -> in Chains, 17 -> in Exile, 12 -> from Beyond, 7 -> of the Night, 3 -> from Mars, 18 -> from the East, 16 -> of the Abyss, 11 -> of the Deep, 8 -> from Hell, 19 -> of Eternity, 4 -> of the North, 15 -> from the Sky)
// Map(5 -> of Death, 10 -> in Flames, 14 -> in Shadow, 20 -> from the Desert, 1 -> of Doom, 6 -> in Disguise, 21 -> of the Underground, 9 -> of Tomorrow, 13 -> of Destruction, 2 -> in Chains, 17 -> in Exile, 12 -> from Beyond, 7 -> of the Night, 3 -> from Mars, 18 -> from the East, 16 -> of the Abyss, 11 -> of the Deep, 8 -> from Hell, 19 -> of Eternity, 4 -> of the North, 15 -> from the Sky)

// %%
object Track {
  def generateTrack(id: Int): Track = {
    val randomAdjective: String = adjectives.getOrElse(Random.nextInt(30) + 1, "")
    val randomName: String = noms.getOrElse(Random.nextInt(30) + 1, "")
    val randomComplement: String = complements.getOrElse(Random.nextInt(21) + 1, "")
    
    val title: String = s"$randomAdjective $randomName $randomComplement"
    val genreId: Int = genres(Random.nextInt(genres.size)).id
    val mediaTypeId: Int = mediaTypes(Random.nextInt(mediaTypes.size)).id

    new Track(id, title, genreId, mediaTypeId)
  }
}
// Out:
// defined object Track
// warning: previously defined class Track is not a companion to object Track.
// Companions must be defined together; you may wish to use :paste mode for this.

// %%
val trackList: List[Track] = (for(index <- 1 to 200) yield {
  Track.generateTrack(index)
}).toList
// Out:
// trackList = List(Track(1,Infinite Machines from the Sky,8,4), Track(2,Electric Giants from the Sky,6,3), Track(3,Urban Wolves from Hell,3,3), Track(4,Lunar Wolves of the North,4,5), Track(5,Wild Ravens of Destruction,1,1), Track(6,Wild Outlaws from Beyond,23,1), Track(7,Neon Echo in Exile,6,3), Track(8,Neon Demons of the Night,6,3), Track(9,Savage Heroes from the Desert,10,1), Track(10,Lost Outlaws of Destruction,4,2), Track(11,Raging Echo from Beyond,16,2), Track(12,Midnight Rebels of Tomorrow,11,2), Track(13,Sonic Void of the North,25,3), Track(14,Mystic Rebels from the Desert,10,4), Track(15,Silent Killers of the Abyss,2,4), Track(16,Raging Wizards in Exile,19,3), Track(17,Stellar Angels from the East,20,3), Track(18,Golden Ravens of Eternity,16,5), Track(19,Toxic Killer...
// List(Track(1,Infinite Machines from the Sky,8,4), Track(2,Electric Giants from the Sky,6,3), Track(3,Urban Wolves from Hell,3,3), Track(4,Lunar Wolves of the North,4,5), Track(5,Wild Ravens of Destruction,1,1), Track(6,Wild Outlaws from Beyond,23,1), Track(7,Neon Echo in Exile,6,3), Track(8,Neon Demons of the Night,6,3), Track(9,Savage Heroes from the Desert,10,1), Track(10,Lost Outlaws of Destruction,4,2), Track(11,Raging Echo from Beyond,16,2), Track(12,Midnight Rebels of Tomorrow,11,2), Track(13,Sonic Void of the North,25,3), Track(14,Mystic Rebels from the Desert,10,4), Track(15,Silent Killers of the Abyss,2,4), Track(16,Raging Wizards in Exile,19,3), Track(17,Stellar Angels from the East,20,3), Track(18,Golden Ravens of Eternity,16,5), Track(19,Toxic Killer...

// %%
object Invoice {
  def generateInvoice(id: Int): Invoice = { 
      val invoiceItemList: List[InvoiceItem] = (for(index <- 1 to (Random.nextInt(5)+1)) yield {
        val trackId = trackList(Random.nextInt(trackList.size)).id
        
        new InvoiceItem(index, id, trackId, 10.35, 1)      
      }).toList

      new Invoice(id, invoiceItemList)
  }  
}
// Out:
// defined object Invoice
// warning: previously defined class Invoice is not a companion to object Invoice.
// Companions must be defined together; you may wish to use :paste mode for this.

// %%
val invoiceList: List[Invoice] = (for(index <- 1 to 2000) yield {
  Invoice.generateInvoice(index)
}).toList
// Out:
// invoiceList = List(Invoice(1,List(InvoiceItem(1,1,164,10.35,1), InvoiceItem(2,1,20,10.35,1))), Invoice(2,List(InvoiceItem(1,2,159,10.35,1), InvoiceItem(2,2,176,10.35,1), InvoiceItem(3,2,104,10.35,1), InvoiceItem(4,2,127,10.35,1), InvoiceItem(5,2,18,10.35,1))), Invoice(3,List(InvoiceItem(1,3,109,10.35,1), InvoiceItem(2,3,176,10.35,1), InvoiceItem(3,3,94,10.35,1), InvoiceItem(4,3,57,10.35,1), InvoiceItem(5,3,167,10.35,1))), Invoice(4,List(InvoiceItem(1,4,58,10.35,1), InvoiceItem(2,4,177,10.35,1), InvoiceItem(3,4,59,10.35,1), InvoiceItem(4,4,85,10.35,1), InvoiceItem(5,4,40,10.35,1))), Invoice(5,List(InvoiceItem(1,5,64,10.35,1))), Invoice(6,List(InvoiceItem(1,6,101,10.35,1), InvoiceItem(2,6,152,10.35,1), InvoiceItem(3,6,6,10.35,1), InvoiceItem(4,6,40,10.35,1), InvoiceItem(5,6...
// List(Invoice(1,List(InvoiceItem(1,1,164,10.35,1), InvoiceItem(2,1,20,10.35,1))), Invoice(2,List(InvoiceItem(1,2,159,10.35,1), InvoiceItem(2,2,176,10.35,1), InvoiceItem(3,2,104,10.35,1), InvoiceItem(4,2,127,10.35,1), InvoiceItem(5,2,18,10.35,1))), Invoice(3,List(InvoiceItem(1,3,109,10.35,1), InvoiceItem(2,3,176,10.35,1), InvoiceItem(3,3,94,10.35,1), InvoiceItem(4,3,57,10.35,1), InvoiceItem(5,3,167,10.35,1))), Invoice(4,List(InvoiceItem(1,4,58,10.35,1), InvoiceItem(2,4,177,10.35,1), InvoiceItem(3,4,59,10.35,1), InvoiceItem(4,4,85,10.35,1), InvoiceItem(5,4,40,10.35,1))), Invoice(5,List(InvoiceItem(1,5,64,10.35,1))), Invoice(6,List(InvoiceItem(1,6,101,10.35,1), InvoiceItem(2,6,152,10.35,1), InvoiceItem(3,6,6,10.35,1), InvoiceItem(4,6,40,10.35,1), InvoiceItem(5,6...

// %%
for (track <- trackList) println(track)
for (invoice <- invoiceList) println(invoice)
// Out:
// Track(1,Infinite Machines from the Sky,8,4)
// Track(2,Electric Giants from the Sky,6,3)
// Track(3,Urban Wolves from Hell,3,3)
// Track(4,Lunar Wolves of the North,4,5)
// Track(5,Wild Ravens of Destruction,1,1)
// Track(6,Wild Outlaws from Beyond,23,1)
// Track(7,Neon Echo in Exile,6,3)
// Track(8,Neon Demons of the Night,6,3)
// Track(9,Savage Heroes from the Desert,10,1)
// Track(10,Lost Outlaws of Destruction,4,2)
// Track(11,Raging Echo from Beyond,16,2)
// Track(12,Midnight Rebels of Tomorrow,11,2)
// Track(13,Sonic Void of the North,25,3)
// Track(14,Mystic Rebels from the Desert,10,4)
// Track(15,Silent Killers of the Abyss,2,4)
// Track(16,Raging Wizards in Exile,19,3)
// Track(17,Stellar Angels from the East,20,3)
// Track(18,Golden Ravens of Eternity,16,5)
// Track(19,Toxic Killers in Chains,25,5)
// Track(20,Raging Ravens from Mars,9,4)
// Track(21,Royal Rebels in Shadow,21,5)
// Track(22,Infinite Echo of the North,15,2)
// Track(23,Silent Warriors from the Desert,20,3)
// Track(24,Velvet Machines in Disguise,9,3)
// Track(25,Cosmic Knights of the Underground,20,4)
// Track(26,Primal Void of Tomorrow,23,4)
// Track(27,Golden Kings from the Desert,5,1)
// Track(28,Electric Shadows in Disguise,23,2)
// Track(29,Cosmic Heroes from the Sky,16,4)
// Track(30,Lunar Thunder from Mars,3,5)
// Track(31,Velvet Dragons of the Deep,17,4)
// Track(32,Liquid Demons of the North,20,4)
// Track(33,Midnight Void of the North,25,3)
// Track(34,Liquid Bandits of the North,21,3)
// Track(35,Neon Prophets in Flames,17,2)
// Track(36,Crimson Warriors in Shadow,6,3)
// Track(37,Infinite Ghosts from Beyond,14,4)
// Track(38,Arctic Void from Beyond,10,3)
// Track(39,Phantom Wizards of the Underground,20,2)
// Track(40,Midnight Lions from Beyond,17,1)
// Track(41,Raging Killers from Hell,18,1)
// Track(42,Sonic Bandits of the Abyss,13,2)
// Track(43,Crystal Knights in Disguise,20,4)
// Track(44,Sacred Rebels of the North,24,3)
// Track(45,Arctic Void of Destruction,21,2)
// Track(46,Digital Dragons of the Underground,7,4)
// Track(47,Screaming Dragons in Exile,22,3)
// Track(48,Infinite Shadows from Mars,5,4)
// Track(49,Primal Thunder of the Underground,25,2)
// Track(50,Raging Pirates from the Desert,23,3)
// Track(51,Arctic Titans from Hell,18,2)
// Track(52,Silent Dragons from the Sky,24,2)
// Track(53,Infinite Wizards of Eternity,2,1)
// Track(54,Arctic Lions from the Sky,5,3)
// Track(55,Sonic Demons of the North,3,1)
// Track(56,Stellar Rebels of Eternity,20,1)
// Track(57,Screaming Void from Mars,22,5)
// Track(58,Royal Echo from the East,4,2)
// Track(59,Golden Giants from Beyond,25,5)
// Track(60,Sonic Horizon of Eternity,12,2)
// Track(61,Liquid Machines of the Abyss,8,1)
// Track(62,Stellar Outlaws of the Abyss,8,1)
// Track(63,Sonic Void from the Desert,9,4)
// Track(64,Crystal Shadows of Tomorrow,14,2)
// Track(65,Neon Ravens in Exile,9,3)
// Track(66,Royal Giants in Exile,15,5)
// Track(67,Cosmic Zombies in Shadow,25,2)
// Track(68,Electric Thunder of Destruction,13,4)
// Track(69,Lost Bandits in Chains,22,1)
// Track(70,Infinite Outlaws of Doom,18,1)
// Track(71,Savage Prophets in Shadow,3,3)
// Track(72,Arctic Killers from the East,24,5)
// Track(73,Midnight Empire in Exile,5,1)
// Track(74,Infinite Empire in Flames,19,5)
// Track(75,Sacred Saints of Eternity,5,5)
// Track(76,Cosmic Shadows in Exile,14,2)
// Track(77,Stellar Heroes from the Desert,7,3)
// Track(78,Golden Knights of Doom,8,1)
// Track(79,Sonic Void of the Night,12,3)
// Track(80,Silent Pirates from the Desert,22,3)
// Track(81,Stellar Horizon in Disguise,6,4)
// Track(82,Lost Ravens of Death,8,3)
// Track(83,Screaming Heroes in Disguise,12,2)
// Track(84,Savage Outlaws from the Sky,15,1)
// Track(85,Screaming Knights of Tomorrow,24,3)
// Track(86,Screaming Horizon of Death,19,3)
// Track(87,Velvet Empire of Doom,13,5)
// Track(88,Liquid Dragons of Death,17,5)
// Track(89,Lunar Echo of the Abyss,13,4)
// Track(90,Screaming Heroes of Tomorrow,13,5)
// Track(91,Lost Demons of Destruction,2,1)
// Track(92,Silent Giants in Chains,11,1)
// Track(93,Savage Void of the Underground,18,2)
// Track(94,Toxic Wolves of the Deep,8,3)
// Track(95,Velvet Empire in Disguise,21,2)
// Track(96,Urban Ravens in Flames,21,5)
// Track(97,Royal Warriors of the North,2,3)
// Track(98,Cosmic Rebels from Mars,16,5)
// Track(99,Electric Shadows from the East,9,4)
// Track(100,Sacred Wizards in Flames,17,3)
// Track(101,Wild Empire of Death,17,5)
// Track(102,Lunar Ravens of the Underground,7,3)
// Track(103,Wild Dragons of Eternity,4,5)
// Track(104,Silent Wolves in Exile,22,4)
// Track(105,Atomic Ravens of Eternity,24,3)
// Track(106,Digital Zombies from Hell,23,2)
// Track(107,Wild Lions in Disguise,3,1)
// Track(108,Silent Killers in Shadow,25,4)
// Track(109,Urban Pirates from Hell,15,1)
// Track(110,Crystal Killers of Doom,9,3)
// Track(111,Stellar Knights of Tomorrow,8,1)
// Track(112,Lunar Ghosts of Doom,20,2)
// Track(113,Wild Thunder of Doom,10,1)
// Track(114,Wild Titans from the Sky,22,3)
// Track(115,Raging Horizon of the Deep,3,2)
// Track(116,Urban Echo from Beyond,11,2)
// Track(117,Velvet Warriors of the Underground,8,4)
// Track(118,Lost Prophets in Chains,9,5)
// Track(119,Stellar Zombies in Chains,17,3)
// Track(120,Sonic Pirates from the East,1,4)
// Track(121,Lost Wizards in Exile,5,1)
// Track(122,Velvet Outlaws in Exile,11,3)
// Track(123,Royal Wizards of the Abyss,7,3)
// Track(124,Silent Ravens from the East,4,1)
// Track(125,Savage Rebels from the Desert,12,4)
// Track(126,Atomic Ghosts from the East,11,2)
// Track(127,Royal Wolves from Beyond,1,4)
// Track(128,Crimson Giants from Mars,15,2)
// Track(129,Velvet Zombies of the Night,15,3)
// Track(130,Sonic Rebels of the Underground,7,1)
// Track(131,Silent Bandits of Eternity,8,1)
// Track(132,Atomic Demons of Eternity,22,5)
// Track(133,Savage Titans from the East,8,2)
// Track(134,Cosmic Outlaws from Hell,6,3)
// Track(135,Primal Ghosts from the Desert,12,5)
// Track(136,Infinite Echo of Tomorrow,17,5)
// Track(137,Screaming Rebels of Destruction,15,1)
// Track(138,Electric Ravens of the Deep,14,4)
// Track(139,Phantom Zombies of Doom,4,2)
// Track(140,Phantom Knights of the Underground,9,2)
// Track(141,Mystic Echo of Eternity,18,4)
// Track(142,Savage Warriors of Death,19,5)
// Track(143,Raging Thunder in Chains,22,5)
// Track(144,Sacred Kings of Death,16,5)
// Track(145,Neon Dragons in Flames,5,2)
// Track(146,Stellar Knights from the Sky,7,3)
// Track(147,Neon Zombies of the Abyss,4,3)
// Track(148,Cosmic Outlaws from the Sky,14,3)
// Track(149,Sonic Ghosts from Hell,19,5)
// Track(150,Mystic Empire in Flames,18,2)
// Track(151,Velvet Prophets of Destruction,17,4)
// Track(152,Royal Killers from the Desert,23,5)
// Track(153,Golden Outlaws of the Night,9,3)
// Track(154,Liquid Heroes of the Deep,4,1)
// Track(155,Lunar Ravens from Hell,10,4)
// Track(156,Crimson Wolves of Tomorrow,8,5)
// Track(157,Phantom Angels from Mars,24,1)
// Track(158,Stellar Giants of the Night,15,1)
// Track(159,Royal Warriors of the Deep,15,5)
// Track(160,Sonic Rebels from the Sky,16,2)
// Track(161,Velvet Outlaws of Death,7,5)
// Track(162,Savage Titans of Death,16,2)
// Track(163,Royal Ghosts in Shadow,14,2)
// Track(164,Lost Machines of Eternity,16,4)
// Track(165,Sonic Angels of Death,11,4)
// Track(166,Midnight Titans of the Abyss,2,3)
// Track(167,Crystal Wolves of Eternity,25,5)
// Track(168,Liquid Outlaws from Mars,10,4)
// Track(169,Arctic Outlaws from Beyond,11,3)
// Track(170,Raging Shadows from Mars,15,5)
// Track(171,Golden Kings from Beyond,3,3)
// Track(172,Sacred Empire from the Sky,1,3)
// Track(173,Toxic Rebels of the Deep,9,4)
// Track(174,Arctic Lions of Doom,11,2)
// Track(175,Liquid Ravens in Chains,6,4)
// Track(176,Savage Kings from the East,15,4)
// Track(177,Royal Prophets of the Abyss,23,2)
// Track(178,Golden Echo from Beyond,23,3)
// Track(179,Sacred Wizards in Disguise,4,1)
// Track(180,Sacred Lions of Tomorrow,1,4)
// Track(181,Golden Lions of Destruction,19,5)
// Track(182,Royal Dragons of Death,17,3)
// Track(183,Digital Rebels of Tomorrow,3,5)
// Track(184,Golden Machines of Doom,10,5)
// Track(185,Primal Shadows of the Night,23,5)
// Track(186,Digital Heroes from the East,4,2)
// Track(187,Eternal Void in Chains,9,1)
// Track(188,Toxic Kings of Tomorrow,18,2)
// Track(189,Sacred Saints in Flames,18,1)
// Track(190,Velvet Kings of the North,12,1)
// Track(191,Toxic Rebels in Exile,11,2)
// Track(192,Primal Wolves of Destruction,17,2)
// Track(193,Stellar Zombies in Disguise,9,2)
// Track(194,Stellar Void of Tomorrow,3,2)
// Track(195,Digital Heroes in Disguise,14,1)
// Track(196,Royal Horizon of Doom,17,4)
// Track(197,Liquid Lions of Doom,8,4)
// Track(198,Infinite Zombies of the Abyss,5,5)
// Track(199,Royal Void in Flames,10,2)
// Track(200,Midnight Outlaws of Death,13,2)
// Invoice(1,List(InvoiceItem(1,1,164,10.35,1), InvoiceItem(2,1,20,10.35,1)))
// Invoice(2,List(InvoiceItem(1,2,159,10.35,1), InvoiceItem(2,2,176,10.35,1), InvoiceItem(3,2,104,10.35,1), InvoiceItem(4,2,127,10.35,1), InvoiceItem(5,2,18,10.35,1)))
// Invoice(3,List(InvoiceItem(1,3,109,10.35,1), InvoiceItem(2,3,176,10.35,1), InvoiceItem(3,3,94,10.35,1), InvoiceItem(4,3,57,10.35,1), InvoiceItem(5,3,167,10.35,1)))
// Invoice(4,List(InvoiceItem(1,4,58,10.35,1), InvoiceItem(2,4,177,10.35,1), InvoiceItem(3,4,59,10.35,1), InvoiceItem(4,4,85,10.35,1), InvoiceItem(5,4,40,10.35,1)))
// Invoice(5,List(InvoiceItem(1,5,64,10.35,1)))
// Invoice(6,List(InvoiceItem(1,6,101,10.35,1), InvoiceItem(2,6,152,10.35,1), InvoiceItem(3,6,6,10.35,1), InvoiceItem(4,6,40,10.35,1), InvoiceItem(5,6,54,10.35,1)))
// Invoice(7,List(InvoiceItem(1,7,185,10.35,1), InvoiceItem(2,7,24,10.35,1), InvoiceItem(3,7,88,10.35,1), InvoiceItem(4,7,120,10.35,1)))
// Invoice(8,List(InvoiceItem(1,8,179,10.35,1)))
// Invoice(9,List(InvoiceItem(1,9,152,10.35,1), InvoiceItem(2,9,105,10.35,1), InvoiceItem(3,9,9,10.35,1), InvoiceItem(4,9,68,10.35,1), InvoiceItem(5,9,26,10.35,1)))
// Invoice(10,List(InvoiceItem(1,10,32,10.35,1)))
// Invoice(11,List(InvoiceItem(1,11,49,10.35,1), InvoiceItem(2,11,147,10.35,1), InvoiceItem(3,11,60,10.35,1), InvoiceItem(4,11,156,10.35,1), InvoiceItem(5,11,143,10.35,1)))
// Invoice(12,List(InvoiceItem(1,12,92,10.35,1), InvoiceItem(2,12,126,10.35,1), InvoiceItem(3,12,147,10.35,1), InvoiceItem(4,12,27,10.35,1), InvoiceItem(5,12,152,10.35,1)))
// Invoice(13,List(InvoiceItem(1,13,69,10.35,1), InvoiceItem(2,13,139,10.35,1), InvoiceItem(3,13,54,10.35,1), InvoiceItem(4,13,62,10.35,1), InvoiceItem(5,13,53,10.35,1)))
// Invoice(14,List(InvoiceItem(1,14,12,10.35,1), InvoiceItem(2,14,135,10.35,1), InvoiceItem(3,14,42,10.35,1), InvoiceItem(4,14,72,10.35,1), InvoiceItem(5,14,48,10.35,1)))
// Invoice(15,List(InvoiceItem(1,15,158,10.35,1), InvoiceItem(2,15,187,10.35,1)))
// Invoice(16,List(InvoiceItem(1,16,9,10.35,1), InvoiceItem(2,16,62,10.35,1), InvoiceItem(3,16,157,10.35,1)))
// Invoice(17,List(InvoiceItem(1,17,35,10.35,1), InvoiceItem(2,17,144,10.35,1), InvoiceItem(3,17,12,10.35,1)))
// Invoice(18,List(InvoiceItem(1,18,15,10.35,1), InvoiceItem(2,18,173,10.35,1), InvoiceItem(3,18,48,10.35,1)))
// Invoice(19,List(InvoiceItem(1,19,175,10.35,1), InvoiceItem(2,19,6,10.35,1), InvoiceItem(3,19,121,10.35,1), InvoiceItem(4,19,101,10.35,1), InvoiceItem(5,19,69,10.35,1)))
// Invoice(20,List(InvoiceItem(1,20,130,10.35,1), InvoiceItem(2,20,100,10.35,1), InvoiceItem(3,20,166,10.35,1)))
// Invoice(21,List(InvoiceItem(1,21,81,10.35,1), InvoiceItem(2,21,149,10.35,1), InvoiceItem(3,21,186,10.35,1), InvoiceItem(4,21,5,10.35,1), InvoiceItem(5,21,95,10.35,1)))
// Invoice(22,List(InvoiceItem(1,22,3,10.35,1), InvoiceItem(2,22,70,10.35,1), InvoiceItem(3,22,194,10.35,1), InvoiceItem(4,22,12,10.35,1)))
// Invoice(23,List(InvoiceItem(1,23,61,10.35,1), InvoiceItem(2,23,28,10.35,1), InvoiceItem(3,23,4,10.35,1)))
// Invoice(24,List(InvoiceItem(1,24,2,10.35,1), InvoiceItem(2,24,48,10.35,1), InvoiceItem(3,24,158,10.35,1)))
// Invoice(25,List(InvoiceItem(1,25,102,10.35,1), InvoiceItem(2,25,1,10.35,1), InvoiceItem(3,25,185,10.35,1)))
// Invoice(26,List(InvoiceItem(1,26,124,10.35,1), InvoiceItem(2,26,143,10.35,1), InvoiceItem(3,26,25,10.35,1)))
// Invoice(27,List(InvoiceItem(1,27,20,10.35,1), InvoiceItem(2,27,103,10.35,1), InvoiceItem(3,27,21,10.35,1), InvoiceItem(4,27,42,10.35,1), InvoiceItem(5,27,170,10.35,1)))
// Invoice(28,List(InvoiceItem(1,28,101,10.35,1), InvoiceItem(2,28,51,10.35,1), InvoiceItem(3,28,6,10.35,1)))
// Invoice(29,List(InvoiceItem(1,29,105,10.35,1)))
// Invoice(30,List(InvoiceItem(1,30,44,10.35,1), InvoiceItem(2,30,187,10.35,1)))
// Invoice(31,List(InvoiceItem(1,31,192,10.35,1)))
// Invoice(32,List(InvoiceItem(1,32,132,10.35,1), InvoiceItem(2,32,25,10.35,1), InvoiceItem(3,32,65,10.35,1), InvoiceItem(4,32,75,10.35,1)))
// Invoice(33,List(InvoiceItem(1,33,76,10.35,1), InvoiceItem(2,33,86,10.35,1), InvoiceItem(3,33,135,10.35,1), InvoiceItem(4,33,160,10.35,1)))
// Invoice(34,List(InvoiceItem(1,34,4,10.35,1), InvoiceItem(2,34,115,10.35,1), InvoiceItem(3,34,16,10.35,1)))
// Invoice(35,List(InvoiceItem(1,35,36,10.35,1), InvoiceItem(2,35,55,10.35,1), InvoiceItem(3,35,46,10.35,1), InvoiceItem(4,35,127,10.35,1)))
// Invoice(36,List(InvoiceItem(1,36,80,10.35,1), InvoiceItem(2,36,59,10.35,1), InvoiceItem(3,36,58,10.35,1), InvoiceItem(4,36,23,10.35,1)))
// Invoice(37,List(InvoiceItem(1,37,105,10.35,1)))
// Invoice(38,List(InvoiceItem(1,38,135,10.35,1), InvoiceItem(2,38,116,10.35,1), InvoiceItem(3,38,105,10.35,1), InvoiceItem(4,38,188,10.35,1)))
// Invoice(39,List(InvoiceItem(1,39,36,10.35,1), InvoiceItem(2,39,55,10.35,1), InvoiceItem(3,39,71,10.35,1), InvoiceItem(4,39,169,10.35,1), InvoiceItem(5,39,31,10.35,1)))
// Invoice(40,List(InvoiceItem(1,40,177,10.35,1), InvoiceItem(2,40,171,10.35,1), InvoiceItem(3,40,196,10.35,1), InvoiceItem(4,40,143,10.35,1), InvoiceItem(5,40,138,10.35,1)))
// Invoice(41,List(InvoiceItem(1,41,117,10.35,1), InvoiceItem(2,41,121,10.35,1), InvoiceItem(3,41,199,10.35,1), InvoiceItem(4,41,19,10.35,1), InvoiceItem(5,41,166,10.35,1)))
// Invoice(42,List(InvoiceItem(1,42,163,10.35,1), InvoiceItem(2,42,152,10.35,1), InvoiceItem(3,42,124,10.35,1), InvoiceItem(4,42,180,10.35,1)))
// Invoice(43,List(InvoiceItem(1,43,121,10.35,1), InvoiceItem(2,43,48,10.35,1), InvoiceItem(3,43,61,10.35,1), InvoiceItem(4,43,158,10.35,1), InvoiceItem(5,43,17,10.35,1)))
// Invoice(44,List(InvoiceItem(1,44,105,10.35,1), InvoiceItem(2,44,52,10.35,1), InvoiceItem(3,44,108,10.35,1)))
// Invoice(45,List(InvoiceItem(1,45,115,10.35,1), InvoiceItem(2,45,60,10.35,1), InvoiceItem(3,45,80,10.35,1)))
// Invoice(46,List(InvoiceItem(1,46,123,10.35,1), InvoiceItem(2,46,127,10.35,1), InvoiceItem(3,46,160,10.35,1)))
// Invoice(47,List(InvoiceItem(1,47,132,10.35,1)))
// Invoice(48,List(InvoiceItem(1,48,108,10.35,1)))
// Invoice(49,List(InvoiceItem(1,49,101,10.35,1), InvoiceItem(2,49,73,10.35,1), InvoiceItem(3,49,161,10.35,1)))
// Invoice(50,List(InvoiceItem(1,50,10,10.35,1), InvoiceItem(2,50,16,10.35,1)))
// Invoice(51,List(InvoiceItem(1,51,120,10.35,1), InvoiceItem(2,51,30,10.35,1)))
// Invoice(52,List(InvoiceItem(1,52,30,10.35,1), InvoiceItem(2,52,185,10.35,1)))
// Invoice(53,List(InvoiceItem(1,53,135,10.35,1), InvoiceItem(2,53,32,10.35,1), InvoiceItem(3,53,98,10.35,1), InvoiceItem(4,53,142,10.35,1), InvoiceItem(5,53,97,10.35,1)))
// Invoice(54,List(InvoiceItem(1,54,108,10.35,1), InvoiceItem(2,54,98,10.35,1), InvoiceItem(3,54,146,10.35,1), InvoiceItem(4,54,8,10.35,1)))
// Invoice(55,List(InvoiceItem(1,55,200,10.35,1), InvoiceItem(2,55,117,10.35,1), InvoiceItem(3,55,10,10.35,1), InvoiceItem(4,55,96,10.35,1), InvoiceItem(5,55,65,10.35,1)))
// Invoice(56,List(InvoiceItem(1,56,1,10.35,1)))
// Invoice(57,List(InvoiceItem(1,57,8,10.35,1), InvoiceItem(2,57,195,10.35,1)))
// Invoice(58,List(InvoiceItem(1,58,138,10.35,1), InvoiceItem(2,58,54,10.35,1), InvoiceItem(3,58,73,10.35,1), InvoiceItem(4,58,21,10.35,1), InvoiceItem(5,58,177,10.35,1)))
// Invoice(59,List(InvoiceItem(1,59,35,10.35,1), InvoiceItem(2,59,50,10.35,1), InvoiceItem(3,59,8,10.35,1), InvoiceItem(4,59,4,10.35,1), InvoiceItem(5,59,157,10.35,1)))
// Invoice(60,List(InvoiceItem(1,60,128,10.35,1), InvoiceItem(2,60,61,10.35,1), InvoiceItem(3,60,87,10.35,1)))
// Invoice(61,List(InvoiceItem(1,61,188,10.35,1), InvoiceItem(2,61,17,10.35,1), InvoiceItem(3,61,70,10.35,1), InvoiceItem(4,61,71,10.35,1)))
// Invoice(62,List(InvoiceItem(1,62,68,10.35,1), InvoiceItem(2,62,68,10.35,1), InvoiceItem(3,62,76,10.35,1)))
// Invoice(63,List(InvoiceItem(1,63,115,10.35,1), InvoiceItem(2,63,135,10.35,1), InvoiceItem(3,63,50,10.35,1), InvoiceItem(4,63,29,10.35,1), InvoiceItem(5,63,15,10.35,1)))
// Invoice(64,List(InvoiceItem(1,64,13,10.35,1), InvoiceItem(2,64,30,10.35,1), InvoiceItem(3,64,53,10.35,1)))
// Invoice(65,List(InvoiceItem(1,65,115,10.35,1)))
// Invoice(66,List(InvoiceItem(1,66,3,10.35,1), InvoiceItem(2,66,177,10.35,1), InvoiceItem(3,66,24,10.35,1)))
// Invoice(67,List(InvoiceItem(1,67,89,10.35,1), InvoiceItem(2,67,108,10.35,1), InvoiceItem(3,67,69,10.35,1)))
// Invoice(68,List(InvoiceItem(1,68,185,10.35,1)))
// Invoice(69,List(InvoiceItem(1,69,15,10.35,1), InvoiceItem(2,69,94,10.35,1), InvoiceItem(3,69,4,10.35,1), InvoiceItem(4,69,147,10.35,1)))
// Invoice(70,List(InvoiceItem(1,70,62,10.35,1)))
// Invoice(71,List(InvoiceItem(1,71,74,10.35,1), InvoiceItem(2,71,180,10.35,1), InvoiceItem(3,71,33,10.35,1), InvoiceItem(4,71,143,10.35,1), InvoiceItem(5,71,12,10.35,1)))
// Invoice(72,List(InvoiceItem(1,72,199,10.35,1)))
// Invoice(73,List(InvoiceItem(1,73,11,10.35,1)))
// Invoice(74,List(InvoiceItem(1,74,55,10.35,1), InvoiceItem(2,74,1,10.35,1), InvoiceItem(3,74,197,10.35,1)))
// Invoice(75,List(InvoiceItem(1,75,58,10.35,1), InvoiceItem(2,75,134,10.35,1), InvoiceItem(3,75,71,10.35,1), InvoiceItem(4,75,93,10.35,1)))
// Invoice(76,List(InvoiceItem(1,76,112,10.35,1), InvoiceItem(2,76,192,10.35,1)))
// Invoice(77,List(InvoiceItem(1,77,135,10.35,1), InvoiceItem(2,77,110,10.35,1), InvoiceItem(3,77,40,10.35,1), InvoiceItem(4,77,74,10.35,1), InvoiceItem(5,77,7,10.35,1)))
// Invoice(78,List(InvoiceItem(1,78,63,10.35,1)))
// Invoice(79,List(InvoiceItem(1,79,45,10.35,1), InvoiceItem(2,79,48,10.35,1), InvoiceItem(3,79,114,10.35,1), InvoiceItem(4,79,43,10.35,1), InvoiceItem(5,79,28,10.35,1)))
// Invoice(80,List(InvoiceItem(1,80,24,10.35,1)))
// Invoice(81,List(InvoiceItem(1,81,186,10.35,1), InvoiceItem(2,81,63,10.35,1), InvoiceItem(3,81,130,10.35,1), InvoiceItem(4,81,72,10.35,1), InvoiceItem(5,81,153,10.35,1)))
// Invoice(82,List(InvoiceItem(1,82,65,10.35,1)))
// Invoice(83,List(InvoiceItem(1,83,11,10.35,1), InvoiceItem(2,83,122,10.35,1)))
// Invoice(84,List(InvoiceItem(1,84,21,10.35,1), InvoiceItem(2,84,6,10.35,1), InvoiceItem(3,84,38,10.35,1)))
// Invoice(85,List(InvoiceItem(1,85,15,10.35,1), InvoiceItem(2,85,183,10.35,1), InvoiceItem(3,85,121,10.35,1), InvoiceItem(4,85,170,10.35,1)))
// Invoice(86,List(InvoiceItem(1,86,50,10.35,1), InvoiceItem(2,86,198,10.35,1), InvoiceItem(3,86,164,10.35,1)))
// Invoice(87,List(InvoiceItem(1,87,56,10.35,1), InvoiceItem(2,87,71,10.35,1), InvoiceItem(3,87,104,10.35,1), InvoiceItem(4,87,24,10.35,1), InvoiceItem(5,87,185,10.35,1)))
// Invoice(88,List(InvoiceItem(1,88,158,10.35,1)))
// Invoice(89,List(InvoiceItem(1,89,113,10.35,1)))
// Invoice(90,List(InvoiceItem(1,90,105,10.35,1)))
// Invoice(91,List(InvoiceItem(1,91,135,10.35,1), InvoiceItem(2,91,172,10.35,1), InvoiceItem(3,91,41,10.35,1), InvoiceItem(4,91,99,10.35,1)))
// Invoice(92,List(InvoiceItem(1,92,178,10.35,1), InvoiceItem(2,92,181,10.35,1)))
// Invoice(93,List(InvoiceItem(1,93,59,10.35,1), InvoiceItem(2,93,71,10.35,1), InvoiceItem(3,93,173,10.35,1)))
// Invoice(94,List(InvoiceItem(1,94,45,10.35,1), InvoiceItem(2,94,21,10.35,1), InvoiceItem(3,94,78,10.35,1)))
// Invoice(95,List(InvoiceItem(1,95,68,10.35,1)))
// Invoice(96,List(InvoiceItem(1,96,151,10.35,1), InvoiceItem(2,96,119,10.35,1), InvoiceItem(3,96,161,10.35,1)))
// Invoice(97,List(InvoiceItem(1,97,161,10.35,1), InvoiceItem(2,97,181,10.35,1), InvoiceItem(3,97,191,10.35,1)))
// Invoice(98,List(InvoiceItem(1,98,179,10.35,1), InvoiceItem(2,98,98,10.35,1), InvoiceItem(3,98,104,10.35,1), InvoiceItem(4,98,164,10.35,1), InvoiceItem(5,98,50,10.35,1)))
// Invoice(99,List(InvoiceItem(1,99,14,10.35,1), InvoiceItem(2,99,10,10.35,1), InvoiceItem(3,99,200,10.35,1), InvoiceItem(4,99,49,10.35,1)))
// Invoice(100,List(InvoiceItem(1,100,66,10.35,1)))
// Invoice(101,List(InvoiceItem(1,101,108,10.35,1), InvoiceItem(2,101,113,10.35,1)))
// Invoice(102,List(InvoiceItem(1,102,111,10.35,1)))
// Invoice(103,List(InvoiceItem(1,103,157,10.35,1), InvoiceItem(2,103,15,10.35,1), InvoiceItem(3,103,79,10.35,1)))
// Invoice(104,List(InvoiceItem(1,104,169,10.35,1), InvoiceItem(2,104,23,10.35,1), InvoiceItem(3,104,20,10.35,1)))
// Invoice(105,List(InvoiceItem(1,105,85,10.35,1)))
// Invoice(106,List(InvoiceItem(1,106,55,10.35,1), InvoiceItem(2,106,79,10.35,1), InvoiceItem(3,106,87,10.35,1), InvoiceItem(4,106,68,10.35,1), InvoiceItem(5,106,139,10.35,1)))
// Invoice(107,List(InvoiceItem(1,107,106,10.35,1), InvoiceItem(2,107,104,10.35,1), InvoiceItem(3,107,155,10.35,1), InvoiceItem(4,107,14,10.35,1)))
// Invoice(108,List(InvoiceItem(1,108,86,10.35,1)))
// Invoice(109,List(InvoiceItem(1,109,59,10.35,1), InvoiceItem(2,109,90,10.35,1), InvoiceItem(3,109,7,10.35,1), InvoiceItem(4,109,19,10.35,1), InvoiceItem(5,109,52,10.35,1)))
// Invoice(110,List(InvoiceItem(1,110,129,10.35,1)))
// Invoice(111,List(InvoiceItem(1,111,25,10.35,1), InvoiceItem(2,111,99,10.35,1)))
// Invoice(112,List(InvoiceItem(1,112,33,10.35,1), InvoiceItem(2,112,105,10.35,1), InvoiceItem(3,112,44,10.35,1), InvoiceItem(4,112,170,10.35,1)))
// Invoice(113,List(InvoiceItem(1,113,104,10.35,1), InvoiceItem(2,113,9,10.35,1), InvoiceItem(3,113,75,10.35,1)))
// Invoice(114,List(InvoiceItem(1,114,25,10.35,1), InvoiceItem(2,114,8,10.35,1), InvoiceItem(3,114,136,10.35,1), InvoiceItem(4,114,130,10.35,1)))
// Invoice(115,List(InvoiceItem(1,115,189,10.35,1), InvoiceItem(2,115,39,10.35,1), InvoiceItem(3,115,136,10.35,1), InvoiceItem(4,115,17,10.35,1), InvoiceItem(5,115,93,10.35,1)))
// Invoice(116,List(InvoiceItem(1,116,142,10.35,1), InvoiceItem(2,116,189,10.35,1), InvoiceItem(3,116,102,10.35,1), InvoiceItem(4,116,12,10.35,1), InvoiceItem(5,116,119,10.35,1)))
// Invoice(117,List(InvoiceItem(1,117,59,10.35,1)))
// Invoice(118,List(InvoiceItem(1,118,46,10.35,1), InvoiceItem(2,118,122,10.35,1), InvoiceItem(3,118,188,10.35,1), InvoiceItem(4,118,170,10.35,1)))
// Invoice(119,List(InvoiceItem(1,119,50,10.35,1), InvoiceItem(2,119,185,10.35,1)))
// Invoice(120,List(InvoiceItem(1,120,107,10.35,1)))
// Invoice(121,List(InvoiceItem(1,121,111,10.35,1), InvoiceItem(2,121,148,10.35,1), InvoiceItem(3,121,56,10.35,1), InvoiceItem(4,121,152,10.35,1), InvoiceItem(5,121,164,10.35,1)))
// Invoice(122,List(InvoiceItem(1,122,67,10.35,1)))
// Invoice(123,List(InvoiceItem(1,123,12,10.35,1), InvoiceItem(2,123,6,10.35,1), InvoiceItem(3,123,67,10.35,1)))
// Invoice(124,List(InvoiceItem(1,124,181,10.35,1), InvoiceItem(2,124,184,10.35,1)))
// Invoice(125,List(InvoiceItem(1,125,27,10.35,1), InvoiceItem(2,125,72,10.35,1), InvoiceItem(3,125,86,10.35,1)))
// Invoice(126,List(InvoiceItem(1,126,183,10.35,1), InvoiceItem(2,126,14,10.35,1), InvoiceItem(3,126,87,10.35,1), InvoiceItem(4,126,26,10.35,1), InvoiceItem(5,126,123,10.35,1)))
// Invoice(127,List(InvoiceItem(1,127,76,10.35,1)))
// Invoice(128,List(InvoiceItem(1,128,135,10.35,1), InvoiceItem(2,128,198,10.35,1), InvoiceItem(3,128,55,10.35,1), InvoiceItem(4,128,101,10.35,1)))
// Invoice(129,List(InvoiceItem(1,129,125,10.35,1), InvoiceItem(2,129,67,10.35,1), InvoiceItem(3,129,49,10.35,1), InvoiceItem(4,129,128,10.35,1)))
// Invoice(130,List(InvoiceItem(1,130,30,10.35,1), InvoiceItem(2,130,155,10.35,1), InvoiceItem(3,130,166,10.35,1)))
// Invoice(131,List(InvoiceItem(1,131,96,10.35,1), InvoiceItem(2,131,98,10.35,1), InvoiceItem(3,131,31,10.35,1), InvoiceItem(4,131,158,10.35,1), InvoiceItem(5,131,182,10.35,1)))
// Invoice(132,List(InvoiceItem(1,132,106,10.35,1), InvoiceItem(2,132,18,10.35,1), InvoiceItem(3,132,56,10.35,1), InvoiceItem(4,132,35,10.35,1), InvoiceItem(5,132,163,10.35,1)))
// Invoice(133,List(InvoiceItem(1,133,19,10.35,1)))
// Invoice(134,List(InvoiceItem(1,134,98,10.35,1), InvoiceItem(2,134,122,10.35,1)))
// Invoice(135,List(InvoiceItem(1,135,47,10.35,1), InvoiceItem(2,135,44,10.35,1), InvoiceItem(3,135,148,10.35,1)))
// Invoice(136,List(InvoiceItem(1,136,129,10.35,1), InvoiceItem(2,136,115,10.35,1)))
// Invoice(137,List(InvoiceItem(1,137,173,10.35,1), InvoiceItem(2,137,9,10.35,1), InvoiceItem(3,137,61,10.35,1), InvoiceItem(4,137,198,10.35,1)))
// Invoice(138,List(InvoiceItem(1,138,126,10.35,1), InvoiceItem(2,138,22,10.35,1), InvoiceItem(3,138,198,10.35,1), InvoiceItem(4,138,25,10.35,1), InvoiceItem(5,138,16,10.35,1)))
// Invoice(139,List(InvoiceItem(1,139,92,10.35,1), InvoiceItem(2,139,138,10.35,1), InvoiceItem(3,139,198,10.35,1), InvoiceItem(4,139,172,10.35,1), InvoiceItem(5,139,34,10.35,1)))
// Invoice(140,List(InvoiceItem(1,140,172,10.35,1)))
// Invoice(141,List(InvoiceItem(1,141,149,10.35,1), InvoiceItem(2,141,145,10.35,1)))
// Invoice(142,List(InvoiceItem(1,142,114,10.35,1)))
// Invoice(143,List(InvoiceItem(1,143,164,10.35,1), InvoiceItem(2,143,182,10.35,1), InvoiceItem(3,143,140,10.35,1), InvoiceItem(4,143,113,10.35,1)))
// Invoice(144,List(InvoiceItem(1,144,131,10.35,1)))
// Invoice(145,List(InvoiceItem(1,145,181,10.35,1), InvoiceItem(2,145,149,10.35,1), InvoiceItem(3,145,60,10.35,1), InvoiceItem(4,145,138,10.35,1), InvoiceItem(5,145,76,10.35,1)))
// Invoice(146,List(InvoiceItem(1,146,120,10.35,1), InvoiceItem(2,146,58,10.35,1), InvoiceItem(3,146,161,10.35,1), InvoiceItem(4,146,94,10.35,1), InvoiceItem(5,146,74,10.35,1)))
// Invoice(147,List(InvoiceItem(1,147,34,10.35,1), InvoiceItem(2,147,96,10.35,1)))
// Invoice(148,List(InvoiceItem(1,148,143,10.35,1), InvoiceItem(2,148,106,10.35,1)))
// Invoice(149,List(InvoiceItem(1,149,9,10.35,1), InvoiceItem(2,149,114,10.35,1), InvoiceItem(3,149,41,10.35,1), InvoiceItem(4,149,118,10.35,1)))
// Invoice(150,List(InvoiceItem(1,150,190,10.35,1), InvoiceItem(2,150,129,10.35,1), InvoiceItem(3,150,42,10.35,1), InvoiceItem(4,150,195,10.35,1), InvoiceItem(5,150,11,10.35,1)))
// Invoice(151,List(InvoiceItem(1,151,105,10.35,1), InvoiceItem(2,151,14,10.35,1), InvoiceItem(3,151,190,10.35,1), InvoiceItem(4,151,47,10.35,1)))
// Invoice(152,List(InvoiceItem(1,152,20,10.35,1)))
// Invoice(153,List(InvoiceItem(1,153,46,10.35,1)))
// Invoice(154,List(InvoiceItem(1,154,45,10.35,1), InvoiceItem(2,154,13,10.35,1), InvoiceItem(3,154,103,10.35,1), InvoiceItem(4,154,130,10.35,1)))
// Invoice(155,List(InvoiceItem(1,155,127,10.35,1), InvoiceItem(2,155,164,10.35,1), InvoiceItem(3,155,99,10.35,1), InvoiceItem(4,155,22,10.35,1), InvoiceItem(5,155,126,10.35,1)))
// Invoice(156,List(InvoiceItem(1,156,168,10.35,1)))
// Invoice(157,List(InvoiceItem(1,157,77,10.35,1), InvoiceItem(2,157,178,10.35,1)))
// Invoice(158,List(InvoiceItem(1,158,187,10.35,1), InvoiceItem(2,158,20,10.35,1), InvoiceItem(3,158,176,10.35,1), InvoiceItem(4,158,129,10.35,1)))
// Invoice(159,List(InvoiceItem(1,159,151,10.35,1)))
// Invoice(160,List(InvoiceItem(1,160,7,10.35,1)))
// Invoice(161,List(InvoiceItem(1,161,190,10.35,1), InvoiceItem(2,161,33,10.35,1), InvoiceItem(3,161,152,10.35,1), InvoiceItem(4,161,31,10.35,1)))
// Invoice(162,List(InvoiceItem(1,162,176,10.35,1), InvoiceItem(2,162,61,10.35,1), InvoiceItem(3,162,112,10.35,1)))
// Invoice(163,List(InvoiceItem(1,163,62,10.35,1), InvoiceItem(2,163,42,10.35,1), InvoiceItem(3,163,102,10.35,1), InvoiceItem(4,163,200,10.35,1), InvoiceItem(5,163,103,10.35,1)))
// Invoice(164,List(InvoiceItem(1,164,12,10.35,1), InvoiceItem(2,164,141,10.35,1), InvoiceItem(3,164,30,10.35,1), InvoiceItem(4,164,100,10.35,1)))
// Invoice(165,List(InvoiceItem(1,165,28,10.35,1), InvoiceItem(2,165,109,10.35,1), InvoiceItem(3,165,94,10.35,1), InvoiceItem(4,165,179,10.35,1), InvoiceItem(5,165,80,10.35,1)))
// Invoice(166,List(InvoiceItem(1,166,70,10.35,1), InvoiceItem(2,166,84,10.35,1), InvoiceItem(3,166,98,10.35,1)))
// Invoice(167,List(InvoiceItem(1,167,57,10.35,1), InvoiceItem(2,167,83,10.35,1)))
// Invoice(168,List(InvoiceItem(1,168,197,10.35,1), InvoiceItem(2,168,52,10.35,1)))
// Invoice(169,List(InvoiceItem(1,169,133,10.35,1), InvoiceItem(2,169,189,10.35,1), InvoiceItem(3,169,43,10.35,1), InvoiceItem(4,169,6,10.35,1), InvoiceItem(5,169,113,10.35,1)))
// Invoice(170,List(InvoiceItem(1,170,97,10.35,1), InvoiceItem(2,170,114,10.35,1)))
// Invoice(171,List(InvoiceItem(1,171,7,10.35,1), InvoiceItem(2,171,76,10.35,1), InvoiceItem(3,171,189,10.35,1), InvoiceItem(4,171,176,10.35,1)))
// Invoice(172,List(InvoiceItem(1,172,108,10.35,1), InvoiceItem(2,172,161,10.35,1), InvoiceItem(3,172,9,10.35,1), InvoiceItem(4,172,141,10.35,1), InvoiceItem(5,172,56,10.35,1)))
// Invoice(173,List(InvoiceItem(1,173,36,10.35,1), InvoiceItem(2,173,23,10.35,1), InvoiceItem(3,173,164,10.35,1)))
// Invoice(174,List(InvoiceItem(1,174,48,10.35,1), InvoiceItem(2,174,199,10.35,1)))
// Invoice(175,List(InvoiceItem(1,175,91,10.35,1), InvoiceItem(2,175,74,10.35,1)))
// Invoice(176,List(InvoiceItem(1,176,173,10.35,1), InvoiceItem(2,176,75,10.35,1), InvoiceItem(3,176,197,10.35,1)))
// Invoice(177,List(InvoiceItem(1,177,78,10.35,1)))
// Invoice(178,List(InvoiceItem(1,178,25,10.35,1)))
// Invoice(179,List(InvoiceItem(1,179,99,10.35,1), InvoiceItem(2,179,64,10.35,1), InvoiceItem(3,179,2,10.35,1), InvoiceItem(4,179,199,10.35,1), InvoiceItem(5,179,57,10.35,1)))
// Invoice(180,List(InvoiceItem(1,180,108,10.35,1)))
// Invoice(181,List(InvoiceItem(1,181,84,10.35,1), InvoiceItem(2,181,47,10.35,1)))
// Invoice(182,List(InvoiceItem(1,182,95,10.35,1)))
// Invoice(183,List(InvoiceItem(1,183,14,10.35,1), InvoiceItem(2,183,6,10.35,1)))
// Invoice(184,List(InvoiceItem(1,184,16,10.35,1), InvoiceItem(2,184,146,10.35,1), InvoiceItem(3,184,47,10.35,1)))
// Invoice(185,List(InvoiceItem(1,185,65,10.35,1), InvoiceItem(2,185,126,10.35,1), InvoiceItem(3,185,109,10.35,1)))
// Invoice(186,List(InvoiceItem(1,186,18,10.35,1)))
// Invoice(187,List(InvoiceItem(1,187,169,10.35,1), InvoiceItem(2,187,49,10.35,1), InvoiceItem(3,187,106,10.35,1), InvoiceItem(4,187,195,10.35,1), InvoiceItem(5,187,129,10.35,1)))
// Invoice(188,List(InvoiceItem(1,188,109,10.35,1), InvoiceItem(2,188,94,10.35,1), InvoiceItem(3,188,164,10.35,1), InvoiceItem(4,188,115,10.35,1), InvoiceItem(5,188,109,10.35,1)))
// Invoice(189,List(InvoiceItem(1,189,179,10.35,1), InvoiceItem(2,189,32,10.35,1), InvoiceItem(3,189,81,10.35,1)))
// Invoice(190,List(InvoiceItem(1,190,78,10.35,1), InvoiceItem(2,190,22,10.35,1), InvoiceItem(3,190,140,10.35,1), InvoiceItem(4,190,65,10.35,1)))
// Invoice(191,List(InvoiceItem(1,191,126,10.35,1)))
// Invoice(192,List(InvoiceItem(1,192,53,10.35,1), InvoiceItem(2,192,9,10.35,1)))
// Invoice(193,List(InvoiceItem(1,193,167,10.35,1)))
// Invoice(194,List(InvoiceItem(1,194,118,10.35,1), InvoiceItem(2,194,13,10.35,1), InvoiceItem(3,194,36,10.35,1), InvoiceItem(4,194,65,10.35,1), InvoiceItem(5,194,22,10.35,1)))
// Invoice(195,List(InvoiceItem(1,195,35,10.35,1), InvoiceItem(2,195,113,10.35,1), InvoiceItem(3,195,107,10.35,1)))
// Invoice(196,List(InvoiceItem(1,196,146,10.35,1), InvoiceItem(2,196,71,10.35,1)))
// Invoice(197,List(InvoiceItem(1,197,97,10.35,1)))
// Invoice(198,List(InvoiceItem(1,198,168,10.35,1), InvoiceItem(2,198,99,10.35,1), InvoiceItem(3,198,107,10.35,1), InvoiceItem(4,198,22,10.35,1)))
// Invoice(199,List(InvoiceItem(1,199,39,10.35,1), InvoiceItem(2,199,71,10.35,1)))
// Invoice(200,List(InvoiceItem(1,200,44,10.35,1), InvoiceItem(2,200,112,10.35,1)))
// Invoice(201,List(InvoiceItem(1,201,64,10.35,1), InvoiceItem(2,201,173,10.35,1), InvoiceItem(3,201,178,10.35,1), InvoiceItem(4,201,5,10.35,1), InvoiceItem(5,201,168,10.35,1)))
// Invoice(202,List(InvoiceItem(1,202,153,10.35,1), InvoiceItem(2,202,134,10.35,1), InvoiceItem(3,202,145,10.35,1)))
// Invoice(203,List(InvoiceItem(1,203,160,10.35,1), InvoiceItem(2,203,44,10.35,1), InvoiceItem(3,203,68,10.35,1), InvoiceItem(4,203,74,10.35,1), InvoiceItem(5,203,125,10.35,1)))
// Invoice(204,List(InvoiceItem(1,204,47,10.35,1), InvoiceItem(2,204,168,10.35,1), InvoiceItem(3,204,100,10.35,1), InvoiceItem(4,204,154,10.35,1)))
// Invoice(205,List(InvoiceItem(1,205,129,10.35,1), InvoiceItem(2,205,23,10.35,1), InvoiceItem(3,205,91,10.35,1), InvoiceItem(4,205,184,10.35,1), InvoiceItem(5,205,59,10.35,1)))
// Invoice(206,List(InvoiceItem(1,206,181,10.35,1), InvoiceItem(2,206,77,10.35,1), InvoiceItem(3,206,148,10.35,1), InvoiceItem(4,206,41,10.35,1)))
// Invoice(207,List(InvoiceItem(1,207,3,10.35,1), InvoiceItem(2,207,95,10.35,1), InvoiceItem(3,207,104,10.35,1)))
// Invoice(208,List(InvoiceItem(1,208,10,10.35,1), InvoiceItem(2,208,73,10.35,1), InvoiceItem(3,208,90,10.35,1), InvoiceItem(4,208,86,10.35,1)))
// Invoice(209,List(InvoiceItem(1,209,144,10.35,1), InvoiceItem(2,209,98,10.35,1), InvoiceItem(3,209,31,10.35,1), InvoiceItem(4,209,35,10.35,1), InvoiceItem(5,209,50,10.35,1)))
// Invoice(210,List(InvoiceItem(1,210,25,10.35,1), InvoiceItem(2,210,7,10.35,1), InvoiceItem(3,210,131,10.35,1)))
// Invoice(211,List(InvoiceItem(1,211,164,10.35,1), InvoiceItem(2,211,113,10.35,1), InvoiceItem(3,211,1,10.35,1)))
// Invoice(212,List(InvoiceItem(1,212,4,10.35,1), InvoiceItem(2,212,10,10.35,1)))
// Invoice(213,List(InvoiceItem(1,213,113,10.35,1), InvoiceItem(2,213,173,10.35,1)))
// Invoice(214,List(InvoiceItem(1,214,141,10.35,1), InvoiceItem(2,214,135,10.35,1), InvoiceItem(3,214,182,10.35,1)))
// Invoice(215,List(InvoiceItem(1,215,22,10.35,1)))
// Invoice(216,List(InvoiceItem(1,216,146,10.35,1), InvoiceItem(2,216,7,10.35,1), InvoiceItem(3,216,154,10.35,1), InvoiceItem(4,216,6,10.35,1)))
// Invoice(217,List(InvoiceItem(1,217,26,10.35,1), InvoiceItem(2,217,98,10.35,1), InvoiceItem(3,217,81,10.35,1), InvoiceItem(4,217,61,10.35,1), InvoiceItem(5,217,18,10.35,1)))
// Invoice(218,List(InvoiceItem(1,218,111,10.35,1), InvoiceItem(2,218,192,10.35,1), InvoiceItem(3,218,55,10.35,1), InvoiceItem(4,218,126,10.35,1), InvoiceItem(5,218,19,10.35,1)))
// Invoice(219,List(InvoiceItem(1,219,132,10.35,1), InvoiceItem(2,219,101,10.35,1), InvoiceItem(3,219,155,10.35,1), InvoiceItem(4,219,130,10.35,1)))
// Invoice(220,List(InvoiceItem(1,220,185,10.35,1), InvoiceItem(2,220,162,10.35,1), InvoiceItem(3,220,115,10.35,1)))
// Invoice(221,List(InvoiceItem(1,221,195,10.35,1), InvoiceItem(2,221,143,10.35,1), InvoiceItem(3,221,181,10.35,1), InvoiceItem(4,221,87,10.35,1)))
// Invoice(222,List(InvoiceItem(1,222,69,10.35,1), InvoiceItem(2,222,68,10.35,1), InvoiceItem(3,222,100,10.35,1), InvoiceItem(4,222,194,10.35,1)))
// Invoice(223,List(InvoiceItem(1,223,67,10.35,1), InvoiceItem(2,223,14,10.35,1), InvoiceItem(3,223,191,10.35,1), InvoiceItem(4,223,57,10.35,1)))
// Invoice(224,List(InvoiceItem(1,224,47,10.35,1), InvoiceItem(2,224,135,10.35,1), InvoiceItem(3,224,14,10.35,1), InvoiceItem(4,224,167,10.35,1)))
// Invoice(225,List(InvoiceItem(1,225,20,10.35,1), InvoiceItem(2,225,169,10.35,1), InvoiceItem(3,225,186,10.35,1)))
// Invoice(226,List(InvoiceItem(1,226,137,10.35,1), InvoiceItem(2,226,163,10.35,1), InvoiceItem(3,226,56,10.35,1), InvoiceItem(4,226,167,10.35,1)))
// Invoice(227,List(InvoiceItem(1,227,45,10.35,1), InvoiceItem(2,227,34,10.35,1)))
// Invoice(228,List(InvoiceItem(1,228,98,10.35,1), InvoiceItem(2,228,115,10.35,1), InvoiceItem(3,228,125,10.35,1), InvoiceItem(4,228,23,10.35,1)))
// Invoice(229,List(InvoiceItem(1,229,54,10.35,1)))
// Invoice(230,List(InvoiceItem(1,230,133,10.35,1)))
// Invoice(231,List(InvoiceItem(1,231,36,10.35,1), InvoiceItem(2,231,167,10.35,1), InvoiceItem(3,231,69,10.35,1), InvoiceItem(4,231,139,10.35,1)))
// Invoice(232,List(InvoiceItem(1,232,188,10.35,1), InvoiceItem(2,232,60,10.35,1), InvoiceItem(3,232,83,10.35,1), InvoiceItem(4,232,37,10.35,1), InvoiceItem(5,232,75,10.35,1)))
// Invoice(233,List(InvoiceItem(1,233,10,10.35,1), InvoiceItem(2,233,177,10.35,1), InvoiceItem(3,233,142,10.35,1), InvoiceItem(4,233,156,10.35,1)))
// Invoice(234,List(InvoiceItem(1,234,80,10.35,1), InvoiceItem(2,234,52,10.35,1), InvoiceItem(3,234,122,10.35,1)))
// Invoice(235,List(InvoiceItem(1,235,151,10.35,1), InvoiceItem(2,235,102,10.35,1)))
// Invoice(236,List(InvoiceItem(1,236,85,10.35,1), InvoiceItem(2,236,41,10.35,1), InvoiceItem(3,236,28,10.35,1)))
// Invoice(237,List(InvoiceItem(1,237,58,10.35,1), InvoiceItem(2,237,178,10.35,1), InvoiceItem(3,237,133,10.35,1), InvoiceItem(4,237,94,10.35,1), InvoiceItem(5,237,26,10.35,1)))
// Invoice(238,List(InvoiceItem(1,238,99,10.35,1), InvoiceItem(2,238,90,10.35,1)))
// Invoice(239,List(InvoiceItem(1,239,42,10.35,1)))
// Invoice(240,List(InvoiceItem(1,240,118,10.35,1), InvoiceItem(2,240,158,10.35,1), InvoiceItem(3,240,198,10.35,1), InvoiceItem(4,240,22,10.35,1), InvoiceItem(5,240,161,10.35,1)))
// Invoice(241,List(InvoiceItem(1,241,86,10.35,1), InvoiceItem(2,241,139,10.35,1)))
// Invoice(242,List(InvoiceItem(1,242,16,10.35,1), InvoiceItem(2,242,164,10.35,1), InvoiceItem(3,242,169,10.35,1), InvoiceItem(4,242,158,10.35,1), InvoiceItem(5,242,129,10.35,1)))
// Invoice(243,List(InvoiceItem(1,243,76,10.35,1), InvoiceItem(2,243,192,10.35,1), InvoiceItem(3,243,81,10.35,1)))
// Invoice(244,List(InvoiceItem(1,244,13,10.35,1), InvoiceItem(2,244,104,10.35,1), InvoiceItem(3,244,62,10.35,1)))
// Invoice(245,List(InvoiceItem(1,245,59,10.35,1), InvoiceItem(2,245,179,10.35,1), InvoiceItem(3,245,83,10.35,1), InvoiceItem(4,245,186,10.35,1)))
// Invoice(246,List(InvoiceItem(1,246,25,10.35,1)))
// Invoice(247,List(InvoiceItem(1,247,76,10.35,1), InvoiceItem(2,247,73,10.35,1), InvoiceItem(3,247,161,10.35,1), InvoiceItem(4,247,52,10.35,1), InvoiceItem(5,247,47,10.35,1)))
// Invoice(248,List(InvoiceItem(1,248,135,10.35,1), InvoiceItem(2,248,19,10.35,1), InvoiceItem(3,248,149,10.35,1)))
// Invoice(249,List(InvoiceItem(1,249,59,10.35,1)))
// Invoice(250,List(InvoiceItem(1,250,5,10.35,1)))
// Invoice(251,List(InvoiceItem(1,251,126,10.35,1)))
// Invoice(252,List(InvoiceItem(1,252,64,10.35,1), InvoiceItem(2,252,200,10.35,1), InvoiceItem(3,252,51,10.35,1)))
// Invoice(253,List(InvoiceItem(1,253,152,10.35,1), InvoiceItem(2,253,20,10.35,1), InvoiceItem(3,253,168,10.35,1)))
// Invoice(254,List(InvoiceItem(1,254,44,10.35,1), InvoiceItem(2,254,160,10.35,1), InvoiceItem(3,254,80,10.35,1)))
// Invoice(255,List(InvoiceItem(1,255,92,10.35,1), InvoiceItem(2,255,176,10.35,1), InvoiceItem(3,255,79,10.35,1)))
// Invoice(256,List(InvoiceItem(1,256,14,10.35,1), InvoiceItem(2,256,77,10.35,1)))
// Invoice(257,List(InvoiceItem(1,257,41,10.35,1), InvoiceItem(2,257,67,10.35,1), InvoiceItem(3,257,133,10.35,1), InvoiceItem(4,257,175,10.35,1), InvoiceItem(5,257,142,10.35,1)))
// Invoice(258,List(InvoiceItem(1,258,133,10.35,1), InvoiceItem(2,258,191,10.35,1), InvoiceItem(3,258,175,10.35,1), InvoiceItem(4,258,166,10.35,1), InvoiceItem(5,258,62,10.35,1)))
// Invoice(259,List(InvoiceItem(1,259,15,10.35,1), InvoiceItem(2,259,6,10.35,1), InvoiceItem(3,259,173,10.35,1), InvoiceItem(4,259,21,10.35,1)))
// Invoice(260,List(InvoiceItem(1,260,121,10.35,1), InvoiceItem(2,260,61,10.35,1), InvoiceItem(3,260,70,10.35,1), InvoiceItem(4,260,45,10.35,1), InvoiceItem(5,260,115,10.35,1)))
// Invoice(261,List(InvoiceItem(1,261,33,10.35,1), InvoiceItem(2,261,10,10.35,1), InvoiceItem(3,261,17,10.35,1), InvoiceItem(4,261,9,10.35,1)))
// Invoice(262,List(InvoiceItem(1,262,199,10.35,1), InvoiceItem(2,262,61,10.35,1), InvoiceItem(3,262,13,10.35,1), InvoiceItem(4,262,66,10.35,1), InvoiceItem(5,262,25,10.35,1)))
// Invoice(263,List(InvoiceItem(1,263,136,10.35,1), InvoiceItem(2,263,103,10.35,1)))
// Invoice(264,List(InvoiceItem(1,264,136,10.35,1), InvoiceItem(2,264,163,10.35,1), InvoiceItem(3,264,137,10.35,1), InvoiceItem(4,264,93,10.35,1)))
// Invoice(265,List(InvoiceItem(1,265,78,10.35,1), InvoiceItem(2,265,139,10.35,1), InvoiceItem(3,265,132,10.35,1), InvoiceItem(4,265,194,10.35,1)))
// Invoice(266,List(InvoiceItem(1,266,186,10.35,1)))
// Invoice(267,List(InvoiceItem(1,267,139,10.35,1), InvoiceItem(2,267,139,10.35,1), InvoiceItem(3,267,45,10.35,1)))
// Invoice(268,List(InvoiceItem(1,268,14,10.35,1), InvoiceItem(2,268,61,10.35,1), InvoiceItem(3,268,194,10.35,1)))
// Invoice(269,List(InvoiceItem(1,269,123,10.35,1), InvoiceItem(2,269,137,10.35,1), InvoiceItem(3,269,182,10.35,1), InvoiceItem(4,269,22,10.35,1), InvoiceItem(5,269,77,10.35,1)))
// Invoice(270,List(InvoiceItem(1,270,8,10.35,1), InvoiceItem(2,270,159,10.35,1), InvoiceItem(3,270,61,10.35,1)))
// Invoice(271,List(InvoiceItem(1,271,34,10.35,1), InvoiceItem(2,271,87,10.35,1), InvoiceItem(3,271,108,10.35,1), InvoiceItem(4,271,129,10.35,1), InvoiceItem(5,271,21,10.35,1)))
// Invoice(272,List(InvoiceItem(1,272,16,10.35,1), InvoiceItem(2,272,95,10.35,1)))
// Invoice(273,List(InvoiceItem(1,273,85,10.35,1), InvoiceItem(2,273,34,10.35,1), InvoiceItem(3,273,116,10.35,1)))
// Invoice(274,List(InvoiceItem(1,274,9,10.35,1), InvoiceItem(2,274,154,10.35,1), InvoiceItem(3,274,76,10.35,1), InvoiceItem(4,274,153,10.35,1)))
// Invoice(275,List(InvoiceItem(1,275,104,10.35,1), InvoiceItem(2,275,165,10.35,1)))
// Invoice(276,List(InvoiceItem(1,276,57,10.35,1), InvoiceItem(2,276,176,10.35,1), InvoiceItem(3,276,20,10.35,1), InvoiceItem(4,276,119,10.35,1), InvoiceItem(5,276,83,10.35,1)))
// Invoice(277,List(InvoiceItem(1,277,54,10.35,1)))
// Invoice(278,List(InvoiceItem(1,278,168,10.35,1), InvoiceItem(2,278,58,10.35,1)))
// Invoice(279,List(InvoiceItem(1,279,189,10.35,1), InvoiceItem(2,279,164,10.35,1), InvoiceItem(3,279,193,10.35,1), InvoiceItem(4,279,148,10.35,1), InvoiceItem(5,279,39,10.35,1)))
// Invoice(280,List(InvoiceItem(1,280,170,10.35,1), InvoiceItem(2,280,181,10.35,1), InvoiceItem(3,280,186,10.35,1)))
// Invoice(281,List(InvoiceItem(1,281,160,10.35,1)))
// Invoice(282,List(InvoiceItem(1,282,76,10.35,1), InvoiceItem(2,282,13,10.35,1)))
// Invoice(283,List(InvoiceItem(1,283,27,10.35,1)))
// Invoice(284,List(InvoiceItem(1,284,117,10.35,1), InvoiceItem(2,284,142,10.35,1), InvoiceItem(3,284,124,10.35,1), InvoiceItem(4,284,187,10.35,1), InvoiceItem(5,284,174,10.35,1)))
// Invoice(285,List(InvoiceItem(1,285,94,10.35,1)))
// Invoice(286,List(InvoiceItem(1,286,106,10.35,1), InvoiceItem(2,286,6,10.35,1), InvoiceItem(3,286,144,10.35,1)))
// Invoice(287,List(InvoiceItem(1,287,184,10.35,1), InvoiceItem(2,287,179,10.35,1)))
// Invoice(288,List(InvoiceItem(1,288,163,10.35,1), InvoiceItem(2,288,12,10.35,1), InvoiceItem(3,288,84,10.35,1), InvoiceItem(4,288,144,10.35,1)))
// Invoice(289,List(InvoiceItem(1,289,9,10.35,1), InvoiceItem(2,289,3,10.35,1)))
// Invoice(290,List(InvoiceItem(1,290,181,10.35,1), InvoiceItem(2,290,197,10.35,1), InvoiceItem(3,290,113,10.35,1), InvoiceItem(4,290,97,10.35,1)))
// Invoice(291,List(InvoiceItem(1,291,106,10.35,1), InvoiceItem(2,291,65,10.35,1), InvoiceItem(3,291,124,10.35,1), InvoiceItem(4,291,67,10.35,1), InvoiceItem(5,291,108,10.35,1)))
// Invoice(292,List(InvoiceItem(1,292,141,10.35,1), InvoiceItem(2,292,163,10.35,1)))
// Invoice(293,List(InvoiceItem(1,293,64,10.35,1), InvoiceItem(2,293,4,10.35,1), InvoiceItem(3,293,56,10.35,1)))
// Invoice(294,List(InvoiceItem(1,294,31,10.35,1)))
// Invoice(295,List(InvoiceItem(1,295,71,10.35,1), InvoiceItem(2,295,171,10.35,1), InvoiceItem(3,295,115,10.35,1)))
// Invoice(296,List(InvoiceItem(1,296,169,10.35,1), InvoiceItem(2,296,180,10.35,1), InvoiceItem(3,296,121,10.35,1), InvoiceItem(4,296,24,10.35,1)))
// Invoice(297,List(InvoiceItem(1,297,175,10.35,1), InvoiceItem(2,297,97,10.35,1), InvoiceItem(3,297,57,10.35,1)))
// Invoice(298,List(InvoiceItem(1,298,155,10.35,1), InvoiceItem(2,298,160,10.35,1), InvoiceItem(3,298,2,10.35,1), InvoiceItem(4,298,74,10.35,1)))
// Invoice(299,List(InvoiceItem(1,299,119,10.35,1)))
// Invoice(300,List(InvoiceItem(1,300,15,10.35,1), InvoiceItem(2,300,69,10.35,1)))
// Invoice(301,List(InvoiceItem(1,301,117,10.35,1), InvoiceItem(2,301,68,10.35,1), InvoiceItem(3,301,187,10.35,1)))
// Invoice(302,List(InvoiceItem(1,302,56,10.35,1), InvoiceItem(2,302,168,10.35,1), InvoiceItem(3,302,175,10.35,1), InvoiceItem(4,302,66,10.35,1)))
// Invoice(303,List(InvoiceItem(1,303,152,10.35,1), InvoiceItem(2,303,132,10.35,1), InvoiceItem(3,303,6,10.35,1), InvoiceItem(4,303,73,10.35,1), InvoiceItem(5,303,26,10.35,1)))
// Invoice(304,List(InvoiceItem(1,304,20,10.35,1), InvoiceItem(2,304,184,10.35,1)))
// Invoice(305,List(InvoiceItem(1,305,52,10.35,1)))
// Invoice(306,List(InvoiceItem(1,306,46,10.35,1), InvoiceItem(2,306,10,10.35,1), InvoiceItem(3,306,133,10.35,1)))
// Invoice(307,List(InvoiceItem(1,307,4,10.35,1), InvoiceItem(2,307,2,10.35,1), InvoiceItem(3,307,77,10.35,1), InvoiceItem(4,307,76,10.35,1)))
// Invoice(308,List(InvoiceItem(1,308,66,10.35,1)))
// Invoice(309,List(InvoiceItem(1,309,125,10.35,1)))
// Invoice(310,List(InvoiceItem(1,310,192,10.35,1), InvoiceItem(2,310,58,10.35,1)))
// Invoice(311,List(InvoiceItem(1,311,159,10.35,1)))
// Invoice(312,List(InvoiceItem(1,312,109,10.35,1)))
// Invoice(313,List(InvoiceItem(1,313,27,10.35,1), InvoiceItem(2,313,138,10.35,1)))
// Invoice(314,List(InvoiceItem(1,314,72,10.35,1)))
// Invoice(315,List(InvoiceItem(1,315,50,10.35,1), InvoiceItem(2,315,146,10.35,1)))
// Invoice(316,List(InvoiceItem(1,316,141,10.35,1), InvoiceItem(2,316,147,10.35,1), InvoiceItem(3,316,86,10.35,1)))
// Invoice(317,List(InvoiceItem(1,317,16,10.35,1), InvoiceItem(2,317,125,10.35,1), InvoiceItem(3,317,176,10.35,1), InvoiceItem(4,317,99,10.35,1)))
// Invoice(318,List(InvoiceItem(1,318,12,10.35,1), InvoiceItem(2,318,101,10.35,1), InvoiceItem(3,318,97,10.35,1)))
// Invoice(319,List(InvoiceItem(1,319,85,10.35,1), InvoiceItem(2,319,107,10.35,1), InvoiceItem(3,319,42,10.35,1), InvoiceItem(4,319,152,10.35,1)))
// Invoice(320,List(InvoiceItem(1,320,71,10.35,1)))
// Invoice(321,List(InvoiceItem(1,321,61,10.35,1), InvoiceItem(2,321,36,10.35,1), InvoiceItem(3,321,38,10.35,1), InvoiceItem(4,321,104,10.35,1), InvoiceItem(5,321,27,10.35,1)))
// Invoice(322,List(InvoiceItem(1,322,35,10.35,1), InvoiceItem(2,322,157,10.35,1)))
// Invoice(323,List(InvoiceItem(1,323,126,10.35,1), InvoiceItem(2,323,111,10.35,1), InvoiceItem(3,323,138,10.35,1), InvoiceItem(4,323,195,10.35,1), InvoiceItem(5,323,174,10.35,1)))
// Invoice(324,List(InvoiceItem(1,324,179,10.35,1), InvoiceItem(2,324,171,10.35,1)))
// Invoice(325,List(InvoiceItem(1,325,95,10.35,1), InvoiceItem(2,325,78,10.35,1), InvoiceItem(3,325,77,10.35,1)))
// Invoice(326,List(InvoiceItem(1,326,4,10.35,1), InvoiceItem(2,326,163,10.35,1), InvoiceItem(3,326,157,10.35,1)))
// Invoice(327,List(InvoiceItem(1,327,24,10.35,1)))
// Invoice(328,List(InvoiceItem(1,328,99,10.35,1), InvoiceItem(2,328,180,10.35,1)))
// Invoice(329,List(InvoiceItem(1,329,11,10.35,1)))
// Invoice(330,List(InvoiceItem(1,330,79,10.35,1), InvoiceItem(2,330,84,10.35,1)))
// Invoice(331,List(InvoiceItem(1,331,39,10.35,1), InvoiceItem(2,331,106,10.35,1)))
// Invoice(332,List(InvoiceItem(1,332,57,10.35,1), InvoiceItem(2,332,4,10.35,1), InvoiceItem(3,332,73,10.35,1)))
// Invoice(333,List(InvoiceItem(1,333,5,10.35,1)))
// Invoice(334,List(InvoiceItem(1,334,104,10.35,1), InvoiceItem(2,334,92,10.35,1), InvoiceItem(3,334,41,10.35,1)))
// Invoice(335,List(InvoiceItem(1,335,25,10.35,1)))
// Invoice(336,List(InvoiceItem(1,336,168,10.35,1), InvoiceItem(2,336,76,10.35,1), InvoiceItem(3,336,17,10.35,1), InvoiceItem(4,336,1,10.35,1), InvoiceItem(5,336,175,10.35,1)))
// Invoice(337,List(InvoiceItem(1,337,49,10.35,1), InvoiceItem(2,337,142,10.35,1)))
// Invoice(338,List(InvoiceItem(1,338,61,10.35,1), InvoiceItem(2,338,148,10.35,1), InvoiceItem(3,338,178,10.35,1)))
// Invoice(339,List(InvoiceItem(1,339,47,10.35,1), InvoiceItem(2,339,113,10.35,1), InvoiceItem(3,339,141,10.35,1), InvoiceItem(4,339,137,10.35,1), InvoiceItem(5,339,50,10.35,1)))
// Invoice(340,List(InvoiceItem(1,340,117,10.35,1), InvoiceItem(2,340,129,10.35,1), InvoiceItem(3,340,96,10.35,1), InvoiceItem(4,340,151,10.35,1), InvoiceItem(5,340,148,10.35,1)))
// Invoice(341,List(InvoiceItem(1,341,8,10.35,1), InvoiceItem(2,341,187,10.35,1), InvoiceItem(3,341,153,10.35,1), InvoiceItem(4,341,128,10.35,1)))
// Invoice(342,List(InvoiceItem(1,342,122,10.35,1), InvoiceItem(2,342,18,10.35,1), InvoiceItem(3,342,69,10.35,1), InvoiceItem(4,342,77,10.35,1)))
// Invoice(343,List(InvoiceItem(1,343,143,10.35,1)))
// Invoice(344,List(InvoiceItem(1,344,69,10.35,1), InvoiceItem(2,344,168,10.35,1), InvoiceItem(3,344,41,10.35,1), InvoiceItem(4,344,165,10.35,1)))
// Invoice(345,List(InvoiceItem(1,345,80,10.35,1), InvoiceItem(2,345,65,10.35,1), InvoiceItem(3,345,149,10.35,1)))
// Invoice(346,List(InvoiceItem(1,346,85,10.35,1), InvoiceItem(2,346,157,10.35,1)))
// Invoice(347,List(InvoiceItem(1,347,97,10.35,1), InvoiceItem(2,347,29,10.35,1)))
// Invoice(348,List(InvoiceItem(1,348,120,10.35,1), InvoiceItem(2,348,55,10.35,1), InvoiceItem(3,348,13,10.35,1)))
// Invoice(349,List(InvoiceItem(1,349,193,10.35,1), InvoiceItem(2,349,79,10.35,1)))
// Invoice(350,List(InvoiceItem(1,350,10,10.35,1)))
// Invoice(351,List(InvoiceItem(1,351,27,10.35,1), InvoiceItem(2,351,143,10.35,1), InvoiceItem(3,351,78,10.35,1), InvoiceItem(4,351,88,10.35,1), InvoiceItem(5,351,3,10.35,1)))
// Invoice(352,List(InvoiceItem(1,352,17,10.35,1), InvoiceItem(2,352,57,10.35,1), InvoiceItem(3,352,60,10.35,1), InvoiceItem(4,352,25,10.35,1)))
// Invoice(353,List(InvoiceItem(1,353,80,10.35,1), InvoiceItem(2,353,189,10.35,1), InvoiceItem(3,353,132,10.35,1), InvoiceItem(4,353,29,10.35,1)))
// Invoice(354,List(InvoiceItem(1,354,44,10.35,1), InvoiceItem(2,354,72,10.35,1), InvoiceItem(3,354,134,10.35,1)))
// Invoice(355,List(InvoiceItem(1,355,55,10.35,1), InvoiceItem(2,355,192,10.35,1), InvoiceItem(3,355,83,10.35,1), InvoiceItem(4,355,170,10.35,1)))
// ...
// Invoice(1862,List(InvoiceItem(1,1862,30,10.35,1), InvoiceItem(2,1862,127,10.35,1)))
// Invoice(1863,List(InvoiceItem(1,1863,74,10.35,1), InvoiceItem(2,1863,144,10.35,1), InvoiceItem(3,1863,127,10.35,1), InvoiceItem(4,1863,94,10.35,1), InvoiceItem(5,1863,167,10.35,1)))
// Invoice(1864,List(InvoiceItem(1,1864,24,10.35,1), InvoiceItem(2,1864,31,10.35,1), InvoiceItem(3,1864,196,10.35,1), InvoiceItem(4,1864,30,10.35,1), InvoiceItem(5,1864,27,10.35,1)))
// Invoice(1865,List(InvoiceItem(1,1865,101,10.35,1), InvoiceItem(2,1865,35,10.35,1), InvoiceItem(3,1865,36,10.35,1), InvoiceItem(4,1865,161,10.35,1)))
// Invoice(1866,List(InvoiceItem(1,1866,141,10.35,1), InvoiceItem(2,1866,142,10.35,1), InvoiceItem(3,1866,46,10.35,1)))
// Invoice(1867,List(InvoiceItem(1,1867,130,10.35,1), InvoiceItem(2,1867,75,10.35,1), InvoiceItem(3,1867,44,10.35,1), InvoiceItem(4,1867,110,10.35,1)))
// Invoice(1868,List(InvoiceItem(1,1868,73,10.35,1), InvoiceItem(2,1868,179,10.35,1)))
// Invoice(1869,List(InvoiceItem(1,1869,120,10.35,1), InvoiceItem(2,1869,8,10.35,1), InvoiceItem(3,1869,101,10.35,1)))
// Invoice(1870,List(InvoiceItem(1,1870,35,10.35,1), InvoiceItem(2,1870,152,10.35,1), InvoiceItem(3,1870,112,10.35,1), InvoiceItem(4,1870,138,10.35,1)))
// Invoice(1871,List(InvoiceItem(1,1871,48,10.35,1), InvoiceItem(2,1871,190,10.35,1), InvoiceItem(3,1871,167,10.35,1), InvoiceItem(4,1871,154,10.35,1)))
// Invoice(1872,List(InvoiceItem(1,1872,59,10.35,1), InvoiceItem(2,1872,26,10.35,1), InvoiceItem(3,1872,107,10.35,1), InvoiceItem(4,1872,161,10.35,1)))
// Invoice(1873,List(InvoiceItem(1,1873,145,10.35,1), InvoiceItem(2,1873,47,10.35,1), InvoiceItem(3,1873,27,10.35,1), InvoiceItem(4,1873,150,10.35,1)))
// Invoice(1874,List(InvoiceItem(1,1874,176,10.35,1)))
// Invoice(1875,List(InvoiceItem(1,1875,65,10.35,1), InvoiceItem(2,1875,136,10.35,1), InvoiceItem(3,1875,30,10.35,1), InvoiceItem(4,1875,55,10.35,1)))
// Invoice(1876,List(InvoiceItem(1,1876,84,10.35,1)))
// Invoice(1877,List(InvoiceItem(1,1877,194,10.35,1)))
// Invoice(1878,List(InvoiceItem(1,1878,57,10.35,1), InvoiceItem(2,1878,32,10.35,1)))
// Invoice(1879,List(InvoiceItem(1,1879,132,10.35,1)))
// Invoice(1880,List(InvoiceItem(1,1880,24,10.35,1), InvoiceItem(2,1880,153,10.35,1)))
// Invoice(1881,List(InvoiceItem(1,1881,122,10.35,1), InvoiceItem(2,1881,143,10.35,1)))
// Invoice(1882,List(InvoiceItem(1,1882,154,10.35,1), InvoiceItem(2,1882,12,10.35,1), InvoiceItem(3,1882,86,10.35,1), InvoiceItem(4,1882,103,10.35,1)))
// Invoice(1883,List(InvoiceItem(1,1883,61,10.35,1)))
// Invoice(1884,List(InvoiceItem(1,1884,114,10.35,1), InvoiceItem(2,1884,36,10.35,1), InvoiceItem(3,1884,168,10.35,1), InvoiceItem(4,1884,165,10.35,1)))
// Invoice(1885,List(InvoiceItem(1,1885,171,10.35,1), InvoiceItem(2,1885,60,10.35,1)))
// Invoice(1886,List(InvoiceItem(1,1886,129,10.35,1), InvoiceItem(2,1886,189,10.35,1)))
// Invoice(1887,List(InvoiceItem(1,1887,26,10.35,1), InvoiceItem(2,1887,182,10.35,1)))
// Invoice(1888,List(InvoiceItem(1,1888,6,10.35,1), InvoiceItem(2,1888,157,10.35,1)))
// Invoice(1889,List(InvoiceItem(1,1889,48,10.35,1), InvoiceItem(2,1889,54,10.35,1), InvoiceItem(3,1889,32,10.35,1)))
// Invoice(1890,List(InvoiceItem(1,1890,103,10.35,1)))
// Invoice(1891,List(InvoiceItem(1,1891,183,10.35,1)))
// Invoice(1892,List(InvoiceItem(1,1892,165,10.35,1)))
// Invoice(1893,List(InvoiceItem(1,1893,95,10.35,1), InvoiceItem(2,1893,3,10.35,1), InvoiceItem(3,1893,48,10.35,1)))
// Invoice(1894,List(InvoiceItem(1,1894,53,10.35,1), InvoiceItem(2,1894,111,10.35,1), InvoiceItem(3,1894,123,10.35,1)))
// Invoice(1895,List(InvoiceItem(1,1895,135,10.35,1), InvoiceItem(2,1895,167,10.35,1), InvoiceItem(3,1895,181,10.35,1)))
// Invoice(1896,List(InvoiceItem(1,1896,37,10.35,1), InvoiceItem(2,1896,185,10.35,1), InvoiceItem(3,1896,157,10.35,1), InvoiceItem(4,1896,65,10.35,1)))
// Invoice(1897,List(InvoiceItem(1,1897,3,10.35,1), InvoiceItem(2,1897,61,10.35,1), InvoiceItem(3,1897,122,10.35,1)))
// Invoice(1898,List(InvoiceItem(1,1898,5,10.35,1), InvoiceItem(2,1898,160,10.35,1), InvoiceItem(3,1898,159,10.35,1), InvoiceItem(4,1898,87,10.35,1), InvoiceItem(5,1898,140,10.35,1)))
// Invoice(1899,List(InvoiceItem(1,1899,135,10.35,1), InvoiceItem(2,1899,72,10.35,1), InvoiceItem(3,1899,138,10.35,1), InvoiceItem(4,1899,144,10.35,1), InvoiceItem(5,1899,28,10.35,1)))
// Invoice(1900,List(InvoiceItem(1,1900,41,10.35,1), InvoiceItem(2,1900,123,10.35,1), InvoiceItem(3,1900,150,10.35,1), InvoiceItem(4,1900,114,10.35,1)))
// Invoice(1901,List(InvoiceItem(1,1901,184,10.35,1), InvoiceItem(2,1901,178,10.35,1)))
// Invoice(1902,List(InvoiceItem(1,1902,18,10.35,1), InvoiceItem(2,1902,83,10.35,1), InvoiceItem(3,1902,50,10.35,1), InvoiceItem(4,1902,137,10.35,1)))
// Invoice(1903,List(InvoiceItem(1,1903,24,10.35,1)))
// Invoice(1904,List(InvoiceItem(1,1904,31,10.35,1), InvoiceItem(2,1904,90,10.35,1), InvoiceItem(3,1904,166,10.35,1), InvoiceItem(4,1904,25,10.35,1)))
// Invoice(1905,List(InvoiceItem(1,1905,87,10.35,1), InvoiceItem(2,1905,14,10.35,1)))
// Invoice(1906,List(InvoiceItem(1,1906,135,10.35,1), InvoiceItem(2,1906,38,10.35,1), InvoiceItem(3,1906,95,10.35,1), InvoiceItem(4,1906,33,10.35,1), InvoiceItem(5,1906,21,10.35,1)))
// Invoice(1907,List(InvoiceItem(1,1907,168,10.35,1)))
// Invoice(1908,List(InvoiceItem(1,1908,54,10.35,1), InvoiceItem(2,1908,196,10.35,1), InvoiceItem(3,1908,169,10.35,1), InvoiceItem(4,1908,68,10.35,1), InvoiceItem(5,1908,129,10.35,1)))
// Invoice(1909,List(InvoiceItem(1,1909,110,10.35,1), InvoiceItem(2,1909,100,10.35,1), InvoiceItem(3,1909,180,10.35,1), InvoiceItem(4,1909,28,10.35,1)))
// Invoice(1910,List(InvoiceItem(1,1910,28,10.35,1), InvoiceItem(2,1910,84,10.35,1)))
// Invoice(1911,List(InvoiceItem(1,1911,2,10.35,1), InvoiceItem(2,1911,183,10.35,1), InvoiceItem(3,1911,125,10.35,1), InvoiceItem(4,1911,122,10.35,1), InvoiceItem(5,1911,85,10.35,1)))
// Invoice(1912,List(InvoiceItem(1,1912,38,10.35,1), InvoiceItem(2,1912,73,10.35,1)))
// Invoice(1913,List(InvoiceItem(1,1913,106,10.35,1)))
// Invoice(1914,List(InvoiceItem(1,1914,177,10.35,1), InvoiceItem(2,1914,32,10.35,1)))
// Invoice(1915,List(InvoiceItem(1,1915,138,10.35,1)))
// Invoice(1916,List(InvoiceItem(1,1916,136,10.35,1), InvoiceItem(2,1916,125,10.35,1), InvoiceItem(3,1916,67,10.35,1), InvoiceItem(4,1916,80,10.35,1)))
// Invoice(1917,List(InvoiceItem(1,1917,82,10.35,1), InvoiceItem(2,1917,68,10.35,1), InvoiceItem(3,1917,51,10.35,1), InvoiceItem(4,1917,65,10.35,1), InvoiceItem(5,1917,34,10.35,1)))
// Invoice(1918,List(InvoiceItem(1,1918,185,10.35,1)))
// Invoice(1919,List(InvoiceItem(1,1919,103,10.35,1), InvoiceItem(2,1919,96,10.35,1), InvoiceItem(3,1919,100,10.35,1)))
// Invoice(1920,List(InvoiceItem(1,1920,21,10.35,1), InvoiceItem(2,1920,55,10.35,1), InvoiceItem(3,1920,36,10.35,1), InvoiceItem(4,1920,5,10.35,1)))
// Invoice(1921,List(InvoiceItem(1,1921,72,10.35,1), InvoiceItem(2,1921,151,10.35,1)))
// Invoice(1922,List(InvoiceItem(1,1922,44,10.35,1), InvoiceItem(2,1922,156,10.35,1), InvoiceItem(3,1922,32,10.35,1)))
// Invoice(1923,List(InvoiceItem(1,1923,9,10.35,1), InvoiceItem(2,1923,140,10.35,1)))
// Invoice(1924,List(InvoiceItem(1,1924,157,10.35,1), InvoiceItem(2,1924,112,10.35,1), InvoiceItem(3,1924,199,10.35,1), InvoiceItem(4,1924,34,10.35,1)))
// Invoice(1925,List(InvoiceItem(1,1925,6,10.35,1), InvoiceItem(2,1925,56,10.35,1), InvoiceItem(3,1925,104,10.35,1)))
// Invoice(1926,List(InvoiceItem(1,1926,34,10.35,1), InvoiceItem(2,1926,56,10.35,1), InvoiceItem(3,1926,20,10.35,1)))
// Invoice(1927,List(InvoiceItem(1,1927,184,10.35,1), InvoiceItem(2,1927,123,10.35,1), InvoiceItem(3,1927,25,10.35,1)))
// Invoice(1928,List(InvoiceItem(1,1928,6,10.35,1), InvoiceItem(2,1928,121,10.35,1), InvoiceItem(3,1928,119,10.35,1)))
// Invoice(1929,List(InvoiceItem(1,1929,38,10.35,1), InvoiceItem(2,1929,164,10.35,1), InvoiceItem(3,1929,141,10.35,1), InvoiceItem(4,1929,135,10.35,1), InvoiceItem(5,1929,2,10.35,1)))
// Invoice(1930,List(InvoiceItem(1,1930,168,10.35,1)))
// Invoice(1931,List(InvoiceItem(1,1931,22,10.35,1), InvoiceItem(2,1931,101,10.35,1), InvoiceItem(3,1931,138,10.35,1), InvoiceItem(4,1931,130,10.35,1)))
// Invoice(1932,List(InvoiceItem(1,1932,69,10.35,1), InvoiceItem(2,1932,182,10.35,1), InvoiceItem(3,1932,67,10.35,1)))
// Invoice(1933,List(InvoiceItem(1,1933,74,10.35,1), InvoiceItem(2,1933,144,10.35,1), InvoiceItem(3,1933,152,10.35,1), InvoiceItem(4,1933,95,10.35,1)))
// Invoice(1934,List(InvoiceItem(1,1934,162,10.35,1), InvoiceItem(2,1934,33,10.35,1)))
// Invoice(1935,List(InvoiceItem(1,1935,80,10.35,1), InvoiceItem(2,1935,40,10.35,1), InvoiceItem(3,1935,109,10.35,1), InvoiceItem(4,1935,13,10.35,1)))
// Invoice(1936,List(InvoiceItem(1,1936,29,10.35,1), InvoiceItem(2,1936,71,10.35,1), InvoiceItem(3,1936,160,10.35,1), InvoiceItem(4,1936,112,10.35,1)))
// Invoice(1937,List(InvoiceItem(1,1937,68,10.35,1), InvoiceItem(2,1937,95,10.35,1), InvoiceItem(3,1937,56,10.35,1)))
// Invoice(1938,List(InvoiceItem(1,1938,103,10.35,1), InvoiceItem(2,1938,48,10.35,1)))
// Invoice(1939,List(InvoiceItem(1,1939,152,10.35,1), InvoiceItem(2,1939,75,10.35,1)))
// Invoice(1940,List(InvoiceItem(1,1940,187,10.35,1)))
// Invoice(1941,List(InvoiceItem(1,1941,125,10.35,1), InvoiceItem(2,1941,3,10.35,1), InvoiceItem(3,1941,93,10.35,1)))
// Invoice(1942,List(InvoiceItem(1,1942,52,10.35,1)))
// Invoice(1943,List(InvoiceItem(1,1943,18,10.35,1)))
// Invoice(1944,List(InvoiceItem(1,1944,14,10.35,1), InvoiceItem(2,1944,132,10.35,1), InvoiceItem(3,1944,27,10.35,1), InvoiceItem(4,1944,175,10.35,1)))
// Invoice(1945,List(InvoiceItem(1,1945,198,10.35,1), InvoiceItem(2,1945,1,10.35,1), InvoiceItem(3,1945,114,10.35,1), InvoiceItem(4,1945,113,10.35,1)))
// Invoice(1946,List(InvoiceItem(1,1946,79,10.35,1)))
// Invoice(1947,List(InvoiceItem(1,1947,163,10.35,1), InvoiceItem(2,1947,8,10.35,1), InvoiceItem(3,1947,124,10.35,1)))
// Invoice(1948,List(InvoiceItem(1,1948,192,10.35,1), InvoiceItem(2,1948,1,10.35,1), InvoiceItem(3,1948,56,10.35,1)))
// Invoice(1949,List(InvoiceItem(1,1949,125,10.35,1), InvoiceItem(2,1949,51,10.35,1), InvoiceItem(3,1949,43,10.35,1), InvoiceItem(4,1949,66,10.35,1), InvoiceItem(5,1949,61,10.35,1)))
// Invoice(1950,List(InvoiceItem(1,1950,5,10.35,1)))
// Invoice(1951,List(InvoiceItem(1,1951,109,10.35,1), InvoiceItem(2,1951,65,10.35,1), InvoiceItem(3,1951,13,10.35,1)))
// Invoice(1952,List(InvoiceItem(1,1952,47,10.35,1)))
// Invoice(1953,List(InvoiceItem(1,1953,49,10.35,1), InvoiceItem(2,1953,56,10.35,1), InvoiceItem(3,1953,5,10.35,1), InvoiceItem(4,1953,5,10.35,1)))
// Invoice(1954,List(InvoiceItem(1,1954,91,10.35,1), InvoiceItem(2,1954,132,10.35,1)))
// Invoice(1955,List(InvoiceItem(1,1955,93,10.35,1), InvoiceItem(2,1955,54,10.35,1)))
// Invoice(1956,List(InvoiceItem(1,1956,16,10.35,1)))
// Invoice(1957,List(InvoiceItem(1,1957,115,10.35,1), InvoiceItem(2,1957,134,10.35,1), InvoiceItem(3,1957,198,10.35,1), InvoiceItem(4,1957,122,10.35,1), InvoiceItem(5,1957,52,10.35,1)))
// Invoice(1958,List(InvoiceItem(1,1958,143,10.35,1), InvoiceItem(2,1958,121,10.35,1), InvoiceItem(3,1958,154,10.35,1), InvoiceItem(4,1958,176,10.35,1), InvoiceItem(5,1958,187,10.35,1)))
// Invoice(1959,List(InvoiceItem(1,1959,50,10.35,1), InvoiceItem(2,1959,31,10.35,1), InvoiceItem(3,1959,157,10.35,1)))
// Invoice(1960,List(InvoiceItem(1,1960,106,10.35,1), InvoiceItem(2,1960,152,10.35,1)))
// Invoice(1961,List(InvoiceItem(1,1961,12,10.35,1)))
// Invoice(1962,List(InvoiceItem(1,1962,129,10.35,1), InvoiceItem(2,1962,119,10.35,1), InvoiceItem(3,1962,35,10.35,1), InvoiceItem(4,1962,20,10.35,1), InvoiceItem(5,1962,140,10.35,1)))
// Invoice(1963,List(InvoiceItem(1,1963,158,10.35,1), InvoiceItem(2,1963,116,10.35,1)))
// Invoice(1964,List(InvoiceItem(1,1964,83,10.35,1), InvoiceItem(2,1964,78,10.35,1), InvoiceItem(3,1964,125,10.35,1), InvoiceItem(4,1964,167,10.35,1)))
// Invoice(1965,List(InvoiceItem(1,1965,188,10.35,1), InvoiceItem(2,1965,82,10.35,1), InvoiceItem(3,1965,178,10.35,1), InvoiceItem(4,1965,15,10.35,1)))
// Invoice(1966,List(InvoiceItem(1,1966,84,10.35,1), InvoiceItem(2,1966,162,10.35,1), InvoiceItem(3,1966,26,10.35,1), InvoiceItem(4,1966,108,10.35,1), InvoiceItem(5,1966,90,10.35,1)))
// Invoice(1967,List(InvoiceItem(1,1967,8,10.35,1), InvoiceItem(2,1967,17,10.35,1), InvoiceItem(3,1967,97,10.35,1), InvoiceItem(4,1967,45,10.35,1)))
// Invoice(1968,List(InvoiceItem(1,1968,98,10.35,1), InvoiceItem(2,1968,4,10.35,1), InvoiceItem(3,1968,144,10.35,1), InvoiceItem(4,1968,175,10.35,1)))
// Invoice(1969,List(InvoiceItem(1,1969,16,10.35,1), InvoiceItem(2,1969,85,10.35,1), InvoiceItem(3,1969,172,10.35,1), InvoiceItem(4,1969,158,10.35,1), InvoiceItem(5,1969,54,10.35,1)))
// Invoice(1970,List(InvoiceItem(1,1970,141,10.35,1), InvoiceItem(2,1970,11,10.35,1), InvoiceItem(3,1970,20,10.35,1), InvoiceItem(4,1970,197,10.35,1)))
// Invoice(1971,List(InvoiceItem(1,1971,59,10.35,1), InvoiceItem(2,1971,37,10.35,1)))
// Invoice(1972,List(InvoiceItem(1,1972,200,10.35,1), InvoiceItem(2,1972,154,10.35,1), InvoiceItem(3,1972,195,10.35,1), InvoiceItem(4,1972,63,10.35,1)))
// Invoice(1973,List(InvoiceItem(1,1973,75,10.35,1), InvoiceItem(2,1973,63,10.35,1)))
// Invoice(1974,List(InvoiceItem(1,1974,115,10.35,1), InvoiceItem(2,1974,163,10.35,1), InvoiceItem(3,1974,24,10.35,1), InvoiceItem(4,1974,194,10.35,1)))
// Invoice(1975,List(InvoiceItem(1,1975,158,10.35,1), InvoiceItem(2,1975,7,10.35,1)))
// Invoice(1976,List(InvoiceItem(1,1976,74,10.35,1), InvoiceItem(2,1976,72,10.35,1), InvoiceItem(3,1976,171,10.35,1)))
// Invoice(1977,List(InvoiceItem(1,1977,160,10.35,1), InvoiceItem(2,1977,18,10.35,1), InvoiceItem(3,1977,64,10.35,1), InvoiceItem(4,1977,117,10.35,1), InvoiceItem(5,1977,122,10.35,1)))
// Invoice(1978,List(InvoiceItem(1,1978,115,10.35,1), InvoiceItem(2,1978,101,10.35,1)))
// Invoice(1979,List(InvoiceItem(1,1979,105,10.35,1), InvoiceItem(2,1979,152,10.35,1), InvoiceItem(3,1979,56,10.35,1)))
// Invoice(1980,List(InvoiceItem(1,1980,53,10.35,1)))
// Invoice(1981,List(InvoiceItem(1,1981,27,10.35,1)))
// Invoice(1982,List(InvoiceItem(1,1982,176,10.35,1), InvoiceItem(2,1982,143,10.35,1), InvoiceItem(3,1982,15,10.35,1), InvoiceItem(4,1982,148,10.35,1), InvoiceItem(5,1982,84,10.35,1)))
// Invoice(1983,List(InvoiceItem(1,1983,194,10.35,1), InvoiceItem(2,1983,98,10.35,1), InvoiceItem(3,1983,76,10.35,1), InvoiceItem(4,1983,45,10.35,1)))
// Invoice(1984,List(InvoiceItem(1,1984,42,10.35,1), InvoiceItem(2,1984,87,10.35,1), InvoiceItem(3,1984,130,10.35,1)))
// Invoice(1985,List(InvoiceItem(1,1985,55,10.35,1), InvoiceItem(2,1985,116,10.35,1), InvoiceItem(3,1985,70,10.35,1)))
// Invoice(1986,List(InvoiceItem(1,1986,55,10.35,1)))
// Invoice(1987,List(InvoiceItem(1,1987,182,10.35,1), InvoiceItem(2,1987,75,10.35,1)))
// Invoice(1988,List(InvoiceItem(1,1988,60,10.35,1), InvoiceItem(2,1988,153,10.35,1), InvoiceItem(3,1988,72,10.35,1), InvoiceItem(4,1988,18,10.35,1)))
// Invoice(1989,List(InvoiceItem(1,1989,187,10.35,1), InvoiceItem(2,1989,34,10.35,1), InvoiceItem(3,1989,13,10.35,1), InvoiceItem(4,1989,165,10.35,1)))
// Invoice(1990,List(InvoiceItem(1,1990,199,10.35,1), InvoiceItem(2,1990,94,10.35,1), InvoiceItem(3,1990,177,10.35,1), InvoiceItem(4,1990,184,10.35,1), InvoiceItem(5,1990,59,10.35,1)))
// Invoice(1991,List(InvoiceItem(1,1991,120,10.35,1), InvoiceItem(2,1991,74,10.35,1), InvoiceItem(3,1991,57,10.35,1), InvoiceItem(4,1991,53,10.35,1), InvoiceItem(5,1991,39,10.35,1)))
// Invoice(1992,List(InvoiceItem(1,1992,94,10.35,1), InvoiceItem(2,1992,196,10.35,1), InvoiceItem(3,1992,2,10.35,1)))
// Invoice(1993,List(InvoiceItem(1,1993,170,10.35,1), InvoiceItem(2,1993,159,10.35,1)))
// Invoice(1994,List(InvoiceItem(1,1994,178,10.35,1)))
// Invoice(1995,List(InvoiceItem(1,1995,147,10.35,1), InvoiceItem(2,1995,22,10.35,1), InvoiceItem(3,1995,187,10.35,1), InvoiceItem(4,1995,16,10.35,1), InvoiceItem(5,1995,12,10.35,1)))
// Invoice(1996,List(InvoiceItem(1,1996,162,10.35,1), InvoiceItem(2,1996,80,10.35,1), InvoiceItem(3,1996,47,10.35,1), InvoiceItem(4,1996,80,10.35,1)))
// Invoice(1997,List(InvoiceItem(1,1997,53,10.35,1), InvoiceItem(2,1997,157,10.35,1)))
// Invoice(1998,List(InvoiceItem(1,1998,74,10.35,1), InvoiceItem(2,1998,136,10.35,1), InvoiceItem(3,1998,59,10.35,1), InvoiceItem(4,1998,6,10.35,1)))
// Invoice(1999,List(InvoiceItem(1,1999,121,10.35,1), InvoiceItem(2,1999,6,10.35,1), InvoiceItem(3,1999,12,10.35,1)))
// Invoice(2000,List(InvoiceItem(1,2000,130,10.35,1), InvoiceItem(2,2000,125,10.35,1), InvoiceItem(3,2000,111,10.35,1)))

// %% [markdown]
// # Atelier 3

// %% [markdown]
// ### Etape 1 Filtrage

// %%
val medias: List[MediaType] = List(mediaTypes(1), mediaTypes(2))
val mediasId: List[Int] = medias.map(_.id)

val filteredTrackList: List[Track] = trackList.filter(track => mediasId.contains(track.mediaTypeId))
// Out:
// medias = List(MediaType(2,Protected AAC audio file), MediaType(3,Protected MPEG-4 video file))
// mediasId = List(2, 3)
// filteredTrackList = List(Track(2,Electric Giants from the Sky,6,3), Track(3,Urban Wolves from Hell,3,3), Track(7,Neon Echo in Exile,6,3), Track(8,Neon Demons of the Night,6,3), Track(10,Lost Outlaws of Destruction,4,2), Track(11,Raging Echo from Beyond,16,2), Track(12,Midnight Rebels of Tomorrow,11,2), Track(13,Sonic Void of the North,25,3), Track(16,Raging Wizards in Exile,19,3), Track(17,Stellar Angels from the East,20,3), Track(22,Infinite Echo of the North,15,2), Track(23,Silent Warriors from the Desert,20,3), Track(24,Velvet Machines in Disguise,9,3), Track(28,Electric Shadows in Disguise,23,2), Track(33,Midnight Void of the N...
// List(Track(2,Electric Giants from the Sky,6,3), Track(3,Urban Wolves from Hell,3,3), Track(7,Neon Echo in Exile,6,3), Track(8,Neon Demons of the Night,6,3), Track(10,Lost Outlaws of Destruction,4,2), Track(11,Raging Echo from Beyond,16,2), Track(12,Midnight Rebels of Tomorrow,11,2), Track(13,Sonic Void of the North,25,3), Track(16,Raging Wizards in Exile,19,3), Track(17,Stellar Angels from the East,20,3), Track(22,Infinite Echo of the North,15,2), Track(23,Silent Warriors from the Desert,20,3), Track(24,Velvet Machines in Disguise,9,3), Track(28,Electric Shadows in Disguise,23,2), Track(33,Midnight Void of the N...

// %%
val invoiceListGenre1: List[Invoice] = invoiceList.filter { invoice =>
  val trackIds = invoice.invoiceListItem.map(_.trackId)
  val tracksInInvoice = trackIds.flatMap(id => trackList.find(_.id == id))
  
  val genre1Count = tracksInInvoice.count(_.genreId == 1)
  val total = tracksInInvoice.size

  total > 0 && genre1Count > total / 2
}
// Out:
// invoiceListGenre1 = List(Invoice(140,List(InvoiceItem(1,140,172,10.35,1))), Invoice(250,List(InvoiceItem(1,250,5,10.35,1))), Invoice(333,List(InvoiceItem(1,333,5,10.35,1))), Invoice(564,List(InvoiceItem(1,564,127,10.35,1))), Invoice(606,List(InvoiceItem(1,606,172,10.35,1))), Invoice(847,List(InvoiceItem(1,847,127,10.35,1))), Invoice(1065,List(InvoiceItem(1,1065,5,10.35,1))), Invoice(1211,List(InvoiceItem(1,1211,127,10.35,1))), Invoice(1313,List(InvoiceItem(1,1313,172,10.35,1))), Invoice(1345,List(InvoiceItem(1,1345,42,10.35,1), InvoiceItem(2,1345,180,10.35,1), InvoiceItem(3,1345,120,10.35,1))), Invoice(1450,List(InvoiceItem(1,1450,180,10.35,1))), Invoice(1516,List(InvoiceItem(1,1516,180,10.35,1))), Invoice(1584,List(InvoiceItem(1,1584,5,10.35,1))), Invoice(1950,List(Invoi...
// List(Invoice(140,List(InvoiceItem(1,140,172,10.35,1))), Invoice(250,List(InvoiceItem(1,250,5,10.35,1))), Invoice(333,List(InvoiceItem(1,333,5,10.35,1))), Invoice(564,List(InvoiceItem(1,564,127,10.35,1))), Invoice(606,List(InvoiceItem(1,606,172,10.35,1))), Invoice(847,List(InvoiceItem(1,847,127,10.35,1))), Invoice(1065,List(InvoiceItem(1,1065,5,10.35,1))), Invoice(1211,List(InvoiceItem(1,1211,127,10.35,1))), Invoice(1313,List(InvoiceItem(1,1313,172,10.35,1))), Invoice(1345,List(InvoiceItem(1,1345,42,10.35,1), InvoiceItem(2,1345,180,10.35,1), InvoiceItem(3,1345,120,10.35,1))), Invoice(1450,List(InvoiceItem(1,1450,180,10.35,1))), Invoice(1516,List(InvoiceItem(1,1516,180,10.35,1))), Invoice(1584,List(InvoiceItem(1,1584,5,10.35,1))), Invoice(1950,List(Invoi...

// %% [markdown]
// ### Etape 2 - Agrégation

// %%
val allTrackIds: List[Int] = invoiceList.flatMap(_.invoiceListItem.map(_.trackId))
val trackIdToCount: Map[Int, Int] = allTrackIds.groupBy(id => id).map {
  case (trackId, list) => (trackId, list.size)
}
val sortedTrackIds: List[(Int, Int)] = trackIdToCount.toList.sortBy { case (_, count) => -count }
val top5TrackIds: List[Int] = sortedTrackIds.take(5).map { case (trackId, _) => trackId }
val top5Tracks: List[Track] = top5TrackIds.flatMap(id => trackList.find(_.id == id))

val top5Titles: List[String] = top5Tracks.map(_.name)
top5Titles.foreach(println)
// Out:
// allTrackIds = List(164, 20, 159, 176, 104, 127, 18, 109, 176, 94, 57, 167, 58, 177, 59, 85, 40, 64, 101, 152, 6, 40, 54, 185, 24, 88, 120, 179, 152, 105, 9, 68, 26, 32, 49, 147, 60, 156, 143, 92, 126, 147, 27, 152, 69, 139, 54, 62, 53, 12, 135, 42, 72, 48, 158, 187, 9, 62, 157, 35, 144, 12, 15, 173, 48, 175, 6, 121, 101, 69, 130, 100, 166, 81, 149, 186, 5, 95, 3, 70, 194, 12, 61, 28, 4, 2, 48, 158, 102, 1, 185, 124, 143, 25, 20, 103, 21, 42, 170, 101, 51, 6, 105, 44, 187, 192, 132, 25, 65, 75, 76, 86, 135, 160, 4, 115, 16, 36, 55, 46, 127, 80, 59, 58, 23, 105, 135, 116, 105, 188, 36, 55, 71, 169, 31, 177, 171, 196, 143, 138, 117, 121, 199, 19, 166, 163, 152, 124, 180, 121, 48, 61, 158, 17, 105, 52, 108, 115, 60, 80, 123, 127, 160, 132, 108, 101, 73, 161, 10, 16, 120, 30, 30, ...
// Primal Shadows of the Night
// Wild Empire of Death
// Royal Killers from the Desert
// Stellar Void of Tomorrow
// Arctic Void of Destruction
// List(164, 20, 159, 176, 104, 127, 18, 109, 176, 94, 57, 167, 58, 177, 59, 85, 40, 64, 101, 152, 6, 40, 54, 185, 24, 88, 120, 179, 152, 105, 9, 68, 26, 32, 49, 147, 60, 156, 143, 92, 126, 147, 27, 152, 69, 139, 54, 62, 53, 12, 135, 42, 72, 48, 158, 187, 9, 62, 157, 35, 144, 12, 15, 173, 48, 175, 6, 121, 101, 69, 130, 100, 166, 81, 149, 186, 5, 95, 3, 70, 194, 12, 61, 28, 4, 2, 48, 158, 102, 1, 185, 124, 143, 25, 20, 103, 21, 42, 170, 101, 51, 6, 105, 44, 187, 192, 132, 25, 65, 75, 76, 86, 135, 160, 4, 115, 16, 36, 55, 46, 127, 80, 59, 58, 23, 105, 135, 116, 105, 188, 36, 55, 71, 169, 31, 177, 171, 196, 143, 138, 117, 121, 199, 19, 166, 163, 152, 124, 180, 121, 48, 61, 158, 17, 105, 52, 108, 115, 60, 80, 123, 127, 160, 132, 108, 101, 73, 161, 10, 16, 120, 30, 30, ...

// %%
val genreIdToInvoiceCount: Map[Int, Int] = invoiceList.flatMap { invoice =>
    val genreIds = invoice.invoiceListItem
      .flatMap(item => trackList.find(_.id == item.trackId).map(_.genreId))
      .distinct

    genreIds.map(genreId => (genreId, 1))
  }
  .groupBy(_._1)
  .mapValues(_.map(_._2).sum)
  .toMap
// Out:
// genreIdToInvoiceCount = Map(5 -> 246, 10 -> 245, 24 -> 177, 25 -> 225, 14 -> 196, 20 -> 220, 1 -> 148, 6 -> 195, 21 -> 151, 9 -> 323, 13 -> 150, 2 -> 143, 17 -> 346, 22 -> 233, 12 -> 175, 7 -> 189, 3 -> 253, 18 -> 191, 16 -> 231, 11 -> 237, 23 -> 284, 8 -> 320, 19 -> 184, 4 -> 270, 15 -> 315)
// Map(5 -> 246, 10 -> 245, 24 -> 177, 25 -> 225, 14 -> 196, 20 -> 220, 1 -> 148, 6 -> 195, 21 -> 151, 9 -> 323, 13 -> 150, 2 -> 143, 17 -> 346, 22 -> 233, 12 -> 175, 7 -> 189, 3 -> 253, 18 -> 191, 16 -> 231, 11 -> 237, 23 -> 284, 8 -> 320, 19 -> 184, 4 -> 270, 15 -> 315)

// %% [markdown]
// ### Etape 3 - Traitement récursif

// %%
def findTopManager(emp: Employee, employeeMap: Map[Int, Employee]): Employee = {
    if (emp.reportsTo == 0 || !employeeMap.contains(emp.reportsTo)) emp
    else findTopManager(employeeMap(emp.reportsTo), employeeMap)
}

val employeeMap: Map[Int, Employee] = employees.map(e => e.id -> e).toMap

val employee = employeeMap(6)
val topManager = findTopManager(employee, employeeMap)

println(s"Le plus haut responsable de ${employee.firstName} ${employee.lastName} est ${topManager.firstName} ${topManager.lastName} (${topManager.title})")
// Out:
// employeeMap = Map(5 -> Employee(5,Johnson,Steve,Sales Support Agent,2), 1 -> Employee(1,Adams,Andrew,General Manager,0), 6 -> Employee(6,Mitchell,Michael,IT Manager,1), 2 -> Employee(2,Edwards,Nancy,Sales Manager,1), 7 -> Employee(7,King,Robert,IT Staff,6), 3 -> Employee(3,Peacock,Jane,Sales Support Agent,2), 8 -> Employee(8,Callahan,Laura,IT Staff,6), 4 -> Employee(4,Park,Margaret,Sales Support Agent,2))
// employee = Employee(6,Mitchell,Michael,IT Manager,1)
// topManager = Employee(1,Adams,Andrew,General Manager,0)
// findTopManager: (emp: Employee, employeeMap: Map[Int,Employee])Employee
// Le plus haut responsable de Michael Mitchell est Andrew Adams (General Manager)
// Employee(1,Adams,Andrew,General Manager,0)

// %% [markdown]
// # Atelier 4 - Transposition sur Spark

// %%
import org.apache.spark.SparkContext
import org.apache.spark.SparkConf

// %% [markdown]
// ### Etape 1 - Manipulation des données générées

// %%
// val pTracks = sc.parallelize(trackList)
// val pInvoices = sc.parallelize(invoiceList)

val invoiceItemsCSV = sc.textFile("./datas/InvoiceItem.csv")
  .map(_.split(";"))
  .map(cols => InvoiceItem(
    cols(0).toInt,
    cols(1).toInt,
    cols(2).toInt,
    cols(3).toDouble,
    cols(4).toInt
))

val pTracks = sc.textFile("./datas/Track.csv")
  .map(_.split(";"))
  .map(cols => new Track(
    cols(0).toInt,
    cols(1).toString,
    cols(2).toInt,
    cols(3).toInt
))

val pInvoices = invoiceItemsCSV.groupBy(_.invoiceId).map { case (invoiceId, items) =>
    new Invoice(invoiceId, items.toList)               
}
// Out:
// invoiceItemsCSV = MapPartitionsRDD[227] at map at <console>:50
// pTracks = MapPartitionsRDD[231] at map at <console>:60
// pInvoices = MapPartitionsRDD[234] at map at <console>:67
// MapPartitionsRDD[234] at map at <console>:67

// %% [markdown]
// #### Filtre par medias (liste)

// %%
val pMedias: List[MediaType] = List(mediaTypes(1), mediaTypes(2))
val pMediasId: List[Int] = pMedias.map(_.id)

val filteredTrackList = pTracks.filter(track => pMediasId.contains(track.mediaTypeId)).collect()
// Out:
// pMedias = List(MediaType(2,Protected AAC audio file), MediaType(3,Protected MPEG-4 video file))
// pMediasId = List(2, 3)
// filteredTrackList = Array(Track(63,Desafinado,1,2), Track(64,Garota De Ipanema,1,2), Track(65,Samba De Uma Nota Só (One Note Samba),1,2), Track(66,Por Causa De Você,1,2), Track(67,Ligia,1,2), Track(68,Fotografia,1,2), Track(69,Dindi (Dindi),1,2), Track(70,Se Todos Fossem Iguais A Você (Instrumental),1,2), Track(71,Falando De Amor,1,2), Track(72,Angela,1,2), Track(73,Corcovado (Quiet Nights Of Quiet Stars),1,2), Track(74,Outra Vez,1,2), Track(75,O Boto (Bôto),1,2), Track(76,Canta, Canta Mais,1,2), Track(77,Enter Sandman,1,3), Track(78,Master Of Puppets,1,3), Track(79,Harvester Of Sorrow,1,3), Track(80,The Unforgiven,1,3), Track(8...
// Array(Track(63,Desafinado,1,2), Track(64,Garota De Ipanema,1,2), Track(65,Samba De Uma Nota Só (One Note Samba),1,2), Track(66,Por Causa De Você,1,2), Track(67,Ligia,1,2), Track(68,Fotografia,1,2), Track(69,Dindi (Dindi),1,2), Track(70,Se Todos Fossem Iguais A Você (Instrumental),1,2), Track(71,Falando De Amor,1,2), Track(72,Angela,1,2), Track(73,Corcovado (Quiet Nights Of Quiet Stars),1,2), Track(74,Outra Vez,1,2), Track(75,O Boto (Bôto),1,2), Track(76,Canta, Canta Mais,1,2), Track(77,Enter Sandman,1,3), Track(78,Master Of Puppets,1,3), Track(79,Harvester Of Sorrow,1,3), Track(80,The Unforgiven,1,3), Track(8...

// %% [markdown]
// #### Top 5 Tracks filter

// %%
val pAllTrackIds = pInvoices.flatMap(_.invoiceListItem.map(_.trackId))
val pTrackIdToCount= pAllTrackIds.map(id => (id, 1)).reduceByKey(_ + _)

val top5TrackIds: Array[Int] = pTrackIdToCount
  .sortBy({ case (_, count) => -count })
  .take(5)
  .map(_._1)

val top5TrackIdsSet = top5TrackIds.toSet
val top5Tracks: Array[Track] = pTracks
  .filter(track => top5TrackIdsSet.contains(track.id))
  .collect()

val top5Titles: Array[String] = top5Tracks.map(_.name)
top5Titles.foreach(println)
// Out:
// J Squared
// Smoke On The Water
// The Garden
// Children Of The Grave
// The Fix
// pAllTrackIds = MapPartitionsRDD[236] at flatMap at <console>:47
// pTrackIdToCount = ShuffledRDD[238] at reduceByKey at <console>:48
// top5TrackIds = Array(466, 2850, 1168, 548, 2108)
// top5TrackIdsSet = Set(1168, 2108, 466, 548, 2850)
// top5Tracks = Array(Track(466,J Squared,1,2), Track(548,Smoke On The Water,1,1), Track(1168,The Garden,2,1), Track(2108,Children Of The Grave,1,3), Track(2850,The Fix,3,21))
// top5Titles = Array(J Squared, Smoke On The Water, The Garden, Children Of The Grave, The Fix)
// Array(J Squared, Smoke On The Water, The Garden, Children Of The Grave, The Fix)

// %% [markdown]
// #### Récupérer les genres les plus présent dans les commandes

// %%
val trackMap: Map[Int, Track] = pTracks.map(track => (track.id, track)).collect().toMap
val broadcastTrackMap = sc.broadcast(trackMap)

val genreInvoicePairs = pInvoices.flatMap { invoice =>
  val genreIds = invoice.invoiceListItem
    .flatMap(item => broadcastTrackMap.value.get(item.trackId).map(_.genreId))
    .distinct
  genreIds.map(genreId => (genreId, 1))
}

val genreIdToInvoiceCount: Map[Int, Int] = genreInvoicePairs
  .reduceByKey(_ + _)
  .collect()
  .toMap

genreIdToInvoiceCount.foreach { case (genreId, count) =>
  println(s"Genre ID: $genreId -> Invoice Count: $count")
}
// Out:
// Genre ID: 5 -> Invoice Count: 3
// Genre ID: 1 -> Invoice Count: 373
// Genre ID: 2 -> Invoice Count: 47
// Genre ID: 3 -> Invoice Count: 30
// Genre ID: 4 -> Invoice Count: 3
// trackMap = Map(2163 -> Track(2163,Black,1,1), 645 -> Track(645,Swedish Schnapps,1,2), 892 -> Track(892,Badge,1,6), 69 -> Track(69,Dindi (Dindi),1,2), 2199 -> Track(2199,Oceans,1,1), 3021 -> Track(3021,Like A Song...,1,1), 1322 -> Track(1322,The Trooper,1,1), 1665 -> Track(1665,Rain Song,1,1), 1036 -> Track(1036,I Get A Kick Out Of You,1,12), 2822 -> Track(2822,Exodus, Pt. 2,3,19), 2630 -> Track(2630,Edie (Ciao Baby),1,1), 1586 -> Track(1586,Thank You,1,1), 1501 -> Track(1501,Hill of the Skull,2,1), 2452 -> Track(2452,Balada Do Amor Inabalável,1,1), 809 -> Track(809,Holy Man,1,1), 1879 -> Track(1879,Escape,1,3), 1337 -> Track(1337,Flight Of The Icarus,1,3), 1718 -> Track(1718,Honolulu,1,7), 2094 -> Track(2094,I Don't Know,2,1), 1411 -> Track(1411,The Educated Fool,1,1), 6...
// Map(2163 -> Track(2163,Black,1,1), 645 -> Track(645,Swedish Schnapps,1,2), 892 -> Track(892,Badge,1,6), 69 -> Track(69,Dindi (Dindi),1,2), 2199 -> Track(2199,Oceans,1,1), 3021 -> Track(3021,Like A Song...,1,1), 1322 -> Track(1322,The Trooper,1,1), 1665 -> Track(1665,Rain Song,1,1), 1036 -> Track(1036,I Get A Kick Out Of You,1,12), 2822 -> Track(2822,Exodus, Pt. 2,3,19), 2630 -> Track(2630,Edie (Ciao Baby),1,1), 1586 -> Track(1586,Thank You,1,1), 1501 -> Track(1501,Hill of the Skull,2,1), 2452 -> Track(2452,Balada Do Amor Inabalável,1,1), 809 -> Track(809,Holy Man,1,1), 1879 -> Track(1879,Escape,1,3), 1337 -> Track(1337,Flight Of The Icarus,1,3), 1718 -> Track(1718,Honolulu,1,7), 2094 -> Track(2094,I Don't Know,2,1), 1411 -> Track(1411,The Educated Fool,1,1), 6...

// %% [markdown]
// ### Etape 2 - Analyse des transformations

// %%
val pMediasIdDebug: List[Int] = List(mediaTypes(1).id, mediaTypes(2).id)

val filteredTrackRDD = pTracks.filter(track => pMediasIdDebug.contains(track.mediaTypeId))
println(filteredTrackRDD.toDebugString)
// Out:
// pMediasIdDebug = List(2, 3)
// filteredTrackRDD = MapPartitionsRDD[248] at filter at <console>:43
// (2) MapPartitionsRDD[248] at filter at <console>:43 []
//  |  MapPartitionsRDD[231] at map at <console>:60 []
//  |  MapPartitionsRDD[230] at map at <console>:59 []
//  |  ./datas/Track.csv MapPartitionsRDD[229] at textFile at <console>:58 []
//  |  ./datas/Track.csv HadoopRDD[228] at textFile at <console>:58 []
// MapPartitionsRDD[248] at filter at <console>:43

// %% [markdown]
// - Pas de shuffle pour cette opération

// %%
val pAllTrackIdsDebug = pInvoices.flatMap(_.invoiceListItem.map(_.trackId))
val pTrackIdToCountDebug = pAllTrackIdsDebug.map(id => (id, 1)).reduceByKey(_ + _)

println(pTrackIdToCountDebug.toDebugString)
// Out:
// pAllTrackIdsDebug = MapPartitionsRDD[249] at flatMap at <console>:40
// pTrackIdToCountDebug = ShuffledRDD[251] at reduceByKey at <console>:41
// (2) ShuffledRDD[251] at reduceByKey at <console>:41 []
//  +-(2) MapPartitionsRDD[250] at map at <console>:41 []
//     |  MapPartitionsRDD[249] at flatMap at <console>:40 []
//     |  MapPartitionsRDD[234] at map at <console>:67 []
//     |  ShuffledRDD[233] at groupBy at <console>:67 []
//     +-(2) MapPartitionsRDD[232] at groupBy at <console>:67 []
//        |  MapPartitionsRDD[227] at map at <console>:50 []
//        |  MapPartitionsRDD[226] at map at <console>:49 []
//        |  ./datas/InvoiceItem.csv MapPartitionsRDD[225] at textFile at <console>:48 []
//        |  ./datas/InvoiceItem.csv HadoopRDD[224] at textFile at <console>:48 []
// ShuffledRDD[251] at reduceByKey at <console>:41

// %% [markdown]
// - Ici reduceByKey provoque un shuffle

// %%
val trackMap: Map[Int, Track] = pTracks.map(track => (track.id, track)).collect().toMap
val broadcastTrackMap = sc.broadcast(trackMap)

val genreInvoicePairsDebug = pInvoices.flatMap { invoice =>
  val genreIds = invoice.invoiceListItem
    .flatMap(item => broadcastTrackMap.value.get(item.trackId).map(_.genreId))
    .distinct
  genreIds.map(genreId => (genreId, 1))
}

val genreIdToInvoiceCountDebug = genreInvoicePairsDebug.reduceByKey(_ + _)

println(genreIdToInvoiceCountDebug.toDebugString)
// Out:
// (2) ShuffledRDD[254] at reduceByKey at <console>:56 []
//  +-(2) MapPartitionsRDD[253] at flatMap at <console>:49 []
//     |  MapPartitionsRDD[234] at map at <console>:67 []
//     |  ShuffledRDD[233] at groupBy at <console>:67 []
//     +-(2) MapPartitionsRDD[232] at groupBy at <console>:67 []
//        |  MapPartitionsRDD[227] at map at <console>:50 []
//        |  MapPartitionsRDD[226] at map at <console>:49 []
//        |  ./datas/InvoiceItem.csv MapPartitionsRDD[225] at textFile at <console>:48 []
//        |  ./datas/InvoiceItem.csv HadoopRDD[224] at textFile at <console>:48 []
// trackMap = Map(2163 -> Track(2163,Black,1,1), 645 -> Track(645,Swedish Schnapps,1,2), 892 -> Track(892,Badge,1,6), 69 -> Track(69,Dindi (Dindi),1,2), 2199 -> Track(2199,Oceans,1,1), 3021 -> Track(3021,Like A Song...,1,1), 1322 -> Track(1322,The Trooper,1,1), 1665 -> Track(1665,Rain Song,1,1), 1036 -> Track(1036,I Get A Kick Out Of You,1,12), 2822 -> Track(2822,Exodus, Pt. 2,3,19), 2630 -> Track(2630,Edie (Ciao Baby),1,1), 1586 -> Track(1586,Thank You,1,1), 1501 -> Track(1501,Hill of the Skull,2,1), 2452 -> Track(2452,Balada Do Amor Inabalável,1,1), 809 -> Track(809,Holy Man,1,1), 1879 -> Track(1879,Escape,1,3), 1337 -> Track(1337,Flight Of The Icarus,1,3), 1718 -> Track(1718,Honolulu,1,7), 2094 -> Track(2094,I Don't Know,2,1), 1411 -> Track(1411,The Educated Fool,1,1), 6...
// Map(2163 -> Track(2163,Black,1,1), 645 -> Track(645,Swedish Schnapps,1,2), 892 -> Track(892,Badge,1,6), 69 -> Track(69,Dindi (Dindi),1,2), 2199 -> Track(2199,Oceans,1,1), 3021 -> Track(3021,Like A Song...,1,1), 1322 -> Track(1322,The Trooper,1,1), 1665 -> Track(1665,Rain Song,1,1), 1036 -> Track(1036,I Get A Kick Out Of You,1,12), 2822 -> Track(2822,Exodus, Pt. 2,3,19), 2630 -> Track(2630,Edie (Ciao Baby),1,1), 1586 -> Track(1586,Thank You,1,1), 1501 -> Track(1501,Hill of the Skull,2,1), 2452 -> Track(2452,Balada Do Amor Inabalável,1,1), 809 -> Track(809,Holy Man,1,1), 1879 -> Track(1879,Escape,1,3), 1337 -> Track(1337,Flight Of The Icarus,1,3), 1718 -> Track(1718,Honolulu,1,7), 2094 -> Track(2094,I Don't Know,2,1), 1411 -> Track(1411,The Educated Fool,1,1), 6...

// %% [markdown]
// - Ici reduceByKey provoque un shuffle

// %% [markdown]
// ### Étape 3 - Chargement de CSV

// %%
val invoiceItemsCSV = sc.textFile("./datas/InvoiceItem.csv")
  .map(_.split(";"))
  .map(cols => InvoiceItem(
    cols(0).toInt,
    cols(1).toInt,
    cols(2).toInt,
    cols(3).toDouble,
    cols(4).toInt
))

val trackCSV = sc.textFile("./datas/Track.csv")
  .map(_.split(";"))
  .map(cols => Track(
    cols(0).toInt,
    cols(1).toString,
    cols(2).toInt,
    cols(3).toInt
))

val invoiceCSV = invoiceItemsCSV.groupBy(_.invoiceId).map { case (invoiceId, items) =>
    new Invoice(invoiceId, items.toList)               
}
// Out:
// invoiceItemsCSV = MapPartitionsRDD[216] at map at <console>:42
// trackCSV = MapPartitionsRDD[220] at map at <console>:52
// invoiceCSV = MapPartitionsRDD[223] at map at <console>:59
// MapPartitionsRDD[223] at map at <console>:59
