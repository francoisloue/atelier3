// %%
import scala.collection.immutable.HashMap
import scala.util.Random

// %% [markdown]
// # Atelier 2

// %% [markdown]
// ### Étape 1 - Représentation objet #####

// %%
case class Employee(
    val id: Int,
    val lastName: String,
    val firstName: String,
    val title: String,
    val reportsTo: Int
)
// Out:
// defined class Employee

// %%
case class MediaType(val id: Int, val name: String)
// Out:
// defined class MediaType

// %%
case class Genre(val id: Int, val name: String)
// Out:
// defined class Genre

// %%
case class Track(
    val id: Int,
    val name: String,
    val genreId: Int,
    val mediaTypeId: Int
)
// Out:
// defined class Track

// %%
case class InvoiceItem(
    val id: Int,
    val invoiceId: Int,
    val trackId: Int,
    val unitPrice: Double,
    val quantity: Int
)
// Out:
// defined class InvoiceItem

// %%
case class Invoice(val id: Int, val invoiceListItem: List[InvoiceItem])
// Out:
// defined class Invoice

// %% [markdown]
// ### Étape 2 - Génération du jeu de données

// %%
val genres: List[Genre] = List(
  new Genre(1, "Rock"),
  new Genre(2, "Jazz"),
  new Genre(3, "Metal"),
  new Genre(4, "Alternative & Punk"),
  new Genre(5, "Rock And Roll"),
  new Genre(6, "Blues"),
  new Genre(7, "Latin"),
  new Genre(8, "Reggae"),
  new Genre(9, "Pop"),
  new Genre(10, "Soundtrack"),
  new Genre(11, "Bossa Nova"),
  new Genre(12, "Easy Listening"),
  new Genre(13, "Heavy Metal"),
  new Genre(14, "R&B/Soul"),
  new Genre(15, "Electronica/Dance"),
  new Genre(16, "World"),
  new Genre(17, "Hip Hop/Rap"),
  new Genre(18, "Science Fiction"),
  new Genre(19, "TV Shows"),
  new Genre(20, "Sci Fi & Fantasy"),
  new Genre(21, "Drama"),
  new Genre(22, "Comedy"),
  new Genre(23, "Alternative"),
  new Genre(24, "Classical"),
  new Genre(25, "Opera")
)
// Out:
// genres = List(Genre(1,Rock), Genre(2,Jazz), Genre(3,Metal), Genre(4,Alternative & Punk), Genre(5,Rock And Roll), Genre(6,Blues), Genre(7,Latin), Genre(8,Reggae), Genre(9,Pop), Genre(10,Soundtrack), Genre(11,Bossa Nova), Genre(12,Easy Listening), Genre(13,Heavy Metal), Genre(14,R&B/Soul), Genre(15,Electronica/Dance), Genre(16,World), Genre(17,Hip Hop/Rap), Genre(18,Science Fiction), Genre(19,TV Shows), Genre(20,Sci Fi & Fantasy), Genre(21,Drama), Genre(22,Comedy), Genre(23,Alternative), Genre(24,Classical), Genre(25,Opera))
// List(Genre(1,Rock), Genre(2,Jazz), Genre(3,Metal), Genre(4,Alternative & Punk), Genre(5,Rock And Roll), Genre(6,Blues), Genre(7,Latin), Genre(8,Reggae), Genre(9,Pop), Genre(10,Soundtrack), Genre(11,Bossa Nova), Genre(12,Easy Listening), Genre(13,Heavy Metal), Genre(14,R&B/Soul), Genre(15,Electronica/Dance), Genre(16,World), Genre(17,Hip Hop/Rap), Genre(18,Science Fiction), Genre(19,TV Shows), Genre(20,Sci Fi & Fantasy), Genre(21,Drama), Genre(22,Comedy), Genre(23,Alternative), Genre(24,Classical), Genre(25,Opera))

// %%
val mediaTypes: List[MediaType] = List(
  new MediaType(1, "MPEG audio file"),
  new MediaType(2, "Protected AAC audio file"),
  new MediaType(3, "Protected MPEG-4 video file"),
  new MediaType(4, "Purchased AAC audio file"),
  new MediaType(5, "AAC audio file")
)
// Out:
// mediaTypes = List(MediaType(1,MPEG audio file), MediaType(2,Protected AAC audio file), MediaType(3,Protected MPEG-4 video file), MediaType(4,Purchased AAC audio file), MediaType(5,AAC audio file))
// List(MediaType(1,MPEG audio file), MediaType(2,Protected AAC audio file), MediaType(3,Protected MPEG-4 video file), MediaType(4,Purchased AAC audio file), MediaType(5,AAC audio file))

// %%
val employees: List[Employee] = List(
  new Employee(1, "Adams", "Andrew", "General Manager", 0),
  new Employee(2, "Edwards", "Nancy", "Sales Manager", 1),
  new Employee(3, "Peacock", "Jane", "Sales Support Agent", 2),
  new Employee(4, "Park", "Margaret", "Sales Support Agent", 2),
  new Employee(5, "Johnson", "Steve", "Sales Support Agent", 2),
  new Employee(6, "Mitchell", "Michael", "IT Manager", 1),
  new Employee(7, "King", "Robert", "IT Staff", 6),
  new Employee(8, "Callahan", "Laura", "IT Staff", 6)
)
// Out:
// employees = List(Employee(1,Adams,Andrew,General Manager,0), Employee(2,Edwards,Nancy,Sales Manager,1), Employee(3,Peacock,Jane,Sales Support Agent,2), Employee(4,Park,Margaret,Sales Support Agent,2), Employee(5,Johnson,Steve,Sales Support Agent,2), Employee(6,Mitchell,Michael,IT Manager,1), Employee(7,King,Robert,IT Staff,6), Employee(8,Callahan,Laura,IT Staff,6))
// List(Employee(1,Adams,Andrew,General Manager,0), Employee(2,Edwards,Nancy,Sales Manager,1), Employee(3,Peacock,Jane,Sales Support Agent,2), Employee(4,Park,Margaret,Sales Support Agent,2), Employee(5,Johnson,Steve,Sales Support Agent,2), Employee(6,Mitchell,Michael,IT Manager,1), Employee(7,King,Robert,IT Staff,6), Employee(8,Callahan,Laura,IT Staff,6))

// %%
val adjectives: HashMap[Int, String] = HashMap(
  1 -> "Cosmic",
  2 -> "Electric",
  3 -> "Velvet",
  4 -> "Mystic",
  5 -> "Atomic",
  6 -> "Phantom",
  7 -> "Silent",
  8 -> "Savage",
  9 -> "Eternal",
  10 -> "Digital",
  11 -> "Lost",
  12 -> "Sacred",
  13 -> "Wild",
  14 -> "Urban",
  15 -> "Golden",
  16 -> "Crystal",
  17 -> "Liquid",
  18 -> "Toxic",
  19 -> "Neon",
  20 -> "Crimson",
  21 -> "Stellar",
  22 -> "Raging",
  23 -> "Arctic",
  24 -> "Sonic",
  25 -> "Primal",
  26 -> "Midnight",
  27 -> "Screaming",
  28 -> "Infinite",
  29 -> "Royal",
  30 -> "Lunar"
)
// Out:
// adjectives = Map(5 -> Atomic, 10 -> Digital, 24 -> Sonic, 25 -> Primal, 14 -> Urban, 20 -> Crimson, 29 -> Royal, 1 -> Cosmic, 6 -> Phantom, 28 -> Infinite, 21 -> Stellar, 9 -> Eternal, 13 -> Wild, 2 -> Electric, 17 -> Liquid, 22 -> Raging, 27 -> Screaming, 12 -> Sacred, 7 -> Silent, 3 -> Velvet, 18 -> Toxic, 16 -> Crystal, 11 -> Lost, 26 -> Midnight, 23 -> Arctic, 8 -> Savage, 30 -> Lunar, 19 -> Neon, 4 -> Mystic, 15 -> Golden)
// Map(5 -> Atomic, 10 -> Digital, 24 -> Sonic, 25 -> Primal, 14 -> Urban, 20 -> Crimson, 29 -> Royal, 1 -> Cosmic, 6 -> Phantom, 28 -> Infinite, 21 -> Stellar, 9 -> Eternal, 13 -> Wild, 2 -> Electric, 17 -> Liquid, 22 -> Raging, 27 -> Screaming, 12 -> Sacred, 7 -> Silent, 3 -> Velvet, 18 -> Toxic, 16 -> Crystal, 11 -> Lost, 26 -> Midnight, 23 -> Arctic, 8 -> Savage, 30 -> Lunar, 19 -> Neon, 4 -> Mystic, 15 -> Golden)

// %%
val noms: HashMap[Int, String] = HashMap(
  1 -> "Echo",
  2 -> "Giants",
  3 -> "Wolves",
  4 -> "Horizon",
  5 -> "Empire",
  6 -> "Void",
  7 -> "Thunder",
  8 -> "Dragons",
  9 -> "Saints",
  10 -> "Kings",
  11 -> "Ghosts",
  12 -> "Ravens",
  13 -> "Pirates",
  14 -> "Heroes",
  15 -> "Rebels",
  16 -> "Demons",
  17 -> "Machines",
  18 -> "Angels",
  19 -> "Knights",
  20 -> "Lions",
  21 -> "Shadows",
  22 -> "Zombies",
  23 -> "Wizards",
  24 -> "Killers",
  25 -> "Titans",
  26 -> "Outlaws",
  27 -> "Rebels",
  28 -> "Prophets",
  29 -> "Bandits",
  30 -> "Warriors"
)
// Out:
// noms = Map(5 -> Empire, 10 -> Kings, 24 -> Killers, 25 -> Titans, 14 -> Heroes, 20 -> Lions, 29 -> Bandits, 1 -> Echo, 6 -> Void, 28 -> Prophets, 21 -> Shadows, 9 -> Saints, 13 -> Pirates, 2 -> Giants, 17 -> Machines, 22 -> Zombies, 27 -> Rebels, 12 -> Ravens, 7 -> Thunder, 3 -> Wolves, 18 -> Angels, 16 -> Demons, 11 -> Ghosts, 26 -> Outlaws, 23 -> Wizards, 8 -> Dragons, 30 -> Warriors, 19 -> Knights, 4 -> Horizon, 15 -> Rebels)
// Map(5 -> Empire, 10 -> Kings, 24 -> Killers, 25 -> Titans, 14 -> Heroes, 20 -> Lions, 29 -> Bandits, 1 -> Echo, 6 -> Void, 28 -> Prophets, 21 -> Shadows, 9 -> Saints, 13 -> Pirates, 2 -> Giants, 17 -> Machines, 22 -> Zombies, 27 -> Rebels, 12 -> Ravens, 7 -> Thunder, 3 -> Wolves, 18 -> Angels, 16 -> Demons, 11 -> Ghosts, 26 -> Outlaws, 23 -> Wizards, 8 -> Dragons, 30 -> Warriors, 19 -> Knights, 4 -> Horizon, 15 -> Rebels)

// %%
val complements: HashMap[Int, String] = HashMap(
  1 -> "of Doom",
  2 -> "in Chains",
  3 -> "from Mars",
  4 -> "of the North",
  5 -> "of Death",
  6 -> "in Disguise",
  7 -> "of the Night",
  8 -> "from Hell",
  9 -> "of Tomorrow",
  10 -> "in Flames",
  11 -> "of the Deep",
  12 -> "from Beyond",
  13 -> "of Destruction",
  14 -> "in Shadow",
  15 -> "from the Sky",
  16 -> "of the Abyss",
  17 -> "in Exile",
  18 -> "from the East",
  19 -> "of Eternity",
  20 -> "from the Desert",
  21 -> "of the Underground"
)
// Out:
// complements = Map(5 -> of Death, 10 -> in Flames, 14 -> in Shadow, 20 -> from the Desert, 1 -> of Doom, 6 -> in Disguise, 21 -> of the Underground, 9 -> of Tomorrow, 13 -> of Destruction, 2 -> in Chains, 17 -> in Exile, 12 -> from Beyond, 7 -> of the Night, 3 -> from Mars, 18 -> from the East, 16 -> of the Abyss, 11 -> of the Deep, 8 -> from Hell, 19 -> of Eternity, 4 -> of the North, 15 -> from the Sky)
// Map(5 -> of Death, 10 -> in Flames, 14 -> in Shadow, 20 -> from the Desert, 1 -> of Doom, 6 -> in Disguise, 21 -> of the Underground, 9 -> of Tomorrow, 13 -> of Destruction, 2 -> in Chains, 17 -> in Exile, 12 -> from Beyond, 7 -> of the Night, 3 -> from Mars, 18 -> from the East, 16 -> of the Abyss, 11 -> of the Deep, 8 -> from Hell, 19 -> of Eternity, 4 -> of the North, 15 -> from the Sky)

// %%
object Track {
  def generateTrack(id: Int): Track = {
    val randomAdjective: String = adjectives.getOrElse(Random.nextInt(30) + 1, "")
    val randomName: String = noms.getOrElse(Random.nextInt(30) + 1, "")
    val randomComplement: String = complements.getOrElse(Random.nextInt(21) + 1, "")
    
    val title: String = s"$randomAdjective $randomName $randomComplement"
    val genreId: Int = genres(Random.nextInt(genres.size)).id
    val mediaTypeId: Int = mediaTypes(Random.nextInt(mediaTypes.size)).id

    new Track(id, title, genreId, mediaTypeId)
  }
}
// Out:
// defined object Track
// warning: previously defined class Track is not a companion to object Track.
// Companions must be defined together; you may wish to use :paste mode for this.

// %%
val trackList: List[Track] = (for(index <- 1 to 200) yield {
  Track.generateTrack(index)
}).toList
// Out:
// trackList = List(Track(1,Stellar Void from the Sky,4,4), Track(2,Neon Warriors in Flames,21,5), Track(3,Wild Killers from Beyond,8,3), Track(4,Screaming Pirates from Beyond,17,4), Track(5,Savage Knights in Shadow,17,1), Track(6,Cosmic Outlaws of Eternity,25,3), Track(7,Mystic Shadows of the North,21,4), Track(8,Stellar Zombies of the Underground,22,4), Track(9,Lunar Saints of the Night,2,4), Track(10,Stellar Angels of Eternity,7,3), Track(11,Cosmic Rebels of Tomorrow,10,1), Track(12,Silent Dragons in Chains,9,2), Track(13,Savage Zombies from the Desert,8,4), Track(14,Liquid Rebels of the Underground,15,3), Track(15,Eternal Prophets from Hell,2,4), Track(16,Primal Ravens from the East,8,3), Track(17,Golden Ravens of the North,9,1), Track(18,Screaming Prophets from Beyond,7,5...
// List(Track(1,Stellar Void from the Sky,4,4), Track(2,Neon Warriors in Flames,21,5), Track(3,Wild Killers from Beyond,8,3), Track(4,Screaming Pirates from Beyond,17,4), Track(5,Savage Knights in Shadow,17,1), Track(6,Cosmic Outlaws of Eternity,25,3), Track(7,Mystic Shadows of the North,21,4), Track(8,Stellar Zombies of the Underground,22,4), Track(9,Lunar Saints of the Night,2,4), Track(10,Stellar Angels of Eternity,7,3), Track(11,Cosmic Rebels of Tomorrow,10,1), Track(12,Silent Dragons in Chains,9,2), Track(13,Savage Zombies from the Desert,8,4), Track(14,Liquid Rebels of the Underground,15,3), Track(15,Eternal Prophets from Hell,2,4), Track(16,Primal Ravens from the East,8,3), Track(17,Golden Ravens of the North,9,1), Track(18,Screaming Prophets from Beyond,7,5...

// %%
object Invoice {
  def generateInvoice(id: Int): Invoice = { 
      val invoiceItemList: List[InvoiceItem] = (for(index <- 1 to (Random.nextInt(5)+1)) yield {
        val trackId = trackList(Random.nextInt(trackList.size)).id
        
        new InvoiceItem(index, id, trackId, 10.35, 1)      
      }).toList

      new Invoice(id, invoiceItemList)
  }  
}
// Out:
// defined object Invoice
// warning: previously defined class Invoice is not a companion to object Invoice.
// Companions must be defined together; you may wish to use :paste mode for this.

// %%
val invoiceList: List[Invoice] = (for(index <- 1 to 2000) yield {
  Invoice.generateInvoice(index)
}).toList
// Out:
// invoiceList = List(Invoice(1,List(InvoiceItem(1,1,67,10.35,1), InvoiceItem(2,1,137,10.35,1))), Invoice(2,List(InvoiceItem(1,2,163,10.35,1))), Invoice(3,List(InvoiceItem(1,3,108,10.35,1), InvoiceItem(2,3,2,10.35,1), InvoiceItem(3,3,194,10.35,1), InvoiceItem(4,3,149,10.35,1), InvoiceItem(5,3,188,10.35,1))), Invoice(4,List(InvoiceItem(1,4,114,10.35,1), InvoiceItem(2,4,169,10.35,1), InvoiceItem(3,4,196,10.35,1))), Invoice(5,List(InvoiceItem(1,5,64,10.35,1))), Invoice(6,List(InvoiceItem(1,6,155,10.35,1), InvoiceItem(2,6,134,10.35,1))), Invoice(7,List(InvoiceItem(1,7,169,10.35,1))), Invoice(8,List(InvoiceItem(1,8,200,10.35,1), InvoiceItem(2,8,150,10.35,1), InvoiceItem(3,8,39,10.35,1), InvoiceItem(4,8,158,10.35,1))), Invoice(9,List(InvoiceItem(1,9,15,10.35,1), InvoiceItem(2,9,18...
// List(Invoice(1,List(InvoiceItem(1,1,67,10.35,1), InvoiceItem(2,1,137,10.35,1))), Invoice(2,List(InvoiceItem(1,2,163,10.35,1))), Invoice(3,List(InvoiceItem(1,3,108,10.35,1), InvoiceItem(2,3,2,10.35,1), InvoiceItem(3,3,194,10.35,1), InvoiceItem(4,3,149,10.35,1), InvoiceItem(5,3,188,10.35,1))), Invoice(4,List(InvoiceItem(1,4,114,10.35,1), InvoiceItem(2,4,169,10.35,1), InvoiceItem(3,4,196,10.35,1))), Invoice(5,List(InvoiceItem(1,5,64,10.35,1))), Invoice(6,List(InvoiceItem(1,6,155,10.35,1), InvoiceItem(2,6,134,10.35,1))), Invoice(7,List(InvoiceItem(1,7,169,10.35,1))), Invoice(8,List(InvoiceItem(1,8,200,10.35,1), InvoiceItem(2,8,150,10.35,1), InvoiceItem(3,8,39,10.35,1), InvoiceItem(4,8,158,10.35,1))), Invoice(9,List(InvoiceItem(1,9,15,10.35,1), InvoiceItem(2,9,18...

// %%
for (track <- trackList) println(track)
for (invoice <- invoiceList) println(invoice)
// Out:
// Track(1,Stellar Void from the Sky,4,4)
// Track(2,Neon Warriors in Flames,21,5)
// Track(3,Wild Killers from Beyond,8,3)
// Track(4,Screaming Pirates from Beyond,17,4)
// Track(5,Savage Knights in Shadow,17,1)
// Track(6,Cosmic Outlaws of Eternity,25,3)
// Track(7,Mystic Shadows of the North,21,4)
// Track(8,Stellar Zombies of the Underground,22,4)
// Track(9,Lunar Saints of the Night,2,4)
// Track(10,Stellar Angels of Eternity,7,3)
// Track(11,Cosmic Rebels of Tomorrow,10,1)
// Track(12,Silent Dragons in Chains,9,2)
// Track(13,Savage Zombies from the Desert,8,4)
// Track(14,Liquid Rebels of the Underground,15,3)
// Track(15,Eternal Prophets from Hell,2,4)
// Track(16,Primal Ravens from the East,8,3)
// Track(17,Golden Ravens of the North,9,1)
// Track(18,Screaming Prophets from Beyond,7,5)
// Track(19,Electric Saints of the Night,6,2)
// Track(20,Primal Wizards in Chains,12,4)
// Track(21,Toxic Heroes in Chains,1,1)
// Track(22,Mystic Wolves of the North,5,2)
// Track(23,Liquid Wizards of Tomorrow,6,3)
// Track(24,Mystic Lions from Hell,1,3)
// Track(25,Screaming Angels of Eternity,23,5)
// Track(26,Arctic Echo in Shadow,19,5)
// Track(27,Screaming Machines of Death,12,2)
// Track(28,Cosmic Horizon from the Sky,24,2)
// Track(29,Urban Demons from Mars,20,3)
// Track(30,Golden Killers in Shadow,10,4)
// Track(31,Infinite Dragons of the Underground,21,2)
// Track(32,Wild Demons from the Sky,12,1)
// Track(33,Neon Angels of the Underground,7,2)
// Track(34,Arctic Thunder of the Underground,3,2)
// Track(35,Sonic Rebels of Tomorrow,21,3)
// Track(36,Urban Demons of the Deep,4,2)
// Track(37,Phantom Giants of Death,19,2)
// Track(38,Atomic Angels of the Night,3,4)
// Track(39,Digital Warriors from the East,13,1)
// Track(40,Neon Horizon of the Night,7,3)
// Track(41,Golden Angels of the Night,2,5)
// Track(42,Lost Killers from the Desert,5,3)
// Track(43,Velvet Thunder in Shadow,1,1)
// Track(44,Phantom Void of Destruction,3,3)
// Track(45,Atomic Dragons in Shadow,23,1)
// Track(46,Velvet Giants in Disguise,21,3)
// Track(47,Phantom Heroes of Destruction,7,3)
// Track(48,Crystal Demons from Mars,24,4)
// Track(49,Liquid Ravens of the North,13,4)
// Track(50,Velvet Prophets of Death,21,2)
// Track(51,Sonic Machines from Beyond,15,3)
// Track(52,Neon Rebels of Tomorrow,19,5)
// Track(53,Lost Horizon of Doom,17,5)
// Track(54,Stellar Saints of Doom,1,1)
// Track(55,Eternal Wolves of Destruction,6,3)
// Track(56,Crystal Horizon in Shadow,18,2)
// Track(57,Stellar Lions in Flames,11,4)
// Track(58,Electric Shadows of the Deep,5,1)
// Track(59,Cosmic Knights of Destruction,13,1)
// Track(60,Atomic Ravens of the Deep,18,2)
// Track(61,Silent Warriors in Exile,18,4)
// Track(62,Toxic Angels from the Desert,25,5)
// Track(63,Savage Outlaws of the North,11,4)
// Track(64,Silent Machines of the Underground,15,1)
// Track(65,Sonic Giants from Hell,7,5)
// Track(66,Lunar Ravens from Hell,16,2)
// Track(67,Stellar Bandits of Eternity,23,5)
// Track(68,Crimson Thunder in Shadow,8,5)
// Track(69,Mystic Zombies of the Night,22,2)
// Track(70,Lost Rebels in Flames,22,5)
// Track(71,Crystal Zombies of Doom,16,1)
// Track(72,Liquid Knights of the Abyss,15,4)
// Track(73,Midnight Giants of Eternity,21,3)
// Track(74,Wild Wolves in Disguise,1,3)
// Track(75,Electric Knights from Mars,2,5)
// Track(76,Screaming Killers in Flames,10,1)
// Track(77,Raging Pirates of the North,11,5)
// Track(78,Velvet Ravens of Death,23,3)
// Track(79,Silent Shadows from the Sky,12,1)
// Track(80,Sonic Echo of Tomorrow,17,5)
// Track(81,Silent Empire from the Sky,18,1)
// Track(82,Digital Ghosts from the East,4,5)
// Track(83,Eternal Heroes from the Desert,23,2)
// Track(84,Atomic Bandits of the Night,4,4)
// Track(85,Wild Void from the Sky,5,4)
// Track(86,Arctic Pirates of Tomorrow,15,2)
// Track(87,Electric Wizards from the East,14,4)
// Track(88,Stellar Heroes from the East,4,3)
// Track(89,Golden Kings of the Underground,13,1)
// Track(90,Raging Echo of the Abyss,13,2)
// Track(91,Infinite Titans of Eternity,12,3)
// Track(92,Silent Zombies from the Sky,19,3)
// Track(93,Silent Empire of the Night,7,3)
// Track(94,Eternal Wolves in Disguise,19,1)
// Track(95,Sacred Titans of Eternity,11,3)
// Track(96,Arctic Thunder of Death,25,3)
// Track(97,Midnight Empire from the Desert,14,4)
// Track(98,Royal Saints of the North,15,4)
// Track(99,Raging Killers in Flames,3,5)
// Track(100,Lost Thunder in Disguise,7,5)
// Track(101,Stellar Demons from the Desert,20,2)
// Track(102,Digital Rebels from the East,2,5)
// Track(103,Infinite Titans of the Night,6,2)
// Track(104,Toxic Bandits in Flames,25,3)
// Track(105,Electric Dragons in Exile,25,4)
// Track(106,Cosmic Bandits in Flames,22,5)
// Track(107,Mystic Void in Exile,7,2)
// Track(108,Sacred Warriors from Mars,23,2)
// Track(109,Screaming Wizards of Eternity,12,2)
// Track(110,Silent Prophets from the East,12,4)
// Track(111,Lost Wizards of Doom,18,5)
// Track(112,Savage Shadows of the North,19,3)
// Track(113,Toxic Demons of Death,2,4)
// Track(114,Screaming Lions from Beyond,19,3)
// Track(115,Stellar Knights in Chains,11,5)
// Track(116,Velvet Empire in Exile,2,4)
// Track(117,Screaming Titans from Mars,19,4)
// Track(118,Eternal Rebels of Death,25,5)
// Track(119,Eternal Echo in Shadow,17,4)
// Track(120,Screaming Bandits of Destruction,6,1)
// Track(121,Atomic Horizon in Shadow,22,1)
// Track(122,Urban Echo from Mars,16,3)
// Track(123,Phantom Prophets of Tomorrow,20,2)
// Track(124,Screaming Lions from the Desert,19,1)
// Track(125,Primal Wizards in Chains,22,1)
// Track(126,Digital Void in Flames,24,5)
// Track(127,Digital Wizards from the East,12,5)
// Track(128,Lunar Titans from the Sky,15,4)
// Track(129,Toxic Pirates from the Desert,16,5)
// Track(130,Midnight Thunder from Hell,2,4)
// Track(131,Wild Rebels of Tomorrow,17,2)
// Track(132,Wild Ghosts of the North,8,1)
// Track(133,Lost Titans of Eternity,19,3)
// Track(134,Eternal Bandits in Flames,5,1)
// Track(135,Velvet Saints of the North,24,4)
// Track(136,Golden Horizon of the North,15,4)
// Track(137,Phantom Machines of the Underground,8,3)
// Track(138,Crystal Pirates in Chains,17,2)
// Track(139,Silent Ghosts of Eternity,3,2)
// Track(140,Eternal Demons from Beyond,12,2)
// Track(141,Digital Ravens of the Night,11,2)
// Track(142,Toxic Void in Shadow,1,2)
// Track(143,Wild Giants of Destruction,21,5)
// Track(144,Urban Empire of Tomorrow,11,3)
// Track(145,Eternal Ghosts in Disguise,11,5)
// Track(146,Velvet Void of Destruction,12,5)
// Track(147,Atomic Thunder in Disguise,8,3)
// Track(148,Urban Pirates of Destruction,12,5)
// Track(149,Urban Shadows from Beyond,1,3)
// Track(150,Neon Saints in Chains,4,4)
// Track(151,Cosmic Rebels in Exile,13,4)
// Track(152,Electric Bandits in Chains,4,1)
// Track(153,Velvet Outlaws from Hell,11,2)
// Track(154,Lost Echo in Flames,9,5)
// Track(155,Screaming Saints from Beyond,25,2)
// Track(156,Screaming Pirates of the Deep,12,5)
// Track(157,Sonic Ravens from the Desert,24,4)
// Track(158,Golden Rebels from Mars,6,3)
// Track(159,Arctic Kings of Tomorrow,20,5)
// Track(160,Wild Ghosts in Disguise,21,5)
// Track(161,Digital Lions from the East,15,1)
// Track(162,Neon Prophets of Destruction,1,3)
// Track(163,Mystic Rebels of the North,17,3)
// Track(164,Savage Empire of the Deep,23,2)
// Track(165,Sonic Rebels from Beyond,24,3)
// Track(166,Atomic Giants of the Abyss,13,3)
// Track(167,Atomic Bandits from the Desert,21,3)
// Track(168,Toxic Prophets from the Desert,6,3)
// Track(169,Sacred Lions of the North,21,4)
// Track(170,Sacred Rebels in Exile,23,3)
// Track(171,Silent Pirates in Shadow,25,1)
// Track(172,Digital Kings in Flames,4,5)
// Track(173,Raging Bandits of the Deep,17,2)
// Track(174,Primal Shadows of the North,20,4)
// Track(175,Infinite Giants of the Underground,19,5)
// Track(176,Sacred Demons in Disguise,5,4)
// Track(177,Cosmic Horizon from Beyond,5,3)
// Track(178,Sonic Dragons of Eternity,21,2)
// Track(179,Phantom Void in Chains,21,2)
// Track(180,Digital Angels in Chains,25,5)
// Track(181,Digital Ravens of the Underground,5,5)
// Track(182,Velvet Dragons of the North,10,1)
// Track(183,Arctic Kings of Destruction,25,3)
// Track(184,Neon Thunder in Exile,10,4)
// Track(185,Golden Empire from the East,23,3)
// Track(186,Lunar Pirates in Flames,7,4)
// Track(187,Royal Angels from Hell,2,2)
// Track(188,Royal Rebels in Shadow,3,5)
// Track(189,Arctic Void of Eternity,11,2)
// Track(190,Savage Bandits from the Desert,23,5)
// Track(191,Stellar Shadows of the Deep,3,2)
// Track(192,Primal Lions in Exile,5,5)
// Track(193,Electric Bandits from Beyond,21,1)
// Track(194,Electric Saints from the Sky,23,3)
// Track(195,Silent Wolves in Flames,10,1)
// Track(196,Primal Echo of the Underground,7,2)
// Track(197,Crystal Rebels in Shadow,20,3)
// Track(198,Sonic Heroes from the East,23,5)
// Track(199,Liquid Saints from Beyond,4,3)
// Track(200,Mystic Rebels of Destruction,19,1)
// Invoice(1,List(InvoiceItem(1,1,67,10.35,1), InvoiceItem(2,1,137,10.35,1)))
// Invoice(2,List(InvoiceItem(1,2,163,10.35,1)))
// Invoice(3,List(InvoiceItem(1,3,108,10.35,1), InvoiceItem(2,3,2,10.35,1), InvoiceItem(3,3,194,10.35,1), InvoiceItem(4,3,149,10.35,1), InvoiceItem(5,3,188,10.35,1)))
// Invoice(4,List(InvoiceItem(1,4,114,10.35,1), InvoiceItem(2,4,169,10.35,1), InvoiceItem(3,4,196,10.35,1)))
// Invoice(5,List(InvoiceItem(1,5,64,10.35,1)))
// Invoice(6,List(InvoiceItem(1,6,155,10.35,1), InvoiceItem(2,6,134,10.35,1)))
// Invoice(7,List(InvoiceItem(1,7,169,10.35,1)))
// Invoice(8,List(InvoiceItem(1,8,200,10.35,1), InvoiceItem(2,8,150,10.35,1), InvoiceItem(3,8,39,10.35,1), InvoiceItem(4,8,158,10.35,1)))
// Invoice(9,List(InvoiceItem(1,9,15,10.35,1), InvoiceItem(2,9,180,10.35,1), InvoiceItem(3,9,185,10.35,1), InvoiceItem(4,9,198,10.35,1), InvoiceItem(5,9,89,10.35,1)))
// Invoice(10,List(InvoiceItem(1,10,127,10.35,1), InvoiceItem(2,10,149,10.35,1), InvoiceItem(3,10,36,10.35,1)))
// Invoice(11,List(InvoiceItem(1,11,107,10.35,1)))
// Invoice(12,List(InvoiceItem(1,12,37,10.35,1), InvoiceItem(2,12,182,10.35,1), InvoiceItem(3,12,138,10.35,1), InvoiceItem(4,12,160,10.35,1), InvoiceItem(5,12,147,10.35,1)))
// Invoice(13,List(InvoiceItem(1,13,49,10.35,1), InvoiceItem(2,13,133,10.35,1), InvoiceItem(3,13,156,10.35,1), InvoiceItem(4,13,58,10.35,1), InvoiceItem(5,13,78,10.35,1)))
// Invoice(14,List(InvoiceItem(1,14,16,10.35,1)))
// Invoice(15,List(InvoiceItem(1,15,200,10.35,1), InvoiceItem(2,15,80,10.35,1), InvoiceItem(3,15,117,10.35,1)))
// Invoice(16,List(InvoiceItem(1,16,51,10.35,1), InvoiceItem(2,16,23,10.35,1)))
// Invoice(17,List(InvoiceItem(1,17,169,10.35,1), InvoiceItem(2,17,83,10.35,1), InvoiceItem(3,17,198,10.35,1), InvoiceItem(4,17,71,10.35,1)))
// Invoice(18,List(InvoiceItem(1,18,74,10.35,1), InvoiceItem(2,18,162,10.35,1), InvoiceItem(3,18,40,10.35,1), InvoiceItem(4,18,195,10.35,1)))
// Invoice(19,List(InvoiceItem(1,19,54,10.35,1), InvoiceItem(2,19,130,10.35,1), InvoiceItem(3,19,40,10.35,1), InvoiceItem(4,19,71,10.35,1), InvoiceItem(5,19,173,10.35,1)))
// Invoice(20,List(InvoiceItem(1,20,23,10.35,1), InvoiceItem(2,20,161,10.35,1), InvoiceItem(3,20,47,10.35,1), InvoiceItem(4,20,116,10.35,1)))
// Invoice(21,List(InvoiceItem(1,21,58,10.35,1), InvoiceItem(2,21,78,10.35,1), InvoiceItem(3,21,98,10.35,1)))
// Invoice(22,List(InvoiceItem(1,22,144,10.35,1), InvoiceItem(2,22,3,10.35,1)))
// Invoice(23,List(InvoiceItem(1,23,154,10.35,1)))
// Invoice(24,List(InvoiceItem(1,24,170,10.35,1), InvoiceItem(2,24,136,10.35,1)))
// Invoice(25,List(InvoiceItem(1,25,58,10.35,1)))
// Invoice(26,List(InvoiceItem(1,26,122,10.35,1), InvoiceItem(2,26,192,10.35,1), InvoiceItem(3,26,158,10.35,1), InvoiceItem(4,26,59,10.35,1), InvoiceItem(5,26,58,10.35,1)))
// Invoice(27,List(InvoiceItem(1,27,27,10.35,1), InvoiceItem(2,27,55,10.35,1), InvoiceItem(3,27,95,10.35,1), InvoiceItem(4,27,9,10.35,1)))
// Invoice(28,List(InvoiceItem(1,28,123,10.35,1), InvoiceItem(2,28,42,10.35,1), InvoiceItem(3,28,127,10.35,1)))
// Invoice(29,List(InvoiceItem(1,29,108,10.35,1), InvoiceItem(2,29,164,10.35,1), InvoiceItem(3,29,10,10.35,1), InvoiceItem(4,29,152,10.35,1)))
// Invoice(30,List(InvoiceItem(1,30,173,10.35,1), InvoiceItem(2,30,75,10.35,1), InvoiceItem(3,30,31,10.35,1)))
// Invoice(31,List(InvoiceItem(1,31,167,10.35,1), InvoiceItem(2,31,50,10.35,1), InvoiceItem(3,31,90,10.35,1), InvoiceItem(4,31,40,10.35,1)))
// Invoice(32,List(InvoiceItem(1,32,62,10.35,1), InvoiceItem(2,32,162,10.35,1), InvoiceItem(3,32,13,10.35,1)))
// Invoice(33,List(InvoiceItem(1,33,143,10.35,1)))
// Invoice(34,List(InvoiceItem(1,34,84,10.35,1), InvoiceItem(2,34,191,10.35,1), InvoiceItem(3,34,158,10.35,1)))
// Invoice(35,List(InvoiceItem(1,35,50,10.35,1), InvoiceItem(2,35,62,10.35,1), InvoiceItem(3,35,53,10.35,1), InvoiceItem(4,35,196,10.35,1)))
// Invoice(36,List(InvoiceItem(1,36,97,10.35,1), InvoiceItem(2,36,72,10.35,1), InvoiceItem(3,36,193,10.35,1)))
// Invoice(37,List(InvoiceItem(1,37,8,10.35,1), InvoiceItem(2,37,144,10.35,1), InvoiceItem(3,37,118,10.35,1)))
// Invoice(38,List(InvoiceItem(1,38,20,10.35,1), InvoiceItem(2,38,128,10.35,1), InvoiceItem(3,38,98,10.35,1), InvoiceItem(4,38,175,10.35,1)))
// Invoice(39,List(InvoiceItem(1,39,22,10.35,1), InvoiceItem(2,39,172,10.35,1), InvoiceItem(3,39,53,10.35,1), InvoiceItem(4,39,167,10.35,1), InvoiceItem(5,39,104,10.35,1)))
// Invoice(40,List(InvoiceItem(1,40,44,10.35,1), InvoiceItem(2,40,171,10.35,1), InvoiceItem(3,40,191,10.35,1), InvoiceItem(4,40,122,10.35,1)))
// Invoice(41,List(InvoiceItem(1,41,170,10.35,1), InvoiceItem(2,41,173,10.35,1)))
// Invoice(42,List(InvoiceItem(1,42,44,10.35,1), InvoiceItem(2,42,45,10.35,1), InvoiceItem(3,42,31,10.35,1), InvoiceItem(4,42,4,10.35,1), InvoiceItem(5,42,50,10.35,1)))
// Invoice(43,List(InvoiceItem(1,43,62,10.35,1), InvoiceItem(2,43,17,10.35,1), InvoiceItem(3,43,79,10.35,1), InvoiceItem(4,43,180,10.35,1), InvoiceItem(5,43,184,10.35,1)))
// Invoice(44,List(InvoiceItem(1,44,54,10.35,1), InvoiceItem(2,44,108,10.35,1), InvoiceItem(3,44,14,10.35,1)))
// Invoice(45,List(InvoiceItem(1,45,119,10.35,1), InvoiceItem(2,45,61,10.35,1), InvoiceItem(3,45,50,10.35,1), InvoiceItem(4,45,75,10.35,1)))
// Invoice(46,List(InvoiceItem(1,46,143,10.35,1), InvoiceItem(2,46,96,10.35,1), InvoiceItem(3,46,131,10.35,1), InvoiceItem(4,46,32,10.35,1), InvoiceItem(5,46,144,10.35,1)))
// Invoice(47,List(InvoiceItem(1,47,43,10.35,1), InvoiceItem(2,47,196,10.35,1), InvoiceItem(3,47,160,10.35,1), InvoiceItem(4,47,16,10.35,1), InvoiceItem(5,47,170,10.35,1)))
// Invoice(48,List(InvoiceItem(1,48,71,10.35,1), InvoiceItem(2,48,131,10.35,1), InvoiceItem(3,48,114,10.35,1), InvoiceItem(4,48,2,10.35,1)))
// Invoice(49,List(InvoiceItem(1,49,101,10.35,1)))
// Invoice(50,List(InvoiceItem(1,50,141,10.35,1), InvoiceItem(2,50,196,10.35,1), InvoiceItem(3,50,168,10.35,1), InvoiceItem(4,50,15,10.35,1), InvoiceItem(5,50,57,10.35,1)))
// Invoice(51,List(InvoiceItem(1,51,155,10.35,1)))
// Invoice(52,List(InvoiceItem(1,52,75,10.35,1), InvoiceItem(2,52,150,10.35,1), InvoiceItem(3,52,51,10.35,1), InvoiceItem(4,52,66,10.35,1), InvoiceItem(5,52,10,10.35,1)))
// Invoice(53,List(InvoiceItem(1,53,11,10.35,1), InvoiceItem(2,53,45,10.35,1)))
// Invoice(54,List(InvoiceItem(1,54,52,10.35,1), InvoiceItem(2,54,76,10.35,1), InvoiceItem(3,54,20,10.35,1), InvoiceItem(4,54,180,10.35,1), InvoiceItem(5,54,100,10.35,1)))
// Invoice(55,List(InvoiceItem(1,55,176,10.35,1), InvoiceItem(2,55,25,10.35,1), InvoiceItem(3,55,199,10.35,1)))
// Invoice(56,List(InvoiceItem(1,56,50,10.35,1)))
// Invoice(57,List(InvoiceItem(1,57,107,10.35,1), InvoiceItem(2,57,49,10.35,1), InvoiceItem(3,57,159,10.35,1), InvoiceItem(4,57,103,10.35,1), InvoiceItem(5,57,52,10.35,1)))
// Invoice(58,List(InvoiceItem(1,58,130,10.35,1), InvoiceItem(2,58,130,10.35,1), InvoiceItem(3,58,14,10.35,1)))
// Invoice(59,List(InvoiceItem(1,59,57,10.35,1)))
// Invoice(60,List(InvoiceItem(1,60,192,10.35,1), InvoiceItem(2,60,101,10.35,1), InvoiceItem(3,60,181,10.35,1)))
// Invoice(61,List(InvoiceItem(1,61,155,10.35,1), InvoiceItem(2,61,180,10.35,1)))
// Invoice(62,List(InvoiceItem(1,62,112,10.35,1), InvoiceItem(2,62,193,10.35,1), InvoiceItem(3,62,89,10.35,1), InvoiceItem(4,62,83,10.35,1)))
// Invoice(63,List(InvoiceItem(1,63,195,10.35,1), InvoiceItem(2,63,161,10.35,1), InvoiceItem(3,63,31,10.35,1), InvoiceItem(4,63,189,10.35,1)))
// Invoice(64,List(InvoiceItem(1,64,171,10.35,1), InvoiceItem(2,64,9,10.35,1), InvoiceItem(3,64,88,10.35,1)))
// Invoice(65,List(InvoiceItem(1,65,86,10.35,1)))
// Invoice(66,List(InvoiceItem(1,66,103,10.35,1)))
// Invoice(67,List(InvoiceItem(1,67,199,10.35,1), InvoiceItem(2,67,85,10.35,1), InvoiceItem(3,67,173,10.35,1)))
// Invoice(68,List(InvoiceItem(1,68,109,10.35,1), InvoiceItem(2,68,83,10.35,1), InvoiceItem(3,68,184,10.35,1), InvoiceItem(4,68,182,10.35,1), InvoiceItem(5,68,179,10.35,1)))
// Invoice(69,List(InvoiceItem(1,69,17,10.35,1)))
// Invoice(70,List(InvoiceItem(1,70,137,10.35,1)))
// Invoice(71,List(InvoiceItem(1,71,148,10.35,1), InvoiceItem(2,71,117,10.35,1), InvoiceItem(3,71,23,10.35,1)))
// Invoice(72,List(InvoiceItem(1,72,6,10.35,1)))
// Invoice(73,List(InvoiceItem(1,73,112,10.35,1), InvoiceItem(2,73,109,10.35,1), InvoiceItem(3,73,39,10.35,1)))
// Invoice(74,List(InvoiceItem(1,74,110,10.35,1)))
// Invoice(75,List(InvoiceItem(1,75,54,10.35,1), InvoiceItem(2,75,101,10.35,1), InvoiceItem(3,75,8,10.35,1)))
// Invoice(76,List(InvoiceItem(1,76,67,10.35,1), InvoiceItem(2,76,132,10.35,1), InvoiceItem(3,76,5,10.35,1)))
// Invoice(77,List(InvoiceItem(1,77,141,10.35,1), InvoiceItem(2,77,122,10.35,1), InvoiceItem(3,77,195,10.35,1), InvoiceItem(4,77,157,10.35,1)))
// Invoice(78,List(InvoiceItem(1,78,134,10.35,1), InvoiceItem(2,78,89,10.35,1), InvoiceItem(3,78,143,10.35,1), InvoiceItem(4,78,59,10.35,1)))
// Invoice(79,List(InvoiceItem(1,79,61,10.35,1)))
// Invoice(80,List(InvoiceItem(1,80,148,10.35,1), InvoiceItem(2,80,11,10.35,1), InvoiceItem(3,80,171,10.35,1)))
// Invoice(81,List(InvoiceItem(1,81,57,10.35,1), InvoiceItem(2,81,24,10.35,1)))
// Invoice(82,List(InvoiceItem(1,82,36,10.35,1), InvoiceItem(2,82,172,10.35,1), InvoiceItem(3,82,172,10.35,1), InvoiceItem(4,82,52,10.35,1), InvoiceItem(5,82,153,10.35,1)))
// Invoice(83,List(InvoiceItem(1,83,133,10.35,1)))
// Invoice(84,List(InvoiceItem(1,84,5,10.35,1), InvoiceItem(2,84,102,10.35,1)))
// Invoice(85,List(InvoiceItem(1,85,195,10.35,1), InvoiceItem(2,85,177,10.35,1)))
// Invoice(86,List(InvoiceItem(1,86,88,10.35,1), InvoiceItem(2,86,39,10.35,1), InvoiceItem(3,86,74,10.35,1), InvoiceItem(4,86,118,10.35,1)))
// Invoice(87,List(InvoiceItem(1,87,139,10.35,1), InvoiceItem(2,87,135,10.35,1), InvoiceItem(3,87,36,10.35,1), InvoiceItem(4,87,193,10.35,1), InvoiceItem(5,87,44,10.35,1)))
// Invoice(88,List(InvoiceItem(1,88,54,10.35,1)))
// Invoice(89,List(InvoiceItem(1,89,119,10.35,1), InvoiceItem(2,89,78,10.35,1)))
// Invoice(90,List(InvoiceItem(1,90,23,10.35,1), InvoiceItem(2,90,101,10.35,1), InvoiceItem(3,90,57,10.35,1), InvoiceItem(4,90,6,10.35,1)))
// Invoice(91,List(InvoiceItem(1,91,49,10.35,1), InvoiceItem(2,91,99,10.35,1), InvoiceItem(3,91,44,10.35,1), InvoiceItem(4,91,5,10.35,1)))
// Invoice(92,List(InvoiceItem(1,92,162,10.35,1), InvoiceItem(2,92,52,10.35,1), InvoiceItem(3,92,181,10.35,1), InvoiceItem(4,92,12,10.35,1)))
// Invoice(93,List(InvoiceItem(1,93,119,10.35,1)))
// Invoice(94,List(InvoiceItem(1,94,85,10.35,1), InvoiceItem(2,94,200,10.35,1), InvoiceItem(3,94,147,10.35,1), InvoiceItem(4,94,177,10.35,1)))
// Invoice(95,List(InvoiceItem(1,95,107,10.35,1), InvoiceItem(2,95,7,10.35,1)))
// Invoice(96,List(InvoiceItem(1,96,73,10.35,1), InvoiceItem(2,96,75,10.35,1), InvoiceItem(3,96,6,10.35,1)))
// Invoice(97,List(InvoiceItem(1,97,82,10.35,1), InvoiceItem(2,97,42,10.35,1)))
// Invoice(98,List(InvoiceItem(1,98,184,10.35,1)))
// Invoice(99,List(InvoiceItem(1,99,72,10.35,1), InvoiceItem(2,99,147,10.35,1)))
// Invoice(100,List(InvoiceItem(1,100,55,10.35,1), InvoiceItem(2,100,18,10.35,1), InvoiceItem(3,100,28,10.35,1), InvoiceItem(4,100,72,10.35,1)))
// Invoice(101,List(InvoiceItem(1,101,82,10.35,1), InvoiceItem(2,101,73,10.35,1), InvoiceItem(3,101,169,10.35,1), InvoiceItem(4,101,36,10.35,1), InvoiceItem(5,101,113,10.35,1)))
// Invoice(102,List(InvoiceItem(1,102,11,10.35,1), InvoiceItem(2,102,17,10.35,1)))
// Invoice(103,List(InvoiceItem(1,103,12,10.35,1), InvoiceItem(2,103,75,10.35,1), InvoiceItem(3,103,166,10.35,1), InvoiceItem(4,103,32,10.35,1), InvoiceItem(5,103,161,10.35,1)))
// Invoice(104,List(InvoiceItem(1,104,161,10.35,1), InvoiceItem(2,104,150,10.35,1), InvoiceItem(3,104,126,10.35,1), InvoiceItem(4,104,144,10.35,1)))
// Invoice(105,List(InvoiceItem(1,105,31,10.35,1), InvoiceItem(2,105,159,10.35,1), InvoiceItem(3,105,31,10.35,1)))
// Invoice(106,List(InvoiceItem(1,106,100,10.35,1), InvoiceItem(2,106,141,10.35,1)))
// Invoice(107,List(InvoiceItem(1,107,45,10.35,1), InvoiceItem(2,107,164,10.35,1), InvoiceItem(3,107,37,10.35,1)))
// Invoice(108,List(InvoiceItem(1,108,56,10.35,1), InvoiceItem(2,108,168,10.35,1)))
// Invoice(109,List(InvoiceItem(1,109,109,10.35,1), InvoiceItem(2,109,32,10.35,1), InvoiceItem(3,109,125,10.35,1), InvoiceItem(4,109,63,10.35,1)))
// Invoice(110,List(InvoiceItem(1,110,175,10.35,1), InvoiceItem(2,110,178,10.35,1)))
// Invoice(111,List(InvoiceItem(1,111,159,10.35,1), InvoiceItem(2,111,54,10.35,1)))
// Invoice(112,List(InvoiceItem(1,112,197,10.35,1), InvoiceItem(2,112,20,10.35,1), InvoiceItem(3,112,17,10.35,1)))
// Invoice(113,List(InvoiceItem(1,113,35,10.35,1)))
// Invoice(114,List(InvoiceItem(1,114,182,10.35,1), InvoiceItem(2,114,2,10.35,1), InvoiceItem(3,114,24,10.35,1), InvoiceItem(4,114,25,10.35,1)))
// Invoice(115,List(InvoiceItem(1,115,179,10.35,1), InvoiceItem(2,115,122,10.35,1), InvoiceItem(3,115,17,10.35,1), InvoiceItem(4,115,156,10.35,1)))
// Invoice(116,List(InvoiceItem(1,116,98,10.35,1), InvoiceItem(2,116,97,10.35,1), InvoiceItem(3,116,14,10.35,1), InvoiceItem(4,116,194,10.35,1), InvoiceItem(5,116,185,10.35,1)))
// Invoice(117,List(InvoiceItem(1,117,155,10.35,1), InvoiceItem(2,117,127,10.35,1)))
// Invoice(118,List(InvoiceItem(1,118,16,10.35,1), InvoiceItem(2,118,42,10.35,1), InvoiceItem(3,118,199,10.35,1), InvoiceItem(4,118,115,10.35,1), InvoiceItem(5,118,56,10.35,1)))
// Invoice(119,List(InvoiceItem(1,119,153,10.35,1), InvoiceItem(2,119,24,10.35,1), InvoiceItem(3,119,86,10.35,1), InvoiceItem(4,119,91,10.35,1), InvoiceItem(5,119,58,10.35,1)))
// Invoice(120,List(InvoiceItem(1,120,137,10.35,1), InvoiceItem(2,120,65,10.35,1), InvoiceItem(3,120,109,10.35,1), InvoiceItem(4,120,21,10.35,1)))
// Invoice(121,List(InvoiceItem(1,121,22,10.35,1), InvoiceItem(2,121,15,10.35,1), InvoiceItem(3,121,157,10.35,1), InvoiceItem(4,121,162,10.35,1), InvoiceItem(5,121,130,10.35,1)))
// Invoice(122,List(InvoiceItem(1,122,136,10.35,1), InvoiceItem(2,122,191,10.35,1), InvoiceItem(3,122,57,10.35,1), InvoiceItem(4,122,34,10.35,1)))
// Invoice(123,List(InvoiceItem(1,123,150,10.35,1), InvoiceItem(2,123,34,10.35,1), InvoiceItem(3,123,133,10.35,1), InvoiceItem(4,123,14,10.35,1)))
// Invoice(124,List(InvoiceItem(1,124,136,10.35,1)))
// Invoice(125,List(InvoiceItem(1,125,56,10.35,1), InvoiceItem(2,125,138,10.35,1), InvoiceItem(3,125,95,10.35,1), InvoiceItem(4,125,7,10.35,1), InvoiceItem(5,125,182,10.35,1)))
// Invoice(126,List(InvoiceItem(1,126,36,10.35,1), InvoiceItem(2,126,171,10.35,1)))
// Invoice(127,List(InvoiceItem(1,127,191,10.35,1), InvoiceItem(2,127,33,10.35,1), InvoiceItem(3,127,14,10.35,1)))
// Invoice(128,List(InvoiceItem(1,128,109,10.35,1), InvoiceItem(2,128,44,10.35,1), InvoiceItem(3,128,37,10.35,1), InvoiceItem(4,128,90,10.35,1)))
// Invoice(129,List(InvoiceItem(1,129,75,10.35,1), InvoiceItem(2,129,32,10.35,1)))
// Invoice(130,List(InvoiceItem(1,130,136,10.35,1), InvoiceItem(2,130,118,10.35,1), InvoiceItem(3,130,85,10.35,1)))
// Invoice(131,List(InvoiceItem(1,131,2,10.35,1), InvoiceItem(2,131,160,10.35,1), InvoiceItem(3,131,194,10.35,1)))
// Invoice(132,List(InvoiceItem(1,132,104,10.35,1)))
// Invoice(133,List(InvoiceItem(1,133,99,10.35,1), InvoiceItem(2,133,90,10.35,1), InvoiceItem(3,133,73,10.35,1), InvoiceItem(4,133,168,10.35,1)))
// Invoice(134,List(InvoiceItem(1,134,179,10.35,1), InvoiceItem(2,134,130,10.35,1)))
// Invoice(135,List(InvoiceItem(1,135,169,10.35,1), InvoiceItem(2,135,187,10.35,1), InvoiceItem(3,135,123,10.35,1), InvoiceItem(4,135,42,10.35,1)))
// Invoice(136,List(InvoiceItem(1,136,50,10.35,1), InvoiceItem(2,136,182,10.35,1)))
// Invoice(137,List(InvoiceItem(1,137,8,10.35,1), InvoiceItem(2,137,86,10.35,1), InvoiceItem(3,137,113,10.35,1), InvoiceItem(4,137,65,10.35,1)))
// Invoice(138,List(InvoiceItem(1,138,126,10.35,1), InvoiceItem(2,138,129,10.35,1)))
// Invoice(139,List(InvoiceItem(1,139,111,10.35,1)))
// Invoice(140,List(InvoiceItem(1,140,46,10.35,1), InvoiceItem(2,140,2,10.35,1)))
// Invoice(141,List(InvoiceItem(1,141,27,10.35,1)))
// Invoice(142,List(InvoiceItem(1,142,73,10.35,1), InvoiceItem(2,142,99,10.35,1), InvoiceItem(3,142,140,10.35,1), InvoiceItem(4,142,97,10.35,1)))
// Invoice(143,List(InvoiceItem(1,143,38,10.35,1), InvoiceItem(2,143,74,10.35,1), InvoiceItem(3,143,84,10.35,1), InvoiceItem(4,143,27,10.35,1)))
// Invoice(144,List(InvoiceItem(1,144,149,10.35,1), InvoiceItem(2,144,49,10.35,1), InvoiceItem(3,144,193,10.35,1)))
// Invoice(145,List(InvoiceItem(1,145,58,10.35,1), InvoiceItem(2,145,91,10.35,1), InvoiceItem(3,145,179,10.35,1), InvoiceItem(4,145,62,10.35,1)))
// Invoice(146,List(InvoiceItem(1,146,31,10.35,1), InvoiceItem(2,146,195,10.35,1), InvoiceItem(3,146,85,10.35,1), InvoiceItem(4,146,134,10.35,1), InvoiceItem(5,146,190,10.35,1)))
// Invoice(147,List(InvoiceItem(1,147,123,10.35,1), InvoiceItem(2,147,199,10.35,1), InvoiceItem(3,147,87,10.35,1)))
// Invoice(148,List(InvoiceItem(1,148,90,10.35,1), InvoiceItem(2,148,99,10.35,1)))
// Invoice(149,List(InvoiceItem(1,149,188,10.35,1), InvoiceItem(2,149,7,10.35,1)))
// Invoice(150,List(InvoiceItem(1,150,182,10.35,1), InvoiceItem(2,150,95,10.35,1), InvoiceItem(3,150,152,10.35,1), InvoiceItem(4,150,64,10.35,1)))
// Invoice(151,List(InvoiceItem(1,151,169,10.35,1), InvoiceItem(2,151,171,10.35,1), InvoiceItem(3,151,56,10.35,1), InvoiceItem(4,151,53,10.35,1), InvoiceItem(5,151,81,10.35,1)))
// Invoice(152,List(InvoiceItem(1,152,141,10.35,1), InvoiceItem(2,152,149,10.35,1)))
// Invoice(153,List(InvoiceItem(1,153,177,10.35,1), InvoiceItem(2,153,199,10.35,1), InvoiceItem(3,153,188,10.35,1), InvoiceItem(4,153,42,10.35,1), InvoiceItem(5,153,16,10.35,1)))
// Invoice(154,List(InvoiceItem(1,154,161,10.35,1), InvoiceItem(2,154,159,10.35,1)))
// Invoice(155,List(InvoiceItem(1,155,38,10.35,1), InvoiceItem(2,155,79,10.35,1), InvoiceItem(3,155,127,10.35,1), InvoiceItem(4,155,117,10.35,1), InvoiceItem(5,155,80,10.35,1)))
// Invoice(156,List(InvoiceItem(1,156,97,10.35,1), InvoiceItem(2,156,43,10.35,1)))
// Invoice(157,List(InvoiceItem(1,157,180,10.35,1), InvoiceItem(2,157,70,10.35,1)))
// Invoice(158,List(InvoiceItem(1,158,112,10.35,1), InvoiceItem(2,158,5,10.35,1)))
// Invoice(159,List(InvoiceItem(1,159,175,10.35,1), InvoiceItem(2,159,129,10.35,1), InvoiceItem(3,159,178,10.35,1), InvoiceItem(4,159,103,10.35,1)))
// Invoice(160,List(InvoiceItem(1,160,168,10.35,1), InvoiceItem(2,160,195,10.35,1), InvoiceItem(3,160,27,10.35,1), InvoiceItem(4,160,110,10.35,1)))
// Invoice(161,List(InvoiceItem(1,161,164,10.35,1), InvoiceItem(2,161,132,10.35,1)))
// Invoice(162,List(InvoiceItem(1,162,188,10.35,1), InvoiceItem(2,162,137,10.35,1), InvoiceItem(3,162,7,10.35,1), InvoiceItem(4,162,141,10.35,1)))
// Invoice(163,List(InvoiceItem(1,163,75,10.35,1), InvoiceItem(2,163,59,10.35,1)))
// Invoice(164,List(InvoiceItem(1,164,182,10.35,1)))
// Invoice(165,List(InvoiceItem(1,165,92,10.35,1), InvoiceItem(2,165,90,10.35,1), InvoiceItem(3,165,107,10.35,1)))
// Invoice(166,List(InvoiceItem(1,166,120,10.35,1)))
// Invoice(167,List(InvoiceItem(1,167,71,10.35,1), InvoiceItem(2,167,75,10.35,1), InvoiceItem(3,167,189,10.35,1), InvoiceItem(4,167,184,10.35,1), InvoiceItem(5,167,186,10.35,1)))
// Invoice(168,List(InvoiceItem(1,168,13,10.35,1), InvoiceItem(2,168,158,10.35,1), InvoiceItem(3,168,191,10.35,1), InvoiceItem(4,168,70,10.35,1)))
// Invoice(169,List(InvoiceItem(1,169,17,10.35,1), InvoiceItem(2,169,33,10.35,1)))
// Invoice(170,List(InvoiceItem(1,170,133,10.35,1), InvoiceItem(2,170,95,10.35,1)))
// Invoice(171,List(InvoiceItem(1,171,56,10.35,1)))
// Invoice(172,List(InvoiceItem(1,172,105,10.35,1), InvoiceItem(2,172,71,10.35,1), InvoiceItem(3,172,184,10.35,1), InvoiceItem(4,172,138,10.35,1)))
// Invoice(173,List(InvoiceItem(1,173,18,10.35,1), InvoiceItem(2,173,53,10.35,1), InvoiceItem(3,173,73,10.35,1), InvoiceItem(4,173,49,10.35,1)))
// Invoice(174,List(InvoiceItem(1,174,187,10.35,1), InvoiceItem(2,174,59,10.35,1), InvoiceItem(3,174,136,10.35,1), InvoiceItem(4,174,33,10.35,1)))
// Invoice(175,List(InvoiceItem(1,175,76,10.35,1), InvoiceItem(2,175,194,10.35,1), InvoiceItem(3,175,121,10.35,1)))
// Invoice(176,List(InvoiceItem(1,176,98,10.35,1), InvoiceItem(2,176,51,10.35,1), InvoiceItem(3,176,30,10.35,1)))
// Invoice(177,List(InvoiceItem(1,177,26,10.35,1), InvoiceItem(2,177,45,10.35,1), InvoiceItem(3,177,119,10.35,1)))
// Invoice(178,List(InvoiceItem(1,178,39,10.35,1), InvoiceItem(2,178,65,10.35,1)))
// Invoice(179,List(InvoiceItem(1,179,138,10.35,1), InvoiceItem(2,179,81,10.35,1), InvoiceItem(3,179,113,10.35,1)))
// Invoice(180,List(InvoiceItem(1,180,168,10.35,1)))
// Invoice(181,List(InvoiceItem(1,181,41,10.35,1), InvoiceItem(2,181,152,10.35,1)))
// Invoice(182,List(InvoiceItem(1,182,196,10.35,1), InvoiceItem(2,182,164,10.35,1)))
// Invoice(183,List(InvoiceItem(1,183,196,10.35,1), InvoiceItem(2,183,27,10.35,1), InvoiceItem(3,183,163,10.35,1), InvoiceItem(4,183,89,10.35,1)))
// Invoice(184,List(InvoiceItem(1,184,109,10.35,1), InvoiceItem(2,184,8,10.35,1), InvoiceItem(3,184,41,10.35,1)))
// Invoice(185,List(InvoiceItem(1,185,72,10.35,1), InvoiceItem(2,185,193,10.35,1)))
// Invoice(186,List(InvoiceItem(1,186,17,10.35,1), InvoiceItem(2,186,35,10.35,1), InvoiceItem(3,186,200,10.35,1), InvoiceItem(4,186,11,10.35,1)))
// Invoice(187,List(InvoiceItem(1,187,81,10.35,1), InvoiceItem(2,187,182,10.35,1), InvoiceItem(3,187,63,10.35,1), InvoiceItem(4,187,117,10.35,1)))
// Invoice(188,List(InvoiceItem(1,188,103,10.35,1), InvoiceItem(2,188,171,10.35,1)))
// Invoice(189,List(InvoiceItem(1,189,10,10.35,1), InvoiceItem(2,189,145,10.35,1), InvoiceItem(3,189,132,10.35,1)))
// Invoice(190,List(InvoiceItem(1,190,9,10.35,1)))
// Invoice(191,List(InvoiceItem(1,191,195,10.35,1), InvoiceItem(2,191,183,10.35,1), InvoiceItem(3,191,75,10.35,1)))
// Invoice(192,List(InvoiceItem(1,192,172,10.35,1), InvoiceItem(2,192,9,10.35,1)))
// Invoice(193,List(InvoiceItem(1,193,87,10.35,1)))
// Invoice(194,List(InvoiceItem(1,194,166,10.35,1), InvoiceItem(2,194,75,10.35,1), InvoiceItem(3,194,84,10.35,1), InvoiceItem(4,194,130,10.35,1)))
// Invoice(195,List(InvoiceItem(1,195,160,10.35,1), InvoiceItem(2,195,180,10.35,1), InvoiceItem(3,195,66,10.35,1)))
// Invoice(196,List(InvoiceItem(1,196,36,10.35,1), InvoiceItem(2,196,105,10.35,1), InvoiceItem(3,196,39,10.35,1), InvoiceItem(4,196,170,10.35,1)))
// Invoice(197,List(InvoiceItem(1,197,145,10.35,1), InvoiceItem(2,197,38,10.35,1)))
// Invoice(198,List(InvoiceItem(1,198,180,10.35,1), InvoiceItem(2,198,9,10.35,1), InvoiceItem(3,198,137,10.35,1), InvoiceItem(4,198,178,10.35,1)))
// Invoice(199,List(InvoiceItem(1,199,118,10.35,1), InvoiceItem(2,199,62,10.35,1), InvoiceItem(3,199,6,10.35,1), InvoiceItem(4,199,127,10.35,1), InvoiceItem(5,199,130,10.35,1)))
// Invoice(200,List(InvoiceItem(1,200,54,10.35,1), InvoiceItem(2,200,177,10.35,1), InvoiceItem(3,200,188,10.35,1)))
// Invoice(201,List(InvoiceItem(1,201,75,10.35,1), InvoiceItem(2,201,127,10.35,1), InvoiceItem(3,201,128,10.35,1), InvoiceItem(4,201,183,10.35,1)))
// Invoice(202,List(InvoiceItem(1,202,21,10.35,1), InvoiceItem(2,202,110,10.35,1), InvoiceItem(3,202,142,10.35,1)))
// Invoice(203,List(InvoiceItem(1,203,158,10.35,1), InvoiceItem(2,203,79,10.35,1), InvoiceItem(3,203,136,10.35,1)))
// Invoice(204,List(InvoiceItem(1,204,87,10.35,1), InvoiceItem(2,204,193,10.35,1), InvoiceItem(3,204,173,10.35,1), InvoiceItem(4,204,162,10.35,1)))
// Invoice(205,List(InvoiceItem(1,205,99,10.35,1)))
// Invoice(206,List(InvoiceItem(1,206,132,10.35,1), InvoiceItem(2,206,176,10.35,1), InvoiceItem(3,206,44,10.35,1), InvoiceItem(4,206,105,10.35,1)))
// Invoice(207,List(InvoiceItem(1,207,164,10.35,1), InvoiceItem(2,207,151,10.35,1), InvoiceItem(3,207,154,10.35,1), InvoiceItem(4,207,76,10.35,1), InvoiceItem(5,207,3,10.35,1)))
// Invoice(208,List(InvoiceItem(1,208,15,10.35,1), InvoiceItem(2,208,89,10.35,1), InvoiceItem(3,208,73,10.35,1)))
// Invoice(209,List(InvoiceItem(1,209,156,10.35,1), InvoiceItem(2,209,15,10.35,1)))
// Invoice(210,List(InvoiceItem(1,210,113,10.35,1), InvoiceItem(2,210,197,10.35,1), InvoiceItem(3,210,68,10.35,1), InvoiceItem(4,210,155,10.35,1), InvoiceItem(5,210,42,10.35,1)))
// Invoice(211,List(InvoiceItem(1,211,200,10.35,1), InvoiceItem(2,211,128,10.35,1), InvoiceItem(3,211,163,10.35,1), InvoiceItem(4,211,2,10.35,1)))
// Invoice(212,List(InvoiceItem(1,212,132,10.35,1), InvoiceItem(2,212,173,10.35,1), InvoiceItem(3,212,168,10.35,1)))
// Invoice(213,List(InvoiceItem(1,213,186,10.35,1)))
// Invoice(214,List(InvoiceItem(1,214,176,10.35,1), InvoiceItem(2,214,155,10.35,1)))
// Invoice(215,List(InvoiceItem(1,215,27,10.35,1), InvoiceItem(2,215,109,10.35,1), InvoiceItem(3,215,48,10.35,1), InvoiceItem(4,215,48,10.35,1)))
// Invoice(216,List(InvoiceItem(1,216,188,10.35,1), InvoiceItem(2,216,13,10.35,1), InvoiceItem(3,216,61,10.35,1), InvoiceItem(4,216,125,10.35,1)))
// Invoice(217,List(InvoiceItem(1,217,150,10.35,1), InvoiceItem(2,217,15,10.35,1)))
// Invoice(218,List(InvoiceItem(1,218,138,10.35,1), InvoiceItem(2,218,177,10.35,1)))
// Invoice(219,List(InvoiceItem(1,219,96,10.35,1), InvoiceItem(2,219,99,10.35,1)))
// Invoice(220,List(InvoiceItem(1,220,78,10.35,1), InvoiceItem(2,220,53,10.35,1), InvoiceItem(3,220,171,10.35,1), InvoiceItem(4,220,19,10.35,1), InvoiceItem(5,220,116,10.35,1)))
// Invoice(221,List(InvoiceItem(1,221,106,10.35,1), InvoiceItem(2,221,163,10.35,1)))
// Invoice(222,List(InvoiceItem(1,222,32,10.35,1), InvoiceItem(2,222,96,10.35,1), InvoiceItem(3,222,122,10.35,1), InvoiceItem(4,222,23,10.35,1)))
// Invoice(223,List(InvoiceItem(1,223,163,10.35,1), InvoiceItem(2,223,165,10.35,1), InvoiceItem(3,223,28,10.35,1), InvoiceItem(4,223,141,10.35,1), InvoiceItem(5,223,157,10.35,1)))
// Invoice(224,List(InvoiceItem(1,224,125,10.35,1), InvoiceItem(2,224,62,10.35,1), InvoiceItem(3,224,38,10.35,1)))
// Invoice(225,List(InvoiceItem(1,225,44,10.35,1), InvoiceItem(2,225,38,10.35,1), InvoiceItem(3,225,25,10.35,1)))
// Invoice(226,List(InvoiceItem(1,226,27,10.35,1), InvoiceItem(2,226,77,10.35,1), InvoiceItem(3,226,37,10.35,1)))
// Invoice(227,List(InvoiceItem(1,227,197,10.35,1)))
// Invoice(228,List(InvoiceItem(1,228,138,10.35,1), InvoiceItem(2,228,80,10.35,1), InvoiceItem(3,228,195,10.35,1)))
// Invoice(229,List(InvoiceItem(1,229,158,10.35,1), InvoiceItem(2,229,199,10.35,1)))
// Invoice(230,List(InvoiceItem(1,230,182,10.35,1), InvoiceItem(2,230,28,10.35,1)))
// Invoice(231,List(InvoiceItem(1,231,93,10.35,1), InvoiceItem(2,231,148,10.35,1), InvoiceItem(3,231,55,10.35,1), InvoiceItem(4,231,136,10.35,1), InvoiceItem(5,231,19,10.35,1)))
// Invoice(232,List(InvoiceItem(1,232,160,10.35,1)))
// Invoice(233,List(InvoiceItem(1,233,40,10.35,1)))
// Invoice(234,List(InvoiceItem(1,234,146,10.35,1), InvoiceItem(2,234,191,10.35,1), InvoiceItem(3,234,137,10.35,1)))
// Invoice(235,List(InvoiceItem(1,235,166,10.35,1), InvoiceItem(2,235,9,10.35,1)))
// Invoice(236,List(InvoiceItem(1,236,171,10.35,1), InvoiceItem(2,236,16,10.35,1)))
// Invoice(237,List(InvoiceItem(1,237,121,10.35,1)))
// Invoice(238,List(InvoiceItem(1,238,85,10.35,1), InvoiceItem(2,238,69,10.35,1), InvoiceItem(3,238,133,10.35,1), InvoiceItem(4,238,175,10.35,1)))
// Invoice(239,List(InvoiceItem(1,239,4,10.35,1), InvoiceItem(2,239,85,10.35,1)))
// Invoice(240,List(InvoiceItem(1,240,39,10.35,1)))
// Invoice(241,List(InvoiceItem(1,241,163,10.35,1)))
// Invoice(242,List(InvoiceItem(1,242,126,10.35,1), InvoiceItem(2,242,93,10.35,1), InvoiceItem(3,242,153,10.35,1), InvoiceItem(4,242,108,10.35,1)))
// Invoice(243,List(InvoiceItem(1,243,109,10.35,1), InvoiceItem(2,243,103,10.35,1), InvoiceItem(3,243,30,10.35,1), InvoiceItem(4,243,86,10.35,1), InvoiceItem(5,243,186,10.35,1)))
// Invoice(244,List(InvoiceItem(1,244,66,10.35,1)))
// Invoice(245,List(InvoiceItem(1,245,99,10.35,1), InvoiceItem(2,245,116,10.35,1), InvoiceItem(3,245,104,10.35,1), InvoiceItem(4,245,160,10.35,1)))
// Invoice(246,List(InvoiceItem(1,246,142,10.35,1), InvoiceItem(2,246,194,10.35,1), InvoiceItem(3,246,127,10.35,1), InvoiceItem(4,246,94,10.35,1), InvoiceItem(5,246,23,10.35,1)))
// Invoice(247,List(InvoiceItem(1,247,83,10.35,1), InvoiceItem(2,247,29,10.35,1)))
// Invoice(248,List(InvoiceItem(1,248,164,10.35,1), InvoiceItem(2,248,183,10.35,1), InvoiceItem(3,248,179,10.35,1), InvoiceItem(4,248,78,10.35,1), InvoiceItem(5,248,15,10.35,1)))
// Invoice(249,List(InvoiceItem(1,249,39,10.35,1), InvoiceItem(2,249,130,10.35,1), InvoiceItem(3,249,105,10.35,1)))
// Invoice(250,List(InvoiceItem(1,250,90,10.35,1)))
// Invoice(251,List(InvoiceItem(1,251,126,10.35,1), InvoiceItem(2,251,85,10.35,1), InvoiceItem(3,251,19,10.35,1)))
// Invoice(252,List(InvoiceItem(1,252,42,10.35,1)))
// Invoice(253,List(InvoiceItem(1,253,12,10.35,1), InvoiceItem(2,253,49,10.35,1), InvoiceItem(3,253,103,10.35,1)))
// Invoice(254,List(InvoiceItem(1,254,68,10.35,1), InvoiceItem(2,254,80,10.35,1), InvoiceItem(3,254,55,10.35,1)))
// Invoice(255,List(InvoiceItem(1,255,150,10.35,1), InvoiceItem(2,255,124,10.35,1), InvoiceItem(3,255,136,10.35,1), InvoiceItem(4,255,51,10.35,1), InvoiceItem(5,255,135,10.35,1)))
// Invoice(256,List(InvoiceItem(1,256,29,10.35,1)))
// Invoice(257,List(InvoiceItem(1,257,109,10.35,1), InvoiceItem(2,257,65,10.35,1), InvoiceItem(3,257,17,10.35,1), InvoiceItem(4,257,92,10.35,1), InvoiceItem(5,257,50,10.35,1)))
// Invoice(258,List(InvoiceItem(1,258,70,10.35,1), InvoiceItem(2,258,112,10.35,1), InvoiceItem(3,258,176,10.35,1), InvoiceItem(4,258,95,10.35,1)))
// Invoice(259,List(InvoiceItem(1,259,4,10.35,1), InvoiceItem(2,259,95,10.35,1), InvoiceItem(3,259,167,10.35,1), InvoiceItem(4,259,109,10.35,1)))
// Invoice(260,List(InvoiceItem(1,260,161,10.35,1), InvoiceItem(2,260,136,10.35,1)))
// Invoice(261,List(InvoiceItem(1,261,190,10.35,1), InvoiceItem(2,261,46,10.35,1), InvoiceItem(3,261,178,10.35,1), InvoiceItem(4,261,70,10.35,1), InvoiceItem(5,261,65,10.35,1)))
// Invoice(262,List(InvoiceItem(1,262,177,10.35,1), InvoiceItem(2,262,114,10.35,1), InvoiceItem(3,262,86,10.35,1), InvoiceItem(4,262,182,10.35,1)))
// Invoice(263,List(InvoiceItem(1,263,82,10.35,1)))
// Invoice(264,List(InvoiceItem(1,264,140,10.35,1), InvoiceItem(2,264,24,10.35,1), InvoiceItem(3,264,11,10.35,1)))
// Invoice(265,List(InvoiceItem(1,265,140,10.35,1), InvoiceItem(2,265,140,10.35,1)))
// Invoice(266,List(InvoiceItem(1,266,159,10.35,1), InvoiceItem(2,266,92,10.35,1), InvoiceItem(3,266,102,10.35,1), InvoiceItem(4,266,90,10.35,1), InvoiceItem(5,266,199,10.35,1)))
// Invoice(267,List(InvoiceItem(1,267,43,10.35,1), InvoiceItem(2,267,165,10.35,1), InvoiceItem(3,267,113,10.35,1)))
// Invoice(268,List(InvoiceItem(1,268,141,10.35,1), InvoiceItem(2,268,52,10.35,1)))
// Invoice(269,List(InvoiceItem(1,269,199,10.35,1), InvoiceItem(2,269,178,10.35,1), InvoiceItem(3,269,13,10.35,1)))
// Invoice(270,List(InvoiceItem(1,270,48,10.35,1), InvoiceItem(2,270,129,10.35,1), InvoiceItem(3,270,70,10.35,1), InvoiceItem(4,270,62,10.35,1)))
// Invoice(271,List(InvoiceItem(1,271,1,10.35,1), InvoiceItem(2,271,38,10.35,1), InvoiceItem(3,271,120,10.35,1), InvoiceItem(4,271,157,10.35,1)))
// Invoice(272,List(InvoiceItem(1,272,1,10.35,1), InvoiceItem(2,272,93,10.35,1), InvoiceItem(3,272,70,10.35,1), InvoiceItem(4,272,117,10.35,1), InvoiceItem(5,272,196,10.35,1)))
// Invoice(273,List(InvoiceItem(1,273,195,10.35,1), InvoiceItem(2,273,188,10.35,1)))
// Invoice(274,List(InvoiceItem(1,274,169,10.35,1), InvoiceItem(2,274,157,10.35,1), InvoiceItem(3,274,35,10.35,1), InvoiceItem(4,274,167,10.35,1)))
// Invoice(275,List(InvoiceItem(1,275,171,10.35,1), InvoiceItem(2,275,37,10.35,1), InvoiceItem(3,275,34,10.35,1), InvoiceItem(4,275,166,10.35,1), InvoiceItem(5,275,4,10.35,1)))
// Invoice(276,List(InvoiceItem(1,276,142,10.35,1), InvoiceItem(2,276,71,10.35,1)))
// Invoice(277,List(InvoiceItem(1,277,128,10.35,1), InvoiceItem(2,277,123,10.35,1), InvoiceItem(3,277,40,10.35,1)))
// Invoice(278,List(InvoiceItem(1,278,147,10.35,1), InvoiceItem(2,278,191,10.35,1)))
// Invoice(279,List(InvoiceItem(1,279,2,10.35,1), InvoiceItem(2,279,13,10.35,1)))
// Invoice(280,List(InvoiceItem(1,280,69,10.35,1), InvoiceItem(2,280,150,10.35,1), InvoiceItem(3,280,194,10.35,1), InvoiceItem(4,280,3,10.35,1), InvoiceItem(5,280,185,10.35,1)))
// Invoice(281,List(InvoiceItem(1,281,42,10.35,1), InvoiceItem(2,281,36,10.35,1), InvoiceItem(3,281,191,10.35,1), InvoiceItem(4,281,32,10.35,1)))
// Invoice(282,List(InvoiceItem(1,282,95,10.35,1), InvoiceItem(2,282,15,10.35,1), InvoiceItem(3,282,104,10.35,1)))
// Invoice(283,List(InvoiceItem(1,283,90,10.35,1), InvoiceItem(2,283,33,10.35,1), InvoiceItem(3,283,113,10.35,1)))
// Invoice(284,List(InvoiceItem(1,284,125,10.35,1), InvoiceItem(2,284,81,10.35,1), InvoiceItem(3,284,82,10.35,1), InvoiceItem(4,284,75,10.35,1), InvoiceItem(5,284,170,10.35,1)))
// Invoice(285,List(InvoiceItem(1,285,180,10.35,1), InvoiceItem(2,285,119,10.35,1), InvoiceItem(3,285,79,10.35,1)))
// Invoice(286,List(InvoiceItem(1,286,193,10.35,1)))
// Invoice(287,List(InvoiceItem(1,287,107,10.35,1), InvoiceItem(2,287,104,10.35,1)))
// Invoice(288,List(InvoiceItem(1,288,149,10.35,1), InvoiceItem(2,288,164,10.35,1), InvoiceItem(3,288,68,10.35,1)))
// Invoice(289,List(InvoiceItem(1,289,6,10.35,1), InvoiceItem(2,289,134,10.35,1), InvoiceItem(3,289,61,10.35,1)))
// Invoice(290,List(InvoiceItem(1,290,104,10.35,1), InvoiceItem(2,290,96,10.35,1), InvoiceItem(3,290,55,10.35,1), InvoiceItem(4,290,145,10.35,1)))
// Invoice(291,List(InvoiceItem(1,291,169,10.35,1), InvoiceItem(2,291,9,10.35,1), InvoiceItem(3,291,17,10.35,1), InvoiceItem(4,291,158,10.35,1), InvoiceItem(5,291,80,10.35,1)))
// Invoice(292,List(InvoiceItem(1,292,103,10.35,1), InvoiceItem(2,292,61,10.35,1), InvoiceItem(3,292,41,10.35,1)))
// Invoice(293,List(InvoiceItem(1,293,76,10.35,1)))
// Invoice(294,List(InvoiceItem(1,294,3,10.35,1), InvoiceItem(2,294,191,10.35,1), InvoiceItem(3,294,29,10.35,1), InvoiceItem(4,294,67,10.35,1)))
// Invoice(295,List(InvoiceItem(1,295,130,10.35,1), InvoiceItem(2,295,143,10.35,1), InvoiceItem(3,295,67,10.35,1), InvoiceItem(4,295,154,10.35,1), InvoiceItem(5,295,112,10.35,1)))
// Invoice(296,List(InvoiceItem(1,296,132,10.35,1), InvoiceItem(2,296,66,10.35,1), InvoiceItem(3,296,150,10.35,1)))
// Invoice(297,List(InvoiceItem(1,297,4,10.35,1), InvoiceItem(2,297,63,10.35,1)))
// Invoice(298,List(InvoiceItem(1,298,25,10.35,1), InvoiceItem(2,298,146,10.35,1), InvoiceItem(3,298,178,10.35,1), InvoiceItem(4,298,129,10.35,1)))
// Invoice(299,List(InvoiceItem(1,299,81,10.35,1), InvoiceItem(2,299,105,10.35,1), InvoiceItem(3,299,126,10.35,1)))
// Invoice(300,List(InvoiceItem(1,300,155,10.35,1), InvoiceItem(2,300,91,10.35,1)))
// Invoice(301,List(InvoiceItem(1,301,165,10.35,1)))
// Invoice(302,List(InvoiceItem(1,302,14,10.35,1), InvoiceItem(2,302,124,10.35,1), InvoiceItem(3,302,185,10.35,1)))
// Invoice(303,List(InvoiceItem(1,303,197,10.35,1), InvoiceItem(2,303,174,10.35,1), InvoiceItem(3,303,48,10.35,1), InvoiceItem(4,303,88,10.35,1)))
// Invoice(304,List(InvoiceItem(1,304,58,10.35,1), InvoiceItem(2,304,24,10.35,1), InvoiceItem(3,304,174,10.35,1), InvoiceItem(4,304,147,10.35,1)))
// Invoice(305,List(InvoiceItem(1,305,121,10.35,1), InvoiceItem(2,305,155,10.35,1), InvoiceItem(3,305,121,10.35,1), InvoiceItem(4,305,62,10.35,1)))
// Invoice(306,List(InvoiceItem(1,306,124,10.35,1)))
// Invoice(307,List(InvoiceItem(1,307,86,10.35,1)))
// Invoice(308,List(InvoiceItem(1,308,133,10.35,1), InvoiceItem(2,308,86,10.35,1), InvoiceItem(3,308,161,10.35,1), InvoiceItem(4,308,197,10.35,1), InvoiceItem(5,308,8,10.35,1)))
// Invoice(309,List(InvoiceItem(1,309,23,10.35,1), InvoiceItem(2,309,59,10.35,1), InvoiceItem(3,309,101,10.35,1), InvoiceItem(4,309,158,10.35,1), InvoiceItem(5,309,133,10.35,1)))
// Invoice(310,List(InvoiceItem(1,310,42,10.35,1), InvoiceItem(2,310,69,10.35,1)))
// Invoice(311,List(InvoiceItem(1,311,134,10.35,1), InvoiceItem(2,311,72,10.35,1), InvoiceItem(3,311,131,10.35,1)))
// Invoice(312,List(InvoiceItem(1,312,173,10.35,1)))
// Invoice(313,List(InvoiceItem(1,313,150,10.35,1), InvoiceItem(2,313,28,10.35,1), InvoiceItem(3,313,159,10.35,1)))
// Invoice(314,List(InvoiceItem(1,314,95,10.35,1), InvoiceItem(2,314,125,10.35,1), InvoiceItem(3,314,77,10.35,1), InvoiceItem(4,314,147,10.35,1), InvoiceItem(5,314,146,10.35,1)))
// Invoice(315,List(InvoiceItem(1,315,198,10.35,1), InvoiceItem(2,315,6,10.35,1), InvoiceItem(3,315,128,10.35,1), InvoiceItem(4,315,144,10.35,1), InvoiceItem(5,315,70,10.35,1)))
// Invoice(316,List(InvoiceItem(1,316,176,10.35,1)))
// Invoice(317,List(InvoiceItem(1,317,89,10.35,1), InvoiceItem(2,317,32,10.35,1), InvoiceItem(3,317,93,10.35,1), InvoiceItem(4,317,38,10.35,1), InvoiceItem(5,317,118,10.35,1)))
// Invoice(318,List(InvoiceItem(1,318,121,10.35,1), InvoiceItem(2,318,62,10.35,1), InvoiceItem(3,318,174,10.35,1), InvoiceItem(4,318,79,10.35,1)))
// Invoice(319,List(InvoiceItem(1,319,20,10.35,1), InvoiceItem(2,319,68,10.35,1), InvoiceItem(3,319,84,10.35,1)))
// Invoice(320,List(InvoiceItem(1,320,57,10.35,1), InvoiceItem(2,320,14,10.35,1), InvoiceItem(3,320,63,10.35,1)))
// Invoice(321,List(InvoiceItem(1,321,22,10.35,1), InvoiceItem(2,321,193,10.35,1), InvoiceItem(3,321,101,10.35,1)))
// Invoice(322,List(InvoiceItem(1,322,94,10.35,1), InvoiceItem(2,322,132,10.35,1)))
// Invoice(323,List(InvoiceItem(1,323,94,10.35,1)))
// Invoice(324,List(InvoiceItem(1,324,195,10.35,1)))
// Invoice(325,List(InvoiceItem(1,325,60,10.35,1), InvoiceItem(2,325,101,10.35,1)))
// Invoice(326,List(InvoiceItem(1,326,154,10.35,1), InvoiceItem(2,326,8,10.35,1), InvoiceItem(3,326,12,10.35,1)))
// Invoice(327,List(InvoiceItem(1,327,116,10.35,1), InvoiceItem(2,327,141,10.35,1)))
// Invoice(328,List(InvoiceItem(1,328,180,10.35,1), InvoiceItem(2,328,17,10.35,1), InvoiceItem(3,328,111,10.35,1)))
// Invoice(329,List(InvoiceItem(1,329,48,10.35,1)))
// Invoice(330,List(InvoiceItem(1,330,6,10.35,1), InvoiceItem(2,330,24,10.35,1), InvoiceItem(3,330,109,10.35,1), InvoiceItem(4,330,115,10.35,1), InvoiceItem(5,330,38,10.35,1)))
// Invoice(331,List(InvoiceItem(1,331,125,10.35,1), InvoiceItem(2,331,46,10.35,1), InvoiceItem(3,331,44,10.35,1), InvoiceItem(4,331,33,10.35,1)))
// Invoice(332,List(InvoiceItem(1,332,14,10.35,1), InvoiceItem(2,332,187,10.35,1)))
// Invoice(333,List(InvoiceItem(1,333,80,10.35,1), InvoiceItem(2,333,92,10.35,1)))
// Invoice(334,List(InvoiceItem(1,334,66,10.35,1), InvoiceItem(2,334,39,10.35,1), InvoiceItem(3,334,157,10.35,1), InvoiceItem(4,334,59,10.35,1)))
// Invoice(335,List(InvoiceItem(1,335,54,10.35,1), InvoiceItem(2,335,15,10.35,1), InvoiceItem(3,335,62,10.35,1), InvoiceItem(4,335,1,10.35,1)))
// Invoice(336,List(InvoiceItem(1,336,42,10.35,1)))
// Invoice(337,List(InvoiceItem(1,337,138,10.35,1), InvoiceItem(2,337,183,10.35,1), InvoiceItem(3,337,24,10.35,1), InvoiceItem(4,337,52,10.35,1), InvoiceItem(5,337,80,10.35,1)))
// Invoice(338,List(InvoiceItem(1,338,58,10.35,1), InvoiceItem(2,338,167,10.35,1), InvoiceItem(3,338,103,10.35,1), InvoiceItem(4,338,68,10.35,1), InvoiceItem(5,338,161,10.35,1)))
// Invoice(339,List(InvoiceItem(1,339,57,10.35,1), InvoiceItem(2,339,35,10.35,1), InvoiceItem(3,339,190,10.35,1)))
// Invoice(340,List(InvoiceItem(1,340,118,10.35,1), InvoiceItem(2,340,153,10.35,1), InvoiceItem(3,340,78,10.35,1)))
// Invoice(341,List(InvoiceItem(1,341,41,10.35,1), InvoiceItem(2,341,166,10.35,1)))
// Invoice(342,List(InvoiceItem(1,342,170,10.35,1), InvoiceItem(2,342,35,10.35,1), InvoiceItem(3,342,20,10.35,1), InvoiceItem(4,342,183,10.35,1), InvoiceItem(5,342,38,10.35,1)))
// Invoice(343,List(InvoiceItem(1,343,199,10.35,1)))
// Invoice(344,List(InvoiceItem(1,344,143,10.35,1), InvoiceItem(2,344,49,10.35,1)))
// Invoice(345,List(InvoiceItem(1,345,10,10.35,1), InvoiceItem(2,345,180,10.35,1), InvoiceItem(3,345,3,10.35,1)))
// Invoice(346,List(InvoiceItem(1,346,98,10.35,1)))
// Invoice(347,List(InvoiceItem(1,347,30,10.35,1), InvoiceItem(2,347,162,10.35,1), InvoiceItem(3,347,18,10.35,1), InvoiceItem(4,347,190,10.35,1)))
// Invoice(348,List(InvoiceItem(1,348,179,10.35,1), InvoiceItem(2,348,50,10.35,1)))
// Invoice(349,List(InvoiceItem(1,349,89,10.35,1), InvoiceItem(2,349,106,10.35,1), InvoiceItem(3,349,44,10.35,1), InvoiceItem(4,349,27,10.35,1), InvoiceItem(5,349,38,10.35,1)))
// Invoice(350,List(InvoiceItem(1,350,81,10.35,1)))
// Invoice(351,List(InvoiceItem(1,351,197,10.35,1), InvoiceItem(2,351,19,10.35,1), InvoiceItem(3,351,55,10.35,1), InvoiceItem(4,351,52,10.35,1), InvoiceItem(5,351,143,10.35,1)))
// Invoice(352,List(InvoiceItem(1,352,88,10.35,1), InvoiceItem(2,352,142,10.35,1)))
// Invoice(353,List(InvoiceItem(1,353,10,10.35,1), InvoiceItem(2,353,129,10.35,1), InvoiceItem(3,353,41,10.35,1), InvoiceItem(4,353,126,10.35,1)))
// Invoice(354,List(InvoiceItem(1,354,77,10.35,1), InvoiceItem(2,354,148,10.35,1), InvoiceItem(3,354,64,10.35,1), InvoiceItem(4,354,163,10.35,1)))
// Invoice(355,List(InvoiceItem(1,355,183,10.35,1), InvoiceItem(2,355,70,10.35,1)))
// Invoice(356,List(InvoiceItem(1,356,152,10.35,1)))
// ...
// Invoice(1863,List(InvoiceItem(1,1863,120,10.35,1), InvoiceItem(2,1863,112,10.35,1), InvoiceItem(3,1863,38,10.35,1), InvoiceItem(4,1863,159,10.35,1)))
// Invoice(1864,List(InvoiceItem(1,1864,138,10.35,1), InvoiceItem(2,1864,117,10.35,1), InvoiceItem(3,1864,192,10.35,1), InvoiceItem(4,1864,51,10.35,1), InvoiceItem(5,1864,19,10.35,1)))
// Invoice(1865,List(InvoiceItem(1,1865,71,10.35,1), InvoiceItem(2,1865,18,10.35,1), InvoiceItem(3,1865,50,10.35,1)))
// Invoice(1866,List(InvoiceItem(1,1866,140,10.35,1), InvoiceItem(2,1866,169,10.35,1), InvoiceItem(3,1866,62,10.35,1), InvoiceItem(4,1866,121,10.35,1)))
// Invoice(1867,List(InvoiceItem(1,1867,64,10.35,1)))
// Invoice(1868,List(InvoiceItem(1,1868,91,10.35,1)))
// Invoice(1869,List(InvoiceItem(1,1869,91,10.35,1), InvoiceItem(2,1869,188,10.35,1), InvoiceItem(3,1869,148,10.35,1)))
// Invoice(1870,List(InvoiceItem(1,1870,15,10.35,1), InvoiceItem(2,1870,110,10.35,1), InvoiceItem(3,1870,12,10.35,1), InvoiceItem(4,1870,73,10.35,1), InvoiceItem(5,1870,93,10.35,1)))
// Invoice(1871,List(InvoiceItem(1,1871,85,10.35,1)))
// Invoice(1872,List(InvoiceItem(1,1872,121,10.35,1)))
// Invoice(1873,List(InvoiceItem(1,1873,189,10.35,1), InvoiceItem(2,1873,23,10.35,1), InvoiceItem(3,1873,4,10.35,1)))
// Invoice(1874,List(InvoiceItem(1,1874,16,10.35,1)))
// Invoice(1875,List(InvoiceItem(1,1875,101,10.35,1), InvoiceItem(2,1875,190,10.35,1), InvoiceItem(3,1875,34,10.35,1)))
// Invoice(1876,List(InvoiceItem(1,1876,150,10.35,1), InvoiceItem(2,1876,165,10.35,1), InvoiceItem(3,1876,41,10.35,1), InvoiceItem(4,1876,121,10.35,1)))
// Invoice(1877,List(InvoiceItem(1,1877,87,10.35,1), InvoiceItem(2,1877,17,10.35,1), InvoiceItem(3,1877,23,10.35,1), InvoiceItem(4,1877,181,10.35,1), InvoiceItem(5,1877,34,10.35,1)))
// Invoice(1878,List(InvoiceItem(1,1878,136,10.35,1), InvoiceItem(2,1878,100,10.35,1), InvoiceItem(3,1878,17,10.35,1), InvoiceItem(4,1878,82,10.35,1), InvoiceItem(5,1878,107,10.35,1)))
// Invoice(1879,List(InvoiceItem(1,1879,180,10.35,1), InvoiceItem(2,1879,56,10.35,1)))
// Invoice(1880,List(InvoiceItem(1,1880,166,10.35,1), InvoiceItem(2,1880,54,10.35,1), InvoiceItem(3,1880,17,10.35,1), InvoiceItem(4,1880,22,10.35,1)))
// Invoice(1881,List(InvoiceItem(1,1881,91,10.35,1), InvoiceItem(2,1881,43,10.35,1)))
// Invoice(1882,List(InvoiceItem(1,1882,62,10.35,1), InvoiceItem(2,1882,148,10.35,1), InvoiceItem(3,1882,50,10.35,1), InvoiceItem(4,1882,100,10.35,1)))
// Invoice(1883,List(InvoiceItem(1,1883,193,10.35,1), InvoiceItem(2,1883,183,10.35,1)))
// Invoice(1884,List(InvoiceItem(1,1884,5,10.35,1), InvoiceItem(2,1884,9,10.35,1), InvoiceItem(3,1884,36,10.35,1), InvoiceItem(4,1884,87,10.35,1), InvoiceItem(5,1884,124,10.35,1)))
// Invoice(1885,List(InvoiceItem(1,1885,187,10.35,1), InvoiceItem(2,1885,9,10.35,1), InvoiceItem(3,1885,107,10.35,1)))
// Invoice(1886,List(InvoiceItem(1,1886,95,10.35,1), InvoiceItem(2,1886,132,10.35,1), InvoiceItem(3,1886,128,10.35,1)))
// Invoice(1887,List(InvoiceItem(1,1887,82,10.35,1), InvoiceItem(2,1887,139,10.35,1), InvoiceItem(3,1887,198,10.35,1), InvoiceItem(4,1887,183,10.35,1)))
// Invoice(1888,List(InvoiceItem(1,1888,27,10.35,1), InvoiceItem(2,1888,34,10.35,1), InvoiceItem(3,1888,114,10.35,1)))
// Invoice(1889,List(InvoiceItem(1,1889,60,10.35,1), InvoiceItem(2,1889,51,10.35,1), InvoiceItem(3,1889,135,10.35,1), InvoiceItem(4,1889,84,10.35,1), InvoiceItem(5,1889,77,10.35,1)))
// Invoice(1890,List(InvoiceItem(1,1890,44,10.35,1), InvoiceItem(2,1890,142,10.35,1), InvoiceItem(3,1890,83,10.35,1), InvoiceItem(4,1890,51,10.35,1), InvoiceItem(5,1890,150,10.35,1)))
// Invoice(1891,List(InvoiceItem(1,1891,174,10.35,1), InvoiceItem(2,1891,27,10.35,1), InvoiceItem(3,1891,109,10.35,1), InvoiceItem(4,1891,176,10.35,1)))
// Invoice(1892,List(InvoiceItem(1,1892,135,10.35,1), InvoiceItem(2,1892,100,10.35,1)))
// Invoice(1893,List(InvoiceItem(1,1893,114,10.35,1), InvoiceItem(2,1893,118,10.35,1)))
// Invoice(1894,List(InvoiceItem(1,1894,199,10.35,1), InvoiceItem(2,1894,156,10.35,1)))
// Invoice(1895,List(InvoiceItem(1,1895,29,10.35,1), InvoiceItem(2,1895,180,10.35,1), InvoiceItem(3,1895,57,10.35,1)))
// Invoice(1896,List(InvoiceItem(1,1896,120,10.35,1)))
// Invoice(1897,List(InvoiceItem(1,1897,29,10.35,1), InvoiceItem(2,1897,168,10.35,1), InvoiceItem(3,1897,60,10.35,1)))
// Invoice(1898,List(InvoiceItem(1,1898,36,10.35,1)))
// Invoice(1899,List(InvoiceItem(1,1899,156,10.35,1), InvoiceItem(2,1899,145,10.35,1), InvoiceItem(3,1899,17,10.35,1), InvoiceItem(4,1899,114,10.35,1)))
// Invoice(1900,List(InvoiceItem(1,1900,75,10.35,1), InvoiceItem(2,1900,127,10.35,1)))
// Invoice(1901,List(InvoiceItem(1,1901,34,10.35,1), InvoiceItem(2,1901,19,10.35,1)))
// Invoice(1902,List(InvoiceItem(1,1902,13,10.35,1)))
// Invoice(1903,List(InvoiceItem(1,1903,115,10.35,1), InvoiceItem(2,1903,39,10.35,1), InvoiceItem(3,1903,82,10.35,1), InvoiceItem(4,1903,62,10.35,1), InvoiceItem(5,1903,10,10.35,1)))
// Invoice(1904,List(InvoiceItem(1,1904,149,10.35,1), InvoiceItem(2,1904,35,10.35,1), InvoiceItem(3,1904,11,10.35,1)))
// Invoice(1905,List(InvoiceItem(1,1905,195,10.35,1), InvoiceItem(2,1905,57,10.35,1), InvoiceItem(3,1905,196,10.35,1), InvoiceItem(4,1905,177,10.35,1), InvoiceItem(5,1905,56,10.35,1)))
// Invoice(1906,List(InvoiceItem(1,1906,55,10.35,1), InvoiceItem(2,1906,29,10.35,1)))
// Invoice(1907,List(InvoiceItem(1,1907,44,10.35,1), InvoiceItem(2,1907,166,10.35,1), InvoiceItem(3,1907,7,10.35,1), InvoiceItem(4,1907,45,10.35,1)))
// Invoice(1908,List(InvoiceItem(1,1908,159,10.35,1), InvoiceItem(2,1908,16,10.35,1), InvoiceItem(3,1908,180,10.35,1), InvoiceItem(4,1908,20,10.35,1), InvoiceItem(5,1908,143,10.35,1)))
// Invoice(1909,List(InvoiceItem(1,1909,152,10.35,1), InvoiceItem(2,1909,103,10.35,1), InvoiceItem(3,1909,19,10.35,1), InvoiceItem(4,1909,161,10.35,1)))
// Invoice(1910,List(InvoiceItem(1,1910,181,10.35,1), InvoiceItem(2,1910,161,10.35,1), InvoiceItem(3,1910,141,10.35,1)))
// Invoice(1911,List(InvoiceItem(1,1911,182,10.35,1), InvoiceItem(2,1911,189,10.35,1), InvoiceItem(3,1911,127,10.35,1)))
// Invoice(1912,List(InvoiceItem(1,1912,185,10.35,1), InvoiceItem(2,1912,184,10.35,1), InvoiceItem(3,1912,29,10.35,1)))
// Invoice(1913,List(InvoiceItem(1,1913,123,10.35,1), InvoiceItem(2,1913,170,10.35,1), InvoiceItem(3,1913,60,10.35,1), InvoiceItem(4,1913,113,10.35,1)))
// Invoice(1914,List(InvoiceItem(1,1914,128,10.35,1), InvoiceItem(2,1914,113,10.35,1), InvoiceItem(3,1914,17,10.35,1), InvoiceItem(4,1914,189,10.35,1)))
// Invoice(1915,List(InvoiceItem(1,1915,19,10.35,1), InvoiceItem(2,1915,78,10.35,1), InvoiceItem(3,1915,87,10.35,1), InvoiceItem(4,1915,18,10.35,1)))
// Invoice(1916,List(InvoiceItem(1,1916,188,10.35,1)))
// Invoice(1917,List(InvoiceItem(1,1917,97,10.35,1), InvoiceItem(2,1917,98,10.35,1)))
// Invoice(1918,List(InvoiceItem(1,1918,11,10.35,1), InvoiceItem(2,1918,199,10.35,1), InvoiceItem(3,1918,109,10.35,1), InvoiceItem(4,1918,109,10.35,1), InvoiceItem(5,1918,130,10.35,1)))
// Invoice(1919,List(InvoiceItem(1,1919,119,10.35,1), InvoiceItem(2,1919,96,10.35,1), InvoiceItem(3,1919,188,10.35,1)))
// Invoice(1920,List(InvoiceItem(1,1920,124,10.35,1), InvoiceItem(2,1920,1,10.35,1), InvoiceItem(3,1920,149,10.35,1), InvoiceItem(4,1920,29,10.35,1), InvoiceItem(5,1920,69,10.35,1)))
// Invoice(1921,List(InvoiceItem(1,1921,21,10.35,1), InvoiceItem(2,1921,99,10.35,1)))
// Invoice(1922,List(InvoiceItem(1,1922,64,10.35,1), InvoiceItem(2,1922,164,10.35,1), InvoiceItem(3,1922,28,10.35,1), InvoiceItem(4,1922,173,10.35,1)))
// Invoice(1923,List(InvoiceItem(1,1923,39,10.35,1), InvoiceItem(2,1923,151,10.35,1), InvoiceItem(3,1923,200,10.35,1), InvoiceItem(4,1923,133,10.35,1), InvoiceItem(5,1923,15,10.35,1)))
// Invoice(1924,List(InvoiceItem(1,1924,55,10.35,1)))
// Invoice(1925,List(InvoiceItem(1,1925,155,10.35,1), InvoiceItem(2,1925,136,10.35,1), InvoiceItem(3,1925,8,10.35,1)))
// Invoice(1926,List(InvoiceItem(1,1926,82,10.35,1), InvoiceItem(2,1926,196,10.35,1), InvoiceItem(3,1926,56,10.35,1), InvoiceItem(4,1926,64,10.35,1)))
// Invoice(1927,List(InvoiceItem(1,1927,66,10.35,1), InvoiceItem(2,1927,170,10.35,1), InvoiceItem(3,1927,122,10.35,1)))
// Invoice(1928,List(InvoiceItem(1,1928,189,10.35,1), InvoiceItem(2,1928,83,10.35,1)))
// Invoice(1929,List(InvoiceItem(1,1929,69,10.35,1), InvoiceItem(2,1929,67,10.35,1), InvoiceItem(3,1929,139,10.35,1)))
// Invoice(1930,List(InvoiceItem(1,1930,178,10.35,1)))
// Invoice(1931,List(InvoiceItem(1,1931,35,10.35,1), InvoiceItem(2,1931,160,10.35,1), InvoiceItem(3,1931,73,10.35,1)))
// Invoice(1932,List(InvoiceItem(1,1932,45,10.35,1), InvoiceItem(2,1932,200,10.35,1)))
// Invoice(1933,List(InvoiceItem(1,1933,130,10.35,1)))
// Invoice(1934,List(InvoiceItem(1,1934,36,10.35,1), InvoiceItem(2,1934,145,10.35,1), InvoiceItem(3,1934,104,10.35,1), InvoiceItem(4,1934,89,10.35,1), InvoiceItem(5,1934,94,10.35,1)))
// Invoice(1935,List(InvoiceItem(1,1935,41,10.35,1), InvoiceItem(2,1935,71,10.35,1)))
// Invoice(1936,List(InvoiceItem(1,1936,149,10.35,1), InvoiceItem(2,1936,25,10.35,1), InvoiceItem(3,1936,172,10.35,1), InvoiceItem(4,1936,175,10.35,1)))
// Invoice(1937,List(InvoiceItem(1,1937,150,10.35,1), InvoiceItem(2,1937,28,10.35,1)))
// Invoice(1938,List(InvoiceItem(1,1938,30,10.35,1), InvoiceItem(2,1938,140,10.35,1)))
// Invoice(1939,List(InvoiceItem(1,1939,20,10.35,1), InvoiceItem(2,1939,35,10.35,1), InvoiceItem(3,1939,198,10.35,1), InvoiceItem(4,1939,103,10.35,1)))
// Invoice(1940,List(InvoiceItem(1,1940,16,10.35,1), InvoiceItem(2,1940,150,10.35,1), InvoiceItem(3,1940,112,10.35,1)))
// Invoice(1941,List(InvoiceItem(1,1941,55,10.35,1), InvoiceItem(2,1941,4,10.35,1), InvoiceItem(3,1941,13,10.35,1), InvoiceItem(4,1941,57,10.35,1), InvoiceItem(5,1941,193,10.35,1)))
// Invoice(1942,List(InvoiceItem(1,1942,76,10.35,1), InvoiceItem(2,1942,69,10.35,1), InvoiceItem(3,1942,73,10.35,1)))
// Invoice(1943,List(InvoiceItem(1,1943,126,10.35,1), InvoiceItem(2,1943,169,10.35,1)))
// Invoice(1944,List(InvoiceItem(1,1944,85,10.35,1), InvoiceItem(2,1944,5,10.35,1), InvoiceItem(3,1944,139,10.35,1)))
// Invoice(1945,List(InvoiceItem(1,1945,178,10.35,1), InvoiceItem(2,1945,186,10.35,1), InvoiceItem(3,1945,199,10.35,1)))
// Invoice(1946,List(InvoiceItem(1,1946,42,10.35,1), InvoiceItem(2,1946,87,10.35,1)))
// Invoice(1947,List(InvoiceItem(1,1947,50,10.35,1)))
// Invoice(1948,List(InvoiceItem(1,1948,14,10.35,1), InvoiceItem(2,1948,28,10.35,1)))
// Invoice(1949,List(InvoiceItem(1,1949,161,10.35,1), InvoiceItem(2,1949,52,10.35,1), InvoiceItem(3,1949,17,10.35,1), InvoiceItem(4,1949,154,10.35,1), InvoiceItem(5,1949,181,10.35,1)))
// Invoice(1950,List(InvoiceItem(1,1950,4,10.35,1), InvoiceItem(2,1950,56,10.35,1)))
// Invoice(1951,List(InvoiceItem(1,1951,174,10.35,1), InvoiceItem(2,1951,128,10.35,1), InvoiceItem(3,1951,39,10.35,1)))
// Invoice(1952,List(InvoiceItem(1,1952,186,10.35,1), InvoiceItem(2,1952,50,10.35,1), InvoiceItem(3,1952,186,10.35,1)))
// Invoice(1953,List(InvoiceItem(1,1953,137,10.35,1), InvoiceItem(2,1953,162,10.35,1), InvoiceItem(3,1953,133,10.35,1)))
// Invoice(1954,List(InvoiceItem(1,1954,27,10.35,1)))
// Invoice(1955,List(InvoiceItem(1,1955,159,10.35,1), InvoiceItem(2,1955,25,10.35,1), InvoiceItem(3,1955,188,10.35,1), InvoiceItem(4,1955,74,10.35,1), InvoiceItem(5,1955,77,10.35,1)))
// Invoice(1956,List(InvoiceItem(1,1956,188,10.35,1), InvoiceItem(2,1956,42,10.35,1), InvoiceItem(3,1956,53,10.35,1), InvoiceItem(4,1956,174,10.35,1), InvoiceItem(5,1956,102,10.35,1)))
// Invoice(1957,List(InvoiceItem(1,1957,189,10.35,1), InvoiceItem(2,1957,184,10.35,1), InvoiceItem(3,1957,195,10.35,1)))
// Invoice(1958,List(InvoiceItem(1,1958,32,10.35,1), InvoiceItem(2,1958,178,10.35,1), InvoiceItem(3,1958,138,10.35,1)))
// Invoice(1959,List(InvoiceItem(1,1959,114,10.35,1), InvoiceItem(2,1959,21,10.35,1), InvoiceItem(3,1959,23,10.35,1)))
// Invoice(1960,List(InvoiceItem(1,1960,9,10.35,1), InvoiceItem(2,1960,167,10.35,1), InvoiceItem(3,1960,133,10.35,1)))
// Invoice(1961,List(InvoiceItem(1,1961,176,10.35,1), InvoiceItem(2,1961,194,10.35,1), InvoiceItem(3,1961,25,10.35,1), InvoiceItem(4,1961,121,10.35,1), InvoiceItem(5,1961,192,10.35,1)))
// Invoice(1962,List(InvoiceItem(1,1962,37,10.35,1), InvoiceItem(2,1962,155,10.35,1), InvoiceItem(3,1962,37,10.35,1), InvoiceItem(4,1962,126,10.35,1)))
// Invoice(1963,List(InvoiceItem(1,1963,84,10.35,1), InvoiceItem(2,1963,187,10.35,1), InvoiceItem(3,1963,17,10.35,1), InvoiceItem(4,1963,81,10.35,1)))
// Invoice(1964,List(InvoiceItem(1,1964,52,10.35,1), InvoiceItem(2,1964,130,10.35,1), InvoiceItem(3,1964,23,10.35,1), InvoiceItem(4,1964,58,10.35,1), InvoiceItem(5,1964,175,10.35,1)))
// Invoice(1965,List(InvoiceItem(1,1965,61,10.35,1), InvoiceItem(2,1965,163,10.35,1), InvoiceItem(3,1965,165,10.35,1), InvoiceItem(4,1965,23,10.35,1), InvoiceItem(5,1965,192,10.35,1)))
// Invoice(1966,List(InvoiceItem(1,1966,91,10.35,1)))
// Invoice(1967,List(InvoiceItem(1,1967,156,10.35,1), InvoiceItem(2,1967,155,10.35,1)))
// Invoice(1968,List(InvoiceItem(1,1968,100,10.35,1)))
// Invoice(1969,List(InvoiceItem(1,1969,100,10.35,1), InvoiceItem(2,1969,74,10.35,1)))
// Invoice(1970,List(InvoiceItem(1,1970,30,10.35,1)))
// Invoice(1971,List(InvoiceItem(1,1971,137,10.35,1)))
// Invoice(1972,List(InvoiceItem(1,1972,100,10.35,1), InvoiceItem(2,1972,96,10.35,1), InvoiceItem(3,1972,167,10.35,1), InvoiceItem(4,1972,62,10.35,1)))
// Invoice(1973,List(InvoiceItem(1,1973,60,10.35,1)))
// Invoice(1974,List(InvoiceItem(1,1974,30,10.35,1)))
// Invoice(1975,List(InvoiceItem(1,1975,126,10.35,1), InvoiceItem(2,1975,168,10.35,1), InvoiceItem(3,1975,117,10.35,1), InvoiceItem(4,1975,154,10.35,1), InvoiceItem(5,1975,196,10.35,1)))
// Invoice(1976,List(InvoiceItem(1,1976,174,10.35,1)))
// Invoice(1977,List(InvoiceItem(1,1977,189,10.35,1), InvoiceItem(2,1977,117,10.35,1)))
// Invoice(1978,List(InvoiceItem(1,1978,11,10.35,1)))
// Invoice(1979,List(InvoiceItem(1,1979,145,10.35,1), InvoiceItem(2,1979,19,10.35,1)))
// Invoice(1980,List(InvoiceItem(1,1980,58,10.35,1), InvoiceItem(2,1980,95,10.35,1), InvoiceItem(3,1980,100,10.35,1), InvoiceItem(4,1980,116,10.35,1), InvoiceItem(5,1980,118,10.35,1)))
// Invoice(1981,List(InvoiceItem(1,1981,20,10.35,1), InvoiceItem(2,1981,71,10.35,1)))
// Invoice(1982,List(InvoiceItem(1,1982,91,10.35,1), InvoiceItem(2,1982,105,10.35,1), InvoiceItem(3,1982,99,10.35,1), InvoiceItem(4,1982,147,10.35,1)))
// Invoice(1983,List(InvoiceItem(1,1983,9,10.35,1), InvoiceItem(2,1983,184,10.35,1), InvoiceItem(3,1983,80,10.35,1)))
// Invoice(1984,List(InvoiceItem(1,1984,83,10.35,1), InvoiceItem(2,1984,165,10.35,1), InvoiceItem(3,1984,199,10.35,1), InvoiceItem(4,1984,23,10.35,1), InvoiceItem(5,1984,196,10.35,1)))
// Invoice(1985,List(InvoiceItem(1,1985,193,10.35,1), InvoiceItem(2,1985,185,10.35,1), InvoiceItem(3,1985,190,10.35,1)))
// Invoice(1986,List(InvoiceItem(1,1986,121,10.35,1), InvoiceItem(2,1986,144,10.35,1), InvoiceItem(3,1986,51,10.35,1), InvoiceItem(4,1986,63,10.35,1)))
// Invoice(1987,List(InvoiceItem(1,1987,133,10.35,1), InvoiceItem(2,1987,95,10.35,1)))
// Invoice(1988,List(InvoiceItem(1,1988,88,10.35,1), InvoiceItem(2,1988,56,10.35,1), InvoiceItem(3,1988,3,10.35,1), InvoiceItem(4,1988,121,10.35,1), InvoiceItem(5,1988,8,10.35,1)))
// Invoice(1989,List(InvoiceItem(1,1989,190,10.35,1)))
// Invoice(1990,List(InvoiceItem(1,1990,142,10.35,1)))
// Invoice(1991,List(InvoiceItem(1,1991,134,10.35,1), InvoiceItem(2,1991,133,10.35,1)))
// Invoice(1992,List(InvoiceItem(1,1992,200,10.35,1), InvoiceItem(2,1992,36,10.35,1), InvoiceItem(3,1992,75,10.35,1)))
// Invoice(1993,List(InvoiceItem(1,1993,44,10.35,1)))
// Invoice(1994,List(InvoiceItem(1,1994,139,10.35,1)))
// Invoice(1995,List(InvoiceItem(1,1995,197,10.35,1), InvoiceItem(2,1995,181,10.35,1), InvoiceItem(3,1995,183,10.35,1), InvoiceItem(4,1995,92,10.35,1)))
// Invoice(1996,List(InvoiceItem(1,1996,151,10.35,1)))
// Invoice(1997,List(InvoiceItem(1,1997,2,10.35,1), InvoiceItem(2,1997,150,10.35,1), InvoiceItem(3,1997,111,10.35,1), InvoiceItem(4,1997,132,10.35,1), InvoiceItem(5,1997,122,10.35,1)))
// Invoice(1998,List(InvoiceItem(1,1998,56,10.35,1), InvoiceItem(2,1998,157,10.35,1), InvoiceItem(3,1998,86,10.35,1), InvoiceItem(4,1998,144,10.35,1)))
// Invoice(1999,List(InvoiceItem(1,1999,140,10.35,1), InvoiceItem(2,1999,27,10.35,1), InvoiceItem(3,1999,82,10.35,1)))
// Invoice(2000,List(InvoiceItem(1,2000,25,10.35,1), InvoiceItem(2,2000,109,10.35,1), InvoiceItem(3,2000,103,10.35,1), InvoiceItem(4,2000,12,10.35,1), InvoiceItem(5,2000,127,10.35,1)))

// %% [markdown]
// # Atelier 3

// %% [markdown]
// ### Etape 1 Filtrage

// %%
val medias: List[MediaType] = List(mediaTypes(1), mediaTypes(2))
val mediasId: List[Int] = medias.map(_.id)

val filteredTrackList: List[Track] = trackList.filter(track => mediasId.contains(track.mediaTypeId))
// Out:
// medias = List(MediaType(2,Protected AAC audio file), MediaType(3,Protected MPEG-4 video file))
// mediasId = List(2, 3)
// filteredTrackList = List(Track(3,Wild Killers from Beyond,8,3), Track(6,Cosmic Outlaws of Eternity,25,3), Track(10,Stellar Angels of Eternity,7,3), Track(12,Silent Dragons in Chains,9,2), Track(14,Liquid Rebels of the Underground,15,3), Track(16,Primal Ravens from the East,8,3), Track(19,Electric Saints of the Night,6,2), Track(22,Mystic Wolves of the North,5,2), Track(23,Liquid Wizards of Tomorrow,6,3), Track(24,Mystic Lions from Hell,1,3), Track(27,Screaming Machines of Death,12,2), Track(28,Cosmic Horizon from the Sky,24,2), Track(29,Urban Demons from Mars,20,3), Track(31,Infinite Dragons of the Underground,21,2), Track(33,Neon ...
// List(Track(3,Wild Killers from Beyond,8,3), Track(6,Cosmic Outlaws of Eternity,25,3), Track(10,Stellar Angels of Eternity,7,3), Track(12,Silent Dragons in Chains,9,2), Track(14,Liquid Rebels of the Underground,15,3), Track(16,Primal Ravens from the East,8,3), Track(19,Electric Saints of the Night,6,2), Track(22,Mystic Wolves of the North,5,2), Track(23,Liquid Wizards of Tomorrow,6,3), Track(24,Mystic Lions from Hell,1,3), Track(27,Screaming Machines of Death,12,2), Track(28,Cosmic Horizon from the Sky,24,2), Track(29,Urban Demons from Mars,20,3), Track(31,Infinite Dragons of the Underground,21,2), Track(33,Neon ...

// %%
val invoiceListGenre1: List[Invoice] = invoiceList.filter { invoice =>
  val trackIds = invoice.invoiceListItem.map(_.trackId)
  val tracksInInvoice = trackIds.flatMap(id => trackList.find(_.id == id))
  
  val genre1Count = tracksInInvoice.count(_.genreId == 1)
  val total = tracksInInvoice.size

  total > 0 && genre1Count > total / 2
}
// Out:
// invoiceListGenre1 = List(Invoice(88,List(InvoiceItem(1,88,54,10.35,1))), Invoice(202,List(InvoiceItem(1,202,21,10.35,1), InvoiceItem(2,202,110,10.35,1), InvoiceItem(3,202,142,10.35,1))), Invoice(423,List(InvoiceItem(1,423,54,10.35,1))), Invoice(539,List(InvoiceItem(1,539,24,10.35,1))), Invoice(595,List(InvoiceItem(1,595,43,10.35,1))), Invoice(703,List(InvoiceItem(1,703,43,10.35,1))), Invoice(854,List(InvoiceItem(1,854,43,10.35,1))), Invoice(929,List(InvoiceItem(1,929,149,10.35,1))), Invoice(932,List(InvoiceItem(1,932,142,10.35,1))), Invoice(960,List(InvoiceItem(1,960,74,10.35,1))), Invoice(965,List(InvoiceItem(1,965,24,10.35,1))), Invoice(1090,List(InvoiceItem(1,1090,54,10.35,1))), Invoice(1297,List(InvoiceItem(1,1297,162,10.35,1))), Invoice(1417,List(InvoiceItem(1,1417,5...
// List(Invoice(88,List(InvoiceItem(1,88,54,10.35,1))), Invoice(202,List(InvoiceItem(1,202,21,10.35,1), InvoiceItem(2,202,110,10.35,1), InvoiceItem(3,202,142,10.35,1))), Invoice(423,List(InvoiceItem(1,423,54,10.35,1))), Invoice(539,List(InvoiceItem(1,539,24,10.35,1))), Invoice(595,List(InvoiceItem(1,595,43,10.35,1))), Invoice(703,List(InvoiceItem(1,703,43,10.35,1))), Invoice(854,List(InvoiceItem(1,854,43,10.35,1))), Invoice(929,List(InvoiceItem(1,929,149,10.35,1))), Invoice(932,List(InvoiceItem(1,932,142,10.35,1))), Invoice(960,List(InvoiceItem(1,960,74,10.35,1))), Invoice(965,List(InvoiceItem(1,965,24,10.35,1))), Invoice(1090,List(InvoiceItem(1,1090,54,10.35,1))), Invoice(1297,List(InvoiceItem(1,1297,162,10.35,1))), Invoice(1417,List(InvoiceItem(1,1417,5...

// %% [markdown]
// ### Etape 2 - Agrégation

// %%
val allTrackIds: List[Int] = invoiceList.flatMap(_.invoiceListItem.map(_.trackId))
val trackIdToCount: Map[Int, Int] = allTrackIds.groupBy(id => id).map {
  case (trackId, list) => (trackId, list.size)
}
val sortedTrackIds: List[(Int, Int)] = trackIdToCount.toList.sortBy { case (_, count) => -count }
val top5TrackIds: List[Int] = sortedTrackIds.take(5).map { case (trackId, _) => trackId }
val top5Tracks: List[Track] = top5TrackIds.flatMap(id => trackList.find(_.id == id))

val top5Titles: List[String] = top5Tracks.map(_.name)
top5Titles.foreach(println)
// Out:
// Golden Ravens of the North
// Wild Ghosts of the North
// Stellar Saints of Doom
// Screaming Saints from Beyond
// Savage Bandits from the Desert
// allTrackIds = List(67, 137, 163, 108, 2, 194, 149, 188, 114, 169, 196, 64, 155, 134, 169, 200, 150, 39, 158, 15, 180, 185, 198, 89, 127, 149, 36, 107, 37, 182, 138, 160, 147, 49, 133, 156, 58, 78, 16, 200, 80, 117, 51, 23, 169, 83, 198, 71, 74, 162, 40, 195, 54, 130, 40, 71, 173, 23, 161, 47, 116, 58, 78, 98, 144, 3, 154, 170, 136, 58, 122, 192, 158, 59, 58, 27, 55, 95, 9, 123, 42, 127, 108, 164, 10, 152, 173, 75, 31, 167, 50, 90, 40, 62, 162, 13, 143, 84, 191, 158, 50, 62, 53, 196, 97, 72, 193, 8, 144, 118, 20, 128, 98, 175, 22, 172, 53, 167, 104, 44, 171, 191, 122, 170, 173, 44, 45, 31, 4, 50, 62, 17, 79, 180, 184, 54, 108, 14, 119, 61, 50, 75, 143, 96, 131, 32, 144, 43, 196, 160, 16, 170, 71, 131, 114, 2, 101, 141, 196, 168, 15, 57, 155, 75, 150, 51, 66, 10, 11, 45, 52, 76...
// List(67, 137, 163, 108, 2, 194, 149, 188, 114, 169, 196, 64, 155, 134, 169, 200, 150, 39, 158, 15, 180, 185, 198, 89, 127, 149, 36, 107, 37, 182, 138, 160, 147, 49, 133, 156, 58, 78, 16, 200, 80, 117, 51, 23, 169, 83, 198, 71, 74, 162, 40, 195, 54, 130, 40, 71, 173, 23, 161, 47, 116, 58, 78, 98, 144, 3, 154, 170, 136, 58, 122, 192, 158, 59, 58, 27, 55, 95, 9, 123, 42, 127, 108, 164, 10, 152, 173, 75, 31, 167, 50, 90, 40, 62, 162, 13, 143, 84, 191, 158, 50, 62, 53, 196, 97, 72, 193, 8, 144, 118, 20, 128, 98, 175, 22, 172, 53, 167, 104, 44, 171, 191, 122, 170, 173, 44, 45, 31, 4, 50, 62, 17, 79, 180, 184, 54, 108, 14, 119, 61, 50, 75, 143, 96, 131, 32, 144, 43, 196, 160, 16, 170, 71, 131, 114, 2, 101, 141, 196, 168, 15, 57, 155, 75, 150, 51, 66, 10, 11, 45, 52, 76...

// %%
val genreIdToInvoiceCount: Map[Int, Int] = invoiceList.flatMap { invoice =>
    val genreIds = invoice.invoiceListItem
      .flatMap(item => trackList.find(_.id == item.trackId).map(_.genreId))
      .distinct

    genreIds.map(genreId => (genreId, 1))
  }
  .groupBy(_._1)
  .mapValues(_.map(_._2).sum)
  .toMap
// Out:
// genreIdToInvoiceCount = Map(5 -> 264, 10 -> 158, 24 -> 162, 25 -> 304, 14 -> 55, 20 -> 176, 1 -> 225, 6 -> 219, 21 -> 375, 9 -> 98, 13 -> 197, 2 -> 262, 17 -> 245, 22 -> 164, 12 -> 295, 7 -> 284, 3 -> 211, 18 -> 122, 16 -> 112, 11 -> 282, 23 -> 307, 8 -> 220, 19 -> 320, 4 -> 256, 15 -> 263)
// Map(5 -> 264, 10 -> 158, 24 -> 162, 25 -> 304, 14 -> 55, 20 -> 176, 1 -> 225, 6 -> 219, 21 -> 375, 9 -> 98, 13 -> 197, 2 -> 262, 17 -> 245, 22 -> 164, 12 -> 295, 7 -> 284, 3 -> 211, 18 -> 122, 16 -> 112, 11 -> 282, 23 -> 307, 8 -> 220, 19 -> 320, 4 -> 256, 15 -> 263)

// %% [markdown]
// ### Etape 3 - Traitement récursif

// %%
def findTopManager(emp: Employee, employeeMap: Map[Int, Employee]): Employee = {
    if (emp.reportsTo == 0 || !employeeMap.contains(emp.reportsTo)) emp
    else findTopManager(employeeMap(emp.reportsTo), employeeMap)
}

val employeeMap: Map[Int, Employee] = employees.map(e => e.id -> e).toMap

val employee = employeeMap(6)
val topManager = findTopManager(employee, employeeMap)

println(s"Le plus haut responsable de ${employee.firstName} ${employee.lastName} est ${topManager.firstName} ${topManager.lastName} (${topManager.title})")
// Out:
// Le plus haut responsable de Michael Mitchell est Andrew Adams (General Manager)
// employeeMap = Map(5 -> Employee(5,Johnson,Steve,Sales Support Agent,2), 1 -> Employee(1,Adams,Andrew,General Manager,0), 6 -> Employee(6,Mitchell,Michael,IT Manager,1), 2 -> Employee(2,Edwards,Nancy,Sales Manager,1), 7 -> Employee(7,King,Robert,IT Staff,6), 3 -> Employee(3,Peacock,Jane,Sales Support Agent,2), 8 -> Employee(8,Callahan,Laura,IT Staff,6), 4 -> Employee(4,Park,Margaret,Sales Support Agent,2))
// employee = Employee(6,Mitchell,Michael,IT Manager,1)
// topManager = Employee(1,Adams,Andrew,General Manager,0)
// findTopManager: (emp: Employee, employeeMap: Map[Int,Employee])Employee
// Employee(1,Adams,Andrew,General Manager,0)
